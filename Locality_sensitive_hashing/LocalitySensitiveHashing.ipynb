# %% [markdown]
# # Locality Sensitive Hashing
#
# This notebook is a tutorial and python implementation of locality sensitive hashing.
#
# We demonstrate the tools using a very very small dataset, consisting of 4 articles pulled from CNN, and a 5th that is a partial concatenation of 3 of those, to artificialy produce some high similarity scores.
#
# Since this is a small dataset, we can easily compare our approximations to the true similarity scores amongst text files. We do so throughout. The layout of this notebook is as follows:
#
# Part I: computing similarity amongst text documents
# 1. Introduce a shingle function. Clean and split each text file into a set of K-shingles
# 2. Compute the exact Jaccard similarity (intersection over union) between all pairs
# 3. Create and apply a MinHashing class:
#     1. Initialize with a dictionary of key-value pairs for the shingles
#     2. Apply "universal hashing" to perform minhashing on a shingle set
#     3. can be called like a function to compute a **signature matrix**
# 4. Evaluate MinHashing effectiveness by computing scores of all pairs
# 5. Introduce LSH for finding **candidate pairs**, i.e. use a banded signature matrix to find all pairs whose similarity is likely above a threshold
# 6. Make this efficient, by using hash table for band, column ids, allowing O(n) comparison
#
# Part II: computing similarity amongst vectors
#
# * Afterwards, we provide an additional LSH family for Euclidean spaces, namely cosine similarity.
# * This is used to ascertain the similarity of vectors in a D-dimensional space.
# * Can be implemented using the *Random Hyperplanes* hashing method.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/ATIML/Locality-sensitive-hashing-tutorial
# Out:
# /content/drive/MyDrive/Colab Notebooks/ATIML/Locality-sensitive-hashing-tutorial

# %%
import os
import time
import itertools
import collections
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Part I: document similarity

# %% [markdown]
# ## MinHashing without Locality Sensitive Hashing

# %% [markdown]
# ### Shingling
#
# We illustrate how to convert a word document into a list of shingles.
# We will use three similar strings, and see how this shows similarity.
# I made a directory and copied 4 files from CNN, then the 5th is a concatenation of 3 of them, randomly deleting some lines

# %%
import os
HOME = os.getcwd()
TARGET = os.path.join(HOME, 'sampledocs/')
# "/content/drive/MyDrive/Colab Notebooks/ATIML/TREC_4_5/"
# 
print(TARGET)

documents = []
# for subdir, dirs, files in os.walk(TARGET):
#     for file in files:
#       with open((str(subdir)+"/"+str(file)), 'r', encoding="ISO-8859-1") as f:
#         lines = f.read()
#         documents += [lines]
for article in os.listdir(TARGET):
    if article == 'stopwords':
        continue
    path = os.path.join(TARGET, article)
    with open(path, 'r') as file:
        documents.append(file.read())
print(documents[1])
        
stopwords = []
with open(os.path.join(TARGET, 'stopwords'), 'r') as file:
    for line in file:
        stopwords.append(line.strip())
        
for i, doc in enumerate(documents):
    doc = doc.strip().replace('\n', ' ').lower()
    for word in stopwords:
        doc = doc.replace(' '+word+' ', ' ')
    documents[i] = doc
    print("/n")
print(f"Average char-length: \
{np.mean(np.array([len(x) for x in documents]))}")
print(f"Min char-length: {min(len(x) for x in documents)}")
print(f"Max char-length: {max(len(x) for x in documents)}")
print(len(documents))
print(type(documents))
for doc in documents:
  print(doc)
# Out:
# /content/drive/MyDrive/Colab Notebooks/ATIML/Locality-sensitive-hashing-tutorial/sampledocs/
# Investigators with the Manhattan district attorney's office have interviewed several employees at President Donald Trump's lender and insurer in recent weeks as part of a wide-ranging investigation into the Trump Organization, according to multiple people familiar with the investigation.
#
# Two employees of Deutsche Bank, which has loaned more than $300 million to the Trump Organization, were interviewed by prosecutors, according to sources familiar with the matter.
# The interviews took place after the November presidential election, the people said, and focused on general questions about how bankers assess loans and underwriting criteria.
# The questioning was not specific to the bank's dealing with the Trump Organization or the President, the people said, with one person adding that it was the beginning of the process. Additional interviews are expected in the near future, they said.
# Prosecutors also interviewed at least one employee at Aon, an insurance broker who has done work with the President's company, according to one source familiar with the matter.
# A spokeswoman for Aon confirmed the company received a subpoena and said it is cooperating with the investigation. The spokeswoman declined to comment on any employee interviews. Representatives for Deutsche Bank and the district attorney's office, led by Cyrus Vance, also declined to comment. Deutsche Bank was subpoenaed as part of the investigation last year and has said it cooperates with authorized investigations.
# The New York Times first reported on the interviews with Deutsche Bank and Aon employees.
# The interviews with Trump counterparties comes as prosecutors wait for a decision by the US Supreme Court over a grand jury subpoena for the President's tax returns. The President has lost several legal challenges in an attempt to block the subpoena to Mazars USA, his long-time accounting firm, for eight years of his personal and business records and tax returns.
# Last month, the 2nd US Circuit Court of Appeals denied Trump's latest effort to block the subpoena paving the way for it to be enforced. The President's lawyers have asked the Supreme Court to stay, or halt, the ruling and a decision is expected any day.
# The Mazars records are critical to the investigation, prosecutors have said. The Manhattan district attorney investigation is the only criminal inquiry facing Trump, his business and his family and will continue after he leaves office. Trump has had discussions about issuing pardons to his family members and possibly himself, CNN has reported, but those pardons would not insulate him from a state criminal indictment.
# In court filings the district attorney's office has suggested the inquiry could involve tax fraud, insurance fraud and schemes to defraud its lenders. They also recently subpoenaed the Trump Organization for records relating to fees it has paid to consultants, including a payment made to a company controlled by the President's daughter, Ivanka Trump, according to people familiar with the matter.
# The Trump Organization has denied any wrongdoing and said applicable taxes were paid.
# Last year prosecutors with the district attorney's office interviewed Michael Cohen, the President's former personal attorney, at least three times about his knowledge of the Trump Organization's business dealings.
# Cohen testified before Congress in February 2019 that the Trump Organization allegedly manipulated its financial statements to suit its desired outcomes. Cohen said Trump "deflated his assets to reduce his real estate taxes." And he alleged company officials would play with the financial numbers when dealing with insurance companies and Deutsche Bank.
# Specifically, Cohen alleged the President inflated the value of his assets at times, including in 2014 when Trump submitted documents to Deutsche Bank as part of an attempt to bid for the Buffalo Bills football team. Trump never did the loan.
# Cohen pleaded guilty to federal crimes, including campaign finance charges for facilitating hush-money payments to silence two woman's allegations of affairs with Trump. Trump has denied the affairs. Cohen is serving a three year prison sentence and was released to home confinement earlier this year due to the coronavirus pandemic.
#
#
# /n
# /n
# /n
# /n
# /n
# Average char-length: 3651.6
# Min char-length: 2412
# Max char-length: 5873
# 5
# <class 'list'>
# washington (cnn)white house chief staff mark meadows told food drug administration commissioner dr. stephen hahn needed grant emergency use authorization pfizer/biontech's coronavirus vaccine end friday, not, needs resign, administration official source familiar situation tell cnn.  another person familiar matter, also confirmed demand vaccine authorized end friday, said president donald trump venting fda chief since vaccine rolled uk earlier week. two men call friday morning. white house official said comment private conversations chief "regularly requests updates progress toward vaccine." hahn quickly disputed description conversation, first reported washington post, news likely raise additional questions extent trump administration political interests involved vaccine authorization process, could undermine public confidence effort.vaccine advisers fda voted thursday recommend agency grant emergency use authorization vaccine, it's expected authorized imminently."this untrue representation phone call chief staff. fda encouraged continue working expeditiously pfizer-biontech's (emergency use authorization) request," hahn said statement friday afternoon. "fda committed issuing authorization quickly, noted statement morning." white house official familiar conversation meadows hahn said it's doubtful fda commissioner actually fired. blunt warning chief staff might well resign pfizer's emergency use authorization isn't granted friday larger sign president's frustration, person said. public health experts fearful along white house officials would put undue pressure authorization process and, turn, compromise public confidence vaccine, source close white house coronavirus task force told cnn. source said it's unclear meadows would make threat late process authorization vaccine expected moment. person added authorization could come end friday. dr. moncef slaoui, head us government's effort develop vaccine covid-19, told cnn's jake tapper "the lead" friday concerned reports' potential effect undermining confidence vaccine's safety. "yes, think opportunity people see undue pressure story right," said also defending fda's authorization process, described "an effective, transparent, thorough, in-depth review." trump grown impatient authorization process recent weeks, one person familiar president's thinking telling cnn trump wants rush many vaccines possible leaves office. friday, called fda "a big, old, slow turtle." "get dam vaccines now, dr. hahn @stevefda," trump tweeted. "stop playing games start saving lives!!!" president-elect joe biden, remarks friday afternoon event announcing additional top administration picks, address news meadows demand hahn urged public faith vaccine expressed gratitude "to scientists public experts evaluated safety efficiency, free political influence." "i want make clear public, confidence -- political influence," biden said. "these first-rate scientists taking time looking elements need looked at. scientific integrity led us point."
# investigators manhattan district attorney's office interviewed several employees president donald trump's lender insurer recent weeks part wide-ranging investigation trump organization, according multiple people familiar investigation.  two employees deutsche bank, loaned $300 million trump organization, interviewed prosecutors, according sources familiar matter. interviews took place november presidential election, people said, focused general questions bankers assess loans underwriting criteria. questioning specific bank's dealing trump organization president, people said, one person adding beginning process. additional interviews expected near future, said. prosecutors also interviewed least one employee aon, insurance broker done work president's company, according one source familiar matter. spokeswoman aon confirmed company received subpoena said cooperating investigation. spokeswoman declined comment employee interviews. representatives deutsche bank district attorney's office, led cyrus vance, also declined comment. deutsche bank subpoenaed part investigation last year said cooperates authorized investigations. new york times first reported interviews deutsche bank aon employees. interviews trump counterparties comes prosecutors wait decision us supreme court grand jury subpoena president's tax returns. president lost several legal challenges attempt block subpoena mazars usa, long-time accounting firm, eight years personal business records tax returns. last month, 2nd us circuit court appeals denied trump's latest effort block subpoena paving way enforced. president's lawyers asked supreme court stay, halt, ruling decision expected day. mazars records critical investigation, prosecutors said. manhattan district attorney investigation criminal inquiry facing trump, business family continue leaves office. trump discussions issuing pardons family members possibly himself, cnn reported, pardons would insulate state criminal indictment. court filings district attorney's office suggested inquiry could involve tax fraud, insurance fraud schemes defraud lenders. also recently subpoenaed trump organization records relating fees paid consultants, including payment made company controlled president's daughter, ivanka trump, according people familiar matter. trump organization denied wrongdoing said applicable taxes paid. last year prosecutors district attorney's office interviewed michael cohen, president's former personal attorney, least three times knowledge trump organization's business dealings. cohen testified congress february 2019 trump organization allegedly manipulated financial statements suit desired outcomes. cohen said trump "deflated assets reduce real estate taxes." alleged company officials would play financial numbers dealing insurance companies deutsche bank. specifically, cohen alleged president inflated value assets times, including 2014 trump submitted documents deutsche bank part attempt bid buffalo bills football team. trump never loan. cohen pleaded guilty federal crimes, including campaign finance charges facilitating hush-money payments silence two woman's allegations affairs trump. trump denied affairs. cohen serving three year prison sentence released home confinement earlier year due coronavirus pandemic.
# in final days desperate, dishonest campaign upend last month's election, president donald trump tossed particularly audacious offensive challenge aimed somehow thinks change outcome.  "let's see courage everybody country knows right," said. time running out, blatant hope intimidate bait state legislatures supreme court overturning vote people, legislative judicial fiat. trump's perverse definition "courage" "right," course, amounts willingness bend truth prize continuation office american democracy. yet madness, witnessed many acts genuine courage. people parties bravely right.secretaries state election authorities contested states, republicans democrats, weathered death threats vows political retribution simply jobs counting, recounting certifying vote. shown enormous courage deserve gratitude respect. thousands everyday americans worked around clock -- midst pandemic sometimes din howling mobs background -- count recount votes. patriotic americans showed inspiring courage. so, too, governors loyally campaigned trump refused bow threats intimidation election. yes, simply law required democracy demands certifying vote states. officials acted knowing hothouse trump's republican party, duty could cost jobs primaries later. dozens judges -- appointed trump -- summarily dismissed ferocious, groundless assault election results. shown gratifying fidelity law. trump made clear start presidency believed every branch, every person government, beholden law oaths office.he told us election, rushing supreme court confirmation amy coney barrett, wanted nine justices rule election disputes. implication clear: justices. way. conservative supreme court would (so far, least) enlisted profane unconstitutional mission overturning election behalf. federal judges lifetime appointments, perhaps took less courage elected officials risked careers -- even lives -- stand rule law. justices deserve credit, too, firmly unanimously rejecting absurd lawsuits trump loyalists pushed way. courageous, too, handful elected republicans acknowledged results, congratulated president-elect joe biden urged peaceful, orderly transition power. seen acts courage, also seen cowardice. rudy giuliani trump legal team debased themselves, legal system democracy filing one frivolous lawsuit another, crying fraud tv -- courtroom, evidence required.and many republican officials, fearful getting sideways trump's base, dutifully echoed dishonest charges vote fraud. group republican state attorneys general lined support preposterous eleventh-hour filing attorney general texas, asking supreme court overturn results four states trump lost. suit filed without standing, supporting evidence colorable argument. nonetheless, rep. mike johnson louisiana circulated email among republican house colleagues urging sign amicus brief support outrageous folly. trump "anxiously awaiting final list" see signs amicus brief, johnson wrote, implying dire consequences anyone failed join. within 24 hours, 100 house republicans complied. supporters trump gone far argue republicans may stage battle house floor reject biden electors contested states, symbolic gesture would fail set chilling precedent.almost egregious many republican members house senate refused acknowledge biden's victory countenanced weeks delay transition. silence, given credence trump's blatant lies, gained traction among large majority republicans nationally. it's crazy, authoritarian stuff. occurring anywhere else, americans would condemn appalling attempt undermine democracy. history scorn cowards meekly complied trump's scheme tarnish overturn election -- honor many showed courage fidelity rule law time trial.
# ew quarantine hobbies unearthed new passions, bringing literal silver lining. year, backyard archaeologists united kingdom recorded discoveries 47,000 objects, british museum announced week. regular people found vast majority historical artifacts traversing countryside metal detectors, adding updating records museum's portable antiquities scheme. british museum said program also saw uptick people updating digital records antiquities country full lockdown march 22 may 13. database contains records 1.5 million objects discovered since 1998 general public rather professional archaeologists. "it brilliant see scheme growing strength strength lockdown thanks garden discoveries digital reporting," said uk culture minister caroline dinenage, news release. list garden treasures dug year includes 13th century medieval seal, bearing latin inscription reading "david, god's messenger, bishop st. andrews." shining among new discoveries two hoards coins. one troves, contained 50 south african solid gold coins, unearthed milton keynes, town 50 miles northwest london. it's mystery coins, minted 1970s south africa's apartheid era, wound buried british backyard half-century. major coin hoard, held 63 gold coins one silver coin featuring monarchs edward iv henry viii, likely buried 16th century. included coins bearing initials several henry viii's wives, including catherine aragon, anne boleyn jane seymour. nearly 500 years later covid-19 pandemic, residents rediscovered weeding garden. another amateur find pandemic ancient roman furniture fitting made copper alloy, clearly featuring face god oceanus. artifact, found old basing 50 miles southeast london, dates far back 1st century. new report pas shows 81,602 objects added scheme 2019, recent spate lockdown treasure hunting, items coming public ownership. uk's treasure act 1996 requires finders report discovery 300 years old local coroner area found it. local authority defines object treasure, takes find british museum valued. government pays fair market price discoverer. law intended allow national local museums ultimately acquire historic treasures overall public benefit. even pandemic portable antiquities scheme's liaison officers able reach finders obtain relics significance, michael lewis, heads program, said news release. mission continues "ensure finds, important understanding britain's past, lost instead recorded posterity," said.
# ew quarantine hobbies unearthed new passions, bringing literal silver lining. year, backyard archaeologists united kingdom recorded discoveries 47,000 objects, british museum announced week. regular people found vast majority historical artifacts traversing countryside metal detectors, adding updating records museum's portable antiquities scheme. british museum said program also saw uptick people updating digital records antiquities country full lockdown march 22 may 13. database contains records 1.5 million objects discovered since 1998 general public rather professional archaeologists. "it brilliant see scheme growing strength strength lockdown thanks garden discoveries digital reporting," said uk culture minister caroline dinenage, news release. list garden treasures dug year includes 13th century medieval seal, bearing latin inscription reading "david, god's messenger, bishop st. andrews." major coin hoard, held 63 gold coins one silver coin featuring monarchs edward iv henry viii, likely buried 16th century. included coins bearing initials several henry viii's wives, including catherine aragon, anne boleyn jane seymour. nearly 500 years later covid-19 pandemic, residents rediscovered weeding garden. another amateur find pandemic ancient roman furniture fitting made copper alloy, clearly featuring face god oceanus. artifact, found old basing 50 miles southeast london, dates far back 1st century. new report pas shows 81,602 objects added scheme 2019, recent spate lockdown treasure hunting, items coming public ownership. local authority defines object treasure, takes find british museum valued. government pays fair market price discoverer. law intended allow national local museums ultimately acquire historic treasures overall public benefit. even pandemic portable antiquities scheme's liaison officers able reach finders obtain relics significance, michael lewis, heads program, said news release. mission continues "ensure finds, important understanding britain's past, lost instead recorded posterity," said.  another person familiar matter, also confirmed demand vaccine authorized end friday, said president donald trump venting fda chief since vaccine rolled uk earlier week. two men call friday morning. white house official said comment private conversations chief "regularly requests updates progress toward vaccine." hahn quickly disputed description conversation, first reported washington post, news likely raise additional questions extent trump administration political interests involved vaccine authorization process, could undermine public confidence effort.vaccine advisers fda voted thursday recommend agency grant emergency use authorization vaccine, it's expected authorized imminently."this untrue representation phone call chief staff. fda encouraged continue working expeditiously pfizer-biontech's (emergency use authorization) request," hahn said statement friday afternoon. "fda committed issuing authorization quickly, noted statement morning." public health experts fearful along white house officials would put undue pressure authorization process and, turn, compromise public confidence vaccine, source close white house coronavirus task force told cnn. source said it's unclear meadows would make threat late process authorization vaccine expected moment. person added authorization could come end friday. dr. moncef slaoui, head us government's effort develop vaccine covid-19, told cnn's jake tapper "the lead" friday concerned reports' potential effect undermining confidence vaccine's safety. president-elect joe biden, remarks friday afternoon event announcing additional top administration picks, address news meadows demand hahn urged public faith vaccine expressed gratitude "to scientists public experts evaluated safety efficiency, free political influence." "i want make clear public, confidence -- political influence," biden said. "these first-rate scientists taking time looking elements need looked at. scientific integri ...

# %%
import pandas as pd
processed_articles = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ATIML/processed_articles.pkl")

# %%
print(type(processed_articles))
# Out:
# <class 'list'>

# %%
print(processed_articles[0])
# Out:
#               march reports     march   article typefbis  document typeforeign media notefb pn          former yugoslav republic of macedonia opinion polls on       politicians  party preferences      summary  newspapers in the former yugoslav republic of     macedonia have published the results of opinion polls     indicating the relative popularity of politicians     political parties and attitudes toward the political system      the  january edition of the skopje newspaper vecer in  macedonian published on pages  the results of an opinion poll  conducted by the brima agency in november  according to  vecer  respondents were classified by age and residence but  the paper did not explain the methodology or give the margin of  error  for the purpose of comparison the paper cited the results  of an unidentified poll made in may  the approvaldisapproval  ratings in percent for ten macedonian politicians were                                              november     may    kiro gligorov president of the republic                    vasil tupurkovski former macedonian                          official in federal yugoslavia   ljubomir frckovski interior minister                       stojan andov parliamentary chairman                        branko crvenkovski prime minister                          vlado popovski defense minister                            stevo crvenkovski foreign minister              no data given   petar gosev democratic party leader                        todor petrov independent parliamentarian        no data given   nikola popovski social democratic                            party parliamentarian      vecer noted that president gligorovs very high approval rating  of  percent among those over age  fell off to a still high   percent among respondents between  and   residents of skopje  ranked the politicians in a slightly different order from the  ranking given by the whole sample gligorov tupurkovski frckovski  andov gosev branko crvenkovski vlado popovski petrov nikola  popovski and stevo crvenkovski      the results of a series of opinion polls conducted by the agency  for public opinion research and published exclusively by the  skopje weekly puls newspaper confirmed gligorovs substantial lead  in popularity among political figures  according to the  december   issue of puls pages  the agency gathered the data by  means of telephone interviews with  residents in the republic of  macedonia during  december puls also provided data from  surveys made in march june and september for comparison  some of  the following percentages are approximate values that were derived  from the graph published by the paper                            march       june      september    december   kiro gligorov                                          stevo crvenkovski                                            stojan andov                                                 branko crvenkovski                               ljubomir frckovski                                           petar gosev                                      jovan andonov   deputy prime minister                                       vlado popovski                                               kiro popovski deputy   chairman parliament                                        ante popovski leader of   maak movement for all   macedonian action                            indistinct  jane miljovski minister   without portfolio                                           vladimir golubovski   vmrodp internal   macedonian revolutionary   organizationdemocratic   party leader                                               nevzat halili   party for democratic   prosperity official                                       lj upco georgievski  vmrodpmne internal  macedonian revolutionary  organizationdemocratic  party for macedonian  national unity  official                                                     dosta dimovska  vmrodpmne  official                                ...

# %%
# create K-shingles by sliding window approach
def getShingles(str1, K=5):
    d1 = set()
    for i in range(len(str1)-K):
        d1.add(str1[i:i+K])
    print(f"Found {len(d1)} unique shingles, out of {len(str1)} possible.")
    return d1
doc_shingles = [getShingles(s, 9) for s in processed_articles[:1000]]
# Out:
# Found 84807 unique shingles, out of 952484 possible.
# Found 73177 unique shingles, out of 790488 possible.
# Found 68941 unique shingles, out of 869578 possible.
# Found 70490 unique shingles, out of 866417 possible.
# Found 70176 unique shingles, out of 877106 possible.
# Found 72740 unique shingles, out of 891931 possible.
# Found 60229 unique shingles, out of 904705 possible.
# Found 63575 unique shingles, out of 910482 possible.
# Found 64596 unique shingles, out of 907309 possible.
# Found 61993 unique shingles, out of 913323 possible.
# Found 63154 unique shingles, out of 886619 possible.
# Found 62858 unique shingles, out of 906803 possible.
# Found 64985 unique shingles, out of 911309 possible.
# Found 61635 unique shingles, out of 902935 possible.
# Found 64984 unique shingles, out of 898793 possible.
# Found 64035 unique shingles, out of 955988 possible.
# Found 62497 unique shingles, out of 865101 possible.
# Found 71179 unique shingles, out of 902894 possible.
# Found 69708 unique shingles, out of 898491 possible.
# Found 69024 unique shingles, out of 902331 possible.
# Found 69314 unique shingles, out of 898693 possible.
# Found 70264 unique shingles, out of 887000 possible.
# Found 69657 unique shingles, out of 883312 possible.
# Found 71911 unique shingles, out of 901626 possible.
# Found 72034 unique shingles, out of 893154 possible.
# Found 69143 unique shingles, out of 891918 possible.
# Found 70181 unique shingles, out of 882857 possible.
# Found 71508 unique shingles, out of 885023 possible.
# Found 69371 unique shingles, out of 901992 possible.
# Found 69130 unique shingles, out of 890032 possible.
# Found 68453 unique shingles, out of 892395 possible.
# Found 68707 unique shingles, out of 887391 possible.
# Found 71404 unique shingles, out of 891501 possible.
# Found 70938 unique shingles, out of 895496 possible.
# Found 70919 unique shingles, out of 894078 possible.
# Found 66918 unique shingles, out of 894796 possible.
# Found 70519 unique shingles, out of 873838 possible.
# Found 70163 unique shingles, out of 895078 possible.
# Found 69152 unique shingles, out of 883142 possible.
# Found 70849 unique shingles, out of 884743 possible.
# Found 69161 unique shingles, out of 894219 possible.
# Found 68651 unique shingles, out of 891909 possible.
# Found 66073 unique shingles, out of 902830 possible.
# Found 67090 unique shingles, out of 902206 possible.
# Found 69323 unique shingles, out of 905977 possible.
# Found 67411 unique shingles, out of 898250 possible.
# Found 63841 unique shingles, out of 886909 possible.
# Found 73013 unique shingles, out of 910136 possible.
# Found 66169 unique shingles, out of 899235 possible.
# Found 68466 unique shingles, out of 900747 possible.
# Found 65734 unique shingles, out of 899587 possible.
# Found 66382 unique shingles, out of 878996 possible.
# Found 68430 unique shingles, out of 889645 possible.
# Found 68452 unique shingles, out of 880472 possible.
# Found 68219 unique shingles, out of 877568 possible.
# Found 67851 unique shingles, out of 884753 possible.
# Found 69907 unique shingles, out of 884522 possible.
# Found 71474 unique shingles, out of 871467 possible.
# Found 74107 unique shingles, out of 883553 possible.
# Found 72804 unique shingles, out of 883899 possible.
# Found 75375 unique shingles, out of 891972 possible.
# Found 75784 unique shingles, out of 889005 possible.
# Found 75935 unique shingles, out of 893447 possible.
# Found 77262 unique shingles, out of 893372 possible.
# Found 73358 unique shingles, out of 878338 possible.
# Found 72289 unique shingles, out of 900603 possible.
# Found 67230 unique shingles, out of 681644 possible.
# Found 65410 unique shingles, out of 937247 possible.
# Found 62046 unique shingles, out of 924442 possible.
# Found 76434 unique shingles, out of 911592 possible.
# Found 62657 unique shingles, out of 907128 possible.
# Found 74390 unique shingles, out of 874550 possible.
# Found 73856 unique shingles, out of 905980 possible.
# Found 70689 unique shingles, out of 901259 possible.
# Found 76311 unique shingles, out of 928596 possible.
# Found 77037 unique shingles, out of 884543 possible.
# Found 77926 unique shingles, out of 844456 possible.
# Found 79067 unique shingles, out of 901527 possible.
# Found 78858 unique shingles, out of 888432 possible.
# Found 78662 unique shingles, out of 898677 possible.
# Found 77239 unique shingles, out of 860027 possible.
# Found 80951 unique shingles, out of 1058226 possible.
# Found 67927 unique shingles, out of 904551 possible.
# Found 73439 unique shingles, out of 908028 possible.
# Found 74736 unique shingles, out of 919019 possible.
# Found 69831 unique shingles, out of 893920 possible.
# Found 73329 unique shingles, out of 901674 possible.
# Found 70898 unique shingles, out of 908690 possible.
# Found 70592 unique shingles, out of 897021 possible.
# Found 48341 unique shingles, out of 312342 possible.
# Found 74668 unique shingles, out of 903083 possible.
# Found 75537 unique shingles, out of 916010 possible.
# Found 81211 unique shingles, out of 917134 possible.
# Found 70974 unique shingles, out of 878489 possible.
# Found 70528 unique shingles, out of 876303 possible.
# Found 72073 unique shingles, out of 877528 possible.
# Found 64754 unique shingles, out of 911944 possible.
# Found 65144 unique shingles, out of 903975 possible.
# Found 62588 unique shingles, out of 920757 possible.
# Found 63090 unique shingles, out of 918570 possible.
# Found 63777 unique shingles, out of 919542 possible.
# Found 63447 unique shingles, out of 911737 possible.
# Found 64963 unique shingles, out of 898983 possible.
# Found 69324 unique shingles, out of 897694 possible.
# Found 65435 unique shingles, out of 853467 possible.
# Found 66967 unique shingles, out of 901437 possible.
# Found 70487 unique shingles, out of 890190 possible.
# Found 68843 unique shingles, out of 890417 possible.
# Found 66179 unique shingles, out of 897946 possible.
# Found 68993 unique shingles, out of 889498 possible.
# Found 70286 unique shingles, out of 890549 possible.
# Found 72284 unique shingles, out of 899351 possible.
# Found 68244 unique shingles, out of 874458 possible.
# Found 66539 unique shingles, out of 897737 possible.
# Found 68366 unique shingles, out of 901992 possible.
# Found 67472 unique shingles, out of 892616 possible.
# Found 73278 unique shingles, out of 885675 possible.
# Found 69116 unique shingles, out of 887868 possible.
# Found 68469 unique shingles, out of 873553 possible.
# Found 67685 unique shingles, out of 887830 possible.
# Found 68825 unique shingles, out of 892190 possible.
# Found 70266 unique shingles, out of 881238 possible.
# Found 71219 unique shingles, out of 872300 possible.
# Found 69902 unique shingles, out of 901439 possible.
# Found 68394 unique shingles, out of 903563 possible.
# Found 69565 unique shingles, out of 917161 possible.
# Found 69823 unique shingles, out of 921779 possible.
# Found 65612 unique shingles, out of 838125 possible.
# Found 70744 unique shingles, out of 889491 possible.
# Found 73839 unique shingles, out of 898013 possible.
# Found 67124 unique shingles, out of 892099 possible.
# Found 68121 unique shingles, out of 887706 possible.
# Found 67180 unique shingles, out of 875708 possible.
# Found 68753 unique shingles, out of 889913 possible.
# Found 70714 unique shingles, out of 1046569 possible.
# Found 75516 unique shingles, out of 886249 possible.
# Found 77722 unique shingles, out of 886472 possible.
# Found 66626 unique shingles, out of 743118 possible.
# Found 72981 unique shingles, out of 895566 possible.
# Found 73826 unique shingles, out of 895337 possible.
# Found 34133 unique shingles, out of 166533 possible.
# Found 73900 unique shingles, out of 893458 possible.
# Found 73694 unique shingles, out of 894270 possible.
# Found 61386 unique shingles, out of 929612 possible.
# Found 72094 unique shingles, out of 942184 possible.
# Found 77061 unique shingles, out of 922013 possible.
# Found 72084 unique shingles, out of 939685 possible.
# Found 59221 unique shingles, out of 774925 possible.
# Found 71259 unique shingles, out of 934349 possible.
# Found 75678 unique shingles, out of 933242 possible.
# Found 73551 unique shingles, out of 907786 possible.
# Found 80481 unique shingles, out of 886299 possible.
# Found 88055 unique shingles, out of 1349432 possible.
# Found 77425 unique shingles, out of 923867 possible.
# Found 74100 unique shingles, out of 897545 possible.
# Found 37574 unique shingles, out of 242389 possible.
# Found 62387 unique shingles, out of 822117 possible.
# Found 82458 unique shingles, out of 1479616 possible.
# Found 71155 unique shingles, out of 901722 possible.
# Found 75628 unique shingles, out of 964183 possible.
# Found 69233 unique shingles, out of 950288 possible.
# Found 73689 unique shingles, out of 928094 possible.
# Found 69804 unique shingles, out of 826331 possible.
# Found 61828 unique shingles, out of 878647 possible.
# Found 54924 unique shingles, out of 510061 possible.
# Found 60749 unique shingles, out of 496659 possible.
# Found 80978 unique shingles, out of 943455 possible.
# Found 84375 unique shingles, out of 1058141 possible.
# Found 70895 unique shingles, out of 883856 possible.
# Found 68674 unique shingles, out of 877893 possible.
# Found 71826 unique shingles, out of 888211 possible.
# Found 63849 unique shingles, out of 924475 possible.
# Found 60462 unique shingles, out of 898239 possible.
# Found 62386 unique shingles, out of 900924 possible.
# Found 62075 unique shingles, out of 906387 possible.
# Found 61518 unique shingles, out of 910658 possible.
# Found 63407 unique shingles, out of 908021 possible.
# Found 61659 unique shingles, out of 901306 possible.
# Found 62361 unique shingles, out of 922171 possible.
# Found 70464 unique shingles, out of 922092 possible.
# Found 70756 unique shingles, out of 902935 possible.
# Found 69728 unique shingles, out of 893555 possible.
# Found 69541 unique shingles, out of 894786 possible.
# Found 70032 unique shingles, out of 889207 possible.
# Found 71178 unique shingles, out of 909473 possible.
# Found 71940 unique shingles, out of 900948 possible.
# Found 71983 unique shingles, out of 897320 possible.
# Found 71577 unique shingles, out of 878153 possible.
# Found 67957 unique shingles, out of 891838 possible.
# Found 65660 unique shingles, out of 891672 possible.
# Found 67853 unique shingles, out of 894377 possible.
# Found 69127 unique shingles, out of 902815 possible.
# Found 71604 unique shingles, out of 887514 possible.
# Found 69884 unique shingles, out of 887368 possible.
# Found 70119 unique shingles, out of 902552 possible.
# Found 68496 unique shingles, out of 886963 possible.
# Found 69583 unique shingles, out of 882248 possible.
# Found 70551 unique shingles, out of 860796 possible.
# Found 67439 unique shingles, out of 891380 possible.
# Found 68201 unique shingles, out of 889385 possible.
# Found 68148 unique shingles, out of 889077 possible.
# Found 66678 unique shingles, out of 890442 possible.
# Found 61997 unique shingles, out of 882858 possible.
# Found 66971 unique shingles, out of 894645 possible.
# Found 64585 unique shingles, out of 910265 possible.
# Found 69621 unique shingles, out of 899728 possible.
# Found 70977 unique shingles, out of 884237 possible.
# Found 69097 unique shingles, out of 886759 possible.
# Found 68286 unique shingles, out of 891532 possible.
# Found 68256 unique shingles, out of 895115 possible.
# Found 65088 unique shingles, out of 885422 possible.
# Found 66840 unique shingles, out of 887426 possible.
# Found 68731 unique shingles, out of 891763 possible.
# Found 72653 unique shingles, out of 907169 possible.
# Found 72067 unique shingles, out of 885075 possible.
# Found 74506 unique shingles, out of 899273 possible.
# Found 72436 unique shingles, out of 863677 possible.
# Found 73145 unique shingles, out of 898629 possible.
# Found 16894 unique shingles, out of 49043 possible.
# Found 76877 unique shingles, out of 887720 possible.
# Found 63137 unique shingles, out of 947969 possible.
# Found 67476 unique shingles, out of 932778 possible.
# Found 79167 unique shingles, out of 922243 possible.
# Found 70834 unique shingles, out of 868404 possible.
# Found 52941 unique shingles, out of 766107 possible.
# Found 79129 unique shingles, out of 926183 possible.
# Found 81854 unique shingles, out of 886740 possible.
# Found 78514 unique shingles, out of 995851 possible.
# Found 76875 unique shingles, out of 877772 possible.
# Found 75271 unique shingles, out of 753915 possible.
# Found 74701 unique shingles, out of 950117 possible.
# Found 70907 unique shingles, out of 915904 possible.
# Found 71567 unique shingles, out of 892308 possible.
# Found 58359 unique shingles, out of 947086 possible.
# Found 43861 unique shingles, out of 399607 possible.
# Found 73910 unique shingles, out of 854347 possible.
# Found 35021 unique shingles, out of 162059 possible.
# Found 82951 unique shingles, out of 960490 possible.
# Found 68689 unique shingles, out of 875376 possible.
# Found 69092 unique shingles, out of 862797 possible.
# Found 68055 unique shingles, out of 878173 possible.
# Found 84607 unique shingles, out of 866015 possible.
# Found 85247 unique shingles, out of 889083 possible.
# Found 64374 unique shingles, out of 966788 possible.
# Found 58086 unique shingles, out of 927597 possible.
# Found 56237 unique shingles, out of 997768 possible.
# Found 60703 unique shingles, out of 899682 possible.
# Found 57228 unique shingles, out of 757891 possible.
# Found 64659 unique shingles, out of 892155 possible.
# Found 64885 unique shingles, out of 880427 possible.
# Found 64925 unique shingles, out of 885130 possible.
# Found 64262 unique shingles, out of 888998 possible.
# Found 65298 unique shingles, out of 881063 possible.
# Found 66084 unique shingles, out of 929933 possible.
# Found 71777 unique shingles, out of 897557 possible.
# Found 70772 unique shingles, out of 883103 possible.
# Found 69635 unique shingles, out of 891120 possible.
# Found 66637 unique shingles, out of 860436 possible.
# Found 70799 unique shingles, out of 884231 possible.
# Found 69643 unique shingles, out of 875675 possible.
# Found 70228 unique shingles, out of 880573 possible.
# Found 68797 unique shingles, out of 880682 possible.
# Found 69895 unique shingles, out of 886954 possible.
# Found 72853 unique shingles, out of 892486 possible.
# Found 71248 unique shingles, out of 890514 possible.
# Found 71921 unique shingles, out of 889673 possible.
# Found 68622 unique shingles, out of 882426 possible.
# Found 71319 unique shingles, out of 888345 possible.
# Found 68619 unique shingles, out of 886238 possible.
# Found 71107 unique shingles, out of 898781 possible.
# Found 70737 unique shingles, out of 899651 possible.
# Found 74670 unique shingles, out of 894035 possible.
# Found 69136 unique shingles, out of 873258 possible.
# Found 68839 unique shingles, out of 884069 possible.
# Found 69743 unique shingles, out of 881421 possible.
# Found 70326 unique shingles, out of 889360 possible.
# Found 69847 unique shingles, out of 879381 possible.
# Found 67264 unique shingles, out of 871306 possible.
# Found 70092 unique shingles, out of 888335 possible.
# Found 65222 unique shingles, out of 879018 possible.
# Found 66463 unique shingles, out of 876285 possible.
# Found 68396 unique shingles, out of 884548 possible.
# Found 68328 unique shingles, out of 883318 possible.
# Found 67895 unique shingles, out of 888770 possible.
# Found 68882 unique shingles, out of 881882 possible.
# Found 65107 unique shingles, out of 871476 possible.
# Found 70303 unique shingles, out of 865844 possible.
# Found 69811 unique shingles, out of 867754 possible.
# Found 68756 unique shingles, out of 872411 possible.
# Found 69652 unique shingles, out of 869271 possible.
# Found 70193 unique shingles, out of 875110 possible.
# Found 68583 unique shingles, out of 882451 possible.
# Found 69038 unique shingles, out of 862749 possible.
# Found 66949 unique shingles, out of 874777 possible.
# Found 66709 unique shingles, out of 873042 possible.
# Found 73777 unique shingles, out of 880124 possible.
# Found 75286 unique shingles, out of 886365 possible.
# Found 70707 unique shingles, out of 873115 possible.
# Found 70891 unique shingles, out of 877716 possible.
# Found 74735 unique shingles, out of 879319 possible.
# Found 74889 unique shingles, out of 889789 possible.
# Found 73172 unique shingles, out of 881488 possible.
# Found 70332 unique shingles, out of 807114 possible.
# Found 61892 unique shingles, out of 904218 possible.
# Found 66149 unique shingles, out of 1105623 possible.
# Found 69524 unique shingles, out of 897551 possible.
# Found 74811 unique shingles, out of 891733 possible.
# Found 64531 unique shingles, out of 665431 possible.
# Found 73784 unique shingles, out of 903286 possible.
# Found 76385 unique shingles, out of 878161 possible.
# Found 78762 unique shingles, out of 880754 possible.
# Found 78235 unique shingles, out of 875968 possible.
# Found 76882 unique shingles, out of 862901 possible.
# Found 71011 unique shingles, out of 925086 possible.
# Found 71843 unique shingles, out of 892507 possible.
# Found 73668 unique shingles, out of 902968 possible.
# Found 72014 unique shingles, out of 918070 possible.
# Found 65246 unique shingles, out of 862788 possible.
# Found 72575 unique shingles, out of 919269 possible.
# Found 79723 unique shingles, out of 900920 possible.
# Found 71283 unique shingles, out of 761104 possible.
# Found 81165 unique shingles, out of 946173 possible.
# Found 71010 unique shingles, out of 868327 possible.
# Found 68474 unique shingles, out of 871194 possible.
# Found 70435 unique shingles, out of 870422 possible.
# Found 69806 unique shingles, out of 884125 possible.
# Found 63840 unique shingles, out of 884698 possible.
# Found 65481 unique shingles, out of 903357 possible.
# Found 65406 unique shingles, out of 910389 possible.
# Found 61880 unique shingles, out of 920708 possible.
# Found 64791 unique shingles, out of 902468 possible.
# Found 62039 unique shingles, out of 882379 possible.
# Found 65859 unique shingles, out of 914452 possible.
# Found 61880 unique shingles, out of 892068 possible.
# Found 61176 unique shingles, out of 862508 possible.
# Found 63036 unique shingles, out of 929254 possible.
# Found 67251 unique shingles, out of 831158 possible.
# Found 72041 unique shingles, out of 904693 possible.
# Found 69095 unique shingles, out of 891198 possible.
# Found 69943 unique shingles, out of 880820 possible.
# Found 68546 unique shingles, out of 882953 possible.
# Found 68467 unique shingles, out of 869120 possible.
# Found 66304 unique shingles, out of 893732 possible.
# Found 69423 unique shingles, out of 882018 possible.
# Found 69906 unique shingles, out of 867036 possible.
# Found 68179 unique shingles, out of 886907 possible.
# Found 70362 unique shingles, out of 875001 possible.
# Found 70152 unique shingles, out of 886671 possible.
# Found 72627 unique shingles, out of 900600 possible.
# Found 72094 unique shingles, out of 901687 possible.
# Found 71667 unique shingles, out of 894739 possible.
# Found 70706 unique shingles, out of 892762 possible.
# Found 71544 unique shingles, out of 890642 possible.
# Found 73211 unique shingles, out of 907745 possible.
# Found 70877 unique shingles, out of 896359 possible.
# Found 68973 unique shingles, out of 878223 possible.
# Found 69187 unique shingles, out of 841042 possible.
# Found 67181 unique shingles, out of 882231 possible.
# Found 67477 unique shingles, out of 884502 possible.
# Found 67155 unique shingles, out of 888138 possible.
# Found 66082 unique shingles, out of 876300 possible.
# Found 69241 unique shingles, out of 880544 possible.
# Found 67542 unique shingles, out of 865329 possible.
# Found 65337 unique shingles, out of 884834 possible.
# Found 66508 unique shingles, out of 871429 possible.
# Found 68202 unique shingles, out of 896128 possible.
# Found 65664 unique shingles, out of 859885 possible.
# Found 66944 unique shingles, out of 901566 possible.
# Found 68971 unique shingles, out of 885101 possible.
# Found 67897 unique shingles, out of 879842 possible.
# Found 65547 unique shingles, out of 881452 possible.
# Found 70832 unique shingles, out of 848611 possible.
# Found 69914 unique shingles, out of 870962 possible.
# Found 68416 unique shingles, out of 879903 possible.
# Found 69677 unique shingles, out of 879172 possible.
# Found 66054 unique shingles, out of 873297 possible.
# Found 68448 unique shingles, out of 872905 possible.
# Found 69837 unique shingles, out of 876727 possible.
# Found 70159 unique shingles, out of 872170 possible.
# Found 68067 unique shingles, out of 875413 possible.
# Found 67119 unique shingles, out of 863058 possible.
# Found 72704 unique shingles, out of 879567 possible.
# Found 76116 unique shingles, out of 889851 possible.
# Found 76474 unique shingles, out of 899270 possible.
# Found 74197 unique shingles, out of 885402 possible.
# Found 72662 unique shingles, out of 886761 possible.
# Found 72079 unique shingles, out of 857783 possible.
# Found 75893 unique shingles, out of 886634 possible.
# Found 70705 unique shingles, out of 880493 possible.
# Found 67286 unique shingles, out of 695842 possible.
# Found 63055 unique shingles, out of 946428 possible.
# Found 67691 unique shingles, out of 882562 possible.
# Found 76691 unique shingles, out of 883665 possible.
# Found 35629 unique shingles, out of 401874 possible.
# Found 64846 unique shingles, out of 972269 possible.
# Found 74194 unique shingles, out of 923475 possible.
# Found 79061 unique shingles, out of 900096 possible.
# Found 79528 unique shingles, out of 879162 possible.
# Found 77144 unique shingles, out of 890546 possible.
# Found 75731 unique shingles, out of 857459 possible.
# Found 83734 unique shingles, out of 1236865 possible.
# Found 68861 unique shingles, out of 914319 possible.
# Found 69084 unique shingles, out of 829165 possible.
# Found 74291 unique shingles, out of 1639356 possible.
# Found 70543 unique shingles, out of 872388 possible.
# Found 70856 unique shingles, out of 912374 possible.
# Found 71195 unique shingles, out of 934650 possible.
# Found 70622 unique shingles, out of 907065 possible.
# Found 47234 unique shingles, out of 281867 possible.
# Found 67067 unique shingles, out of 899875 possible.
# Found 79608 unique shingles, out of 886317 possible.
# Found 80330 unique shingles, out of 813999 possible.
# Found 67995 unique shingles, out of 844764 possible.
# Found 73402 unique shingles, out of 855155 possible.
# Found 70405 unique shingles, out of 866798 possible.
# Found 66860 unique shingles, out of 919413 possible.
# Found 63383 unique shingles, out of 889531 possible.
# Found 63371 unique shingles, out of 898783 possible.
# Found 62251 unique shingles, out of 913443 possible.
# Found 62669 unique shingles, out of 898447 possible.
# Found 63532 unique shingles, out of 911107 possible.
# Found 63296 unique shingles, out of 887430 possible.
# Found 65690 unique shingles, out of 949674 possible.
# Found 63322 unique shingles, out of 906838 possible.
# Found 62949 unique shingles, out of 927779 possible.
# Found 71088 unique shingles, out of 883093 possible.
# Found 69708 unique shingles, out of 831302 possible.
# Found 71785 unique shingles, out of 886956 possible.
# Found 72874 unique shingles, out of 890604 possible.
# Found 71221 unique shingles, out of 899836 possible.
# Found 73844 unique shingles, out of 885743 possible.
# Found 71111 unique shingles, out of 872274 possible.
# Found 70613 unique shingles, out of 894063 possible.
# Found 69742 unique shingles, out of 890045 possible.
# Found 71346 unique shingles, out of 896570 possible.
# Found 72338 unique shingles, out of 904751 possible.
# Found 70265 unique shingles, out of 876840 possible.
# Found 70058 unique shingles, out of 887192 possible.
# Found 68229 unique shingles, out of 889683 possible.
# Found 71212 unique shingles, out of 882754 possible.
# Found 71494 unique shingles, out of 890097 possible.
# Found 71822 unique shingles, out of 889465 possible.
# Found 70051 unique shingles, out of 884566 possible.
# Found 67236 unique shingles, out of 880323 possible.
# Found 68732 unique shingles, out of 884729 possible.
# Found 68681 unique shingles, out of 884215 possible.
# Found 69086 unique shingles, out of 886242 possible.
# Found 68664 unique shingles, out of 897708 possible.
# Found 68451 unique shingles, out of 896897 possible.
# Found 64204 unique shingles, out of 907923 possible.
# Found 62880 unique shingles, out of 877303 possible.
# Found 66839 unique shingles, out of 864217 possible.
# Found 64123 unique shingles, out of 882071 possible.
# Found 67599 unique shingles, out of 876391 possible.
# Found 67496 unique shingles, out of 892696 possible.
# Found 68426 unique shingles, out of 877373 possible.
# Found 69865 unique shingles, out of 870812 possible.
# Found 69793 unique shingles, out of 872533 possible.
# Found 68310 unique shingles, out of 865030 possible.
# Found 68431 unique shingles, out of 880244 possible.
# Found 68002 unique shingles, out of 867228 possible.
# Found 66630 unique shingles, out of 865605 possible.
# Found 66426 unique shingles, out of 865782 possible.
# Found 67362 unique shingles, out of 875944 possible.
# Found 71811 unique shingles, out of 871390 possible.
# Found 75002 unique shingles, out of 884487 possible.
# Found 73802 unique shingles, out of 885351 possible.
# Found 74585 unique shingles, out of 891119 possible.
# Found 75202 unique shingles, out of 887788 possible.
# Found 73239 unique shingles, out of 887421 possible.
# Found 74092 unique shingles, out of 885182 possible.
# Found 60272 unique shingles, out of 596053 possible.
# Found 67822 unique shingles, out of 942246 possible.
# Found 64492 unique shingles, out of 938183 possible.
# Found 60052 unique shingles, out of 904750 possible.
# Found 60477 unique shingles, out of 922036 possible.
# Found 76879 unique shingles, out of 870875 possible.
# Found 77617 unique shingles, out of 936617 possible.
# Found 74333 unique shingles, out of 920709 possible.
# Found 81320 unique shingles, out of 894070 possible.
# Found 80389 unique shingles, out of 891901 possible.
# Found 70598 unique shingles, out of 727017 possible.
# Found 77936 unique shingles, out of 885278 possible.
# Found 70106 unique shingles, out of 723411 possible.
# Found 61340 unique shingles, out of 877596 possible.
# Found 74572 unique shingles, out of 938052 possible.
# Found 67728 unique shingles, out of 750071 possible.
# Found 67237 unique shingles, out of 918624 possible.
# Found 72816 unique shingles, out of 917127 possible.
# Found 73167 unique shingles, out of 880577 possible.
# Found 557 unique shingles, out of 743 possible.
# Found 72129 unique shingles, out of 913151 possible.
# Found 1883 unique shingles, out of 2876 possible.
# Found 79639 unique shingles, out of 1312590 possible.
# Found 1790 unique shingles, out of 3434 possible.
# Found 1775 unique shingles, out of 2565 possible.
# Found 36125 unique shingles, out of 563019 possible.
# Found 23444 unique shingles, out of 208004 possible.
# Found 29453 unique shingles, out of 487124 possible.
# Found 46105 unique shingles, out of 735107 possible.
# Found 38884 unique shingles, out of 511684 possible.
# Found 23908 unique shingles, out of 165757 possible.
# Found 45037 unique shingles, out of 543012 possible.
# Found 16896 unique shingles, out of 102844 possible.
# Found 41040 unique shingles, out of 455693 possible.
# Found 40390 unique shingles, out of 376443 possible.
# Found 40522 unique shingles, out of 575193 possible.
# Found 33539 unique shingles, out of 389049 possible.
# Found 50280 unique shingles, out of 742869 possible.
# Found 17183 unique shingles, out of 98841 possible.
# Found 25274 unique shingles, out of 230918 possible.
# Found 32492 unique shingles, out of 707368 possible.
# Found 40659 unique shingles, out of 430187 possible.
# Found 43631 unique shingles, out of 477995 possible.
# Found 28691 unique shingles, out of 259015 possible.
# Found 23822 unique shingles, out of 225624 possible.
# Found 45807 unique shingles, out of 805424 possible.
# Found 52317 unique shingles, out of 789416 possible.
# Found 33491 unique shingles, out of 469205 possible.
# Found 23236 unique shingles, out of 163590 possible.
# Found 43014 unique shingles, out of 551846 possible.
# Found 24258 unique shingles, out of 198197 possible.
# Found 31204 unique shingles, out of 478258 possible.
# Found 43409 unique shingles, out of 547177 possible.
# Found 32644 unique shingles, out of 369170 possible.
# Found 53903 unique shingles, out of 687566 possible.
# Found 27522 unique shingles, out of 266267 possible.
# Found 21253 unique shingles, out of 159719 possible.
# Found 39715 unique shingles, out of 402020 possible.
# Found 29046 unique shingles, out of 308966 possible.
# Found 28260 unique shingles, out of 294132 possible.
# Found 40649 unique shingles, out of 414911 possible.
# Found 52034 unique shingles, out of 873696 possible.
# Found 22827 unique shingles, out of 191677 possible.
# Found 44655 unique shingles, out of 451189 possible.
# Found 24848 unique shingles, out of 183401 possible.
# Found 32959 unique shingles, out of 392904 possible.
# Found 20012 unique shingles, out of 142270 possible.
# Found 47752 unique shingles, out of 533914 possible.
# Found 26157 unique shingles, out of 251777 possible.
# Found 23081 unique shingles, out of 205436 possible.
# Found 29053 unique shingles, out of 491142 possible.
# Found 42812 unique shingles, out of 531591 possible.
# Found 20527 unique shingles, out of 150553 possible.
# Found 20620 unique shingles, out of 188420 possible.
# Found 61187 unique shingles, out of 846237 possible.
# Found 40182 unique shingles, out of 410577 possible.
# Found 36050 unique shingles, out of 418466 possible.
# Found 14152 unique shingles, out of 59780 possible.
# Found 40124 unique shingles, out of 400016 possible.
# Found 40022 unique shingles, out of 661471 possible.
# Found 41436 unique shingles, out of 535972 possible.
# Found 15554 unique shingles, out of 95658 possible.
# Found 45251 unique shingles, out of 509187 possible.
# Found 33750 unique shingles, out of 258106 possible.
# Found 40462 unique shingles, out of 398821 possible.
# Found 28012 unique shingles, out of 301020 possible.
# Found 23338 unique shingles, out of 238180 possible.
# Found 36152 unique shingles, out of 558510 possible.
# Found 64440 unique shingles, out of 904785 possible.
# Found 45782 unique shingles, out of 553411 possible.
# Found 54189 unique shingles, out of 1387528 possible.
# Found 20954 unique shingles, out of 154138 possible.
# Found 17651 unique shingles, out of 123862 possible.
# Found 48194 unique shingles, out of 509699 possible.
# Found 45626 unique shingles, out of 811994 possible.
# Found 18739 unique shingles, out of 96922 possible.
# Found 45853 unique shingles, out of 966940 possible.
# Found 37253 unique shingles, out of 579182 possible.
# Found 65198 unique shingles, out of 655717 possible.
# Found 37374 unique shingles, out of 398548 possible.
# Found 30911 unique shingles, out of 482576 possible.
# Found 23081 unique shingles, out of 162586 possible.
# Found 33456 unique shingles, out of 364631 possible.
# Found 52957 unique shingles, out of 503919 possible.
# Found 25620 unique shingles, out of 227441 possible.
# Found 30071 unique shingles, out of 255742 possible.
# Found 43685 unique shingles, out of 519394 possible.
# Found 24351 unique shingles, out of 238712 possible.
# Found 49012 unique shingles, out of 677641 possible.
# Found 41103 unique shingles, out of 403943 possible.
# Found 23124 unique shingles, out of 187557 possible.
# Found 53932 unique shingles, out of 1091537 possible.
# Found 25942 unique shingles, out of 231485 possible.
# Found 43939 unique shingles, out of 711475 possible.
# Found 25271 unique shingles, out of 255017 possible.
# Found 46582 unique shingles, out of 756753 possible.
# Found 46085 unique shingles, out of 611037 possible.
# Found 44033 unique shingles, out of 900498 possible.
# Found 43333 unique shingles, out of 528572 possible.
# Found 55097 unique shingles, out of 1261826 possible.
# Found 20649 unique shingles, out of 173044 possible.
# Found 44820 unique shingles, out of 813838 possible.
# Found 42756 unique shingles, out of 572121 possible.
# Found 30962 unique shingles, out of 349249 possible.
# Found 50859 unique shingles, out of 865178 possible.
# Found 24884 unique shingles, out of 175695 possible.
# Found 35023 unique shingles, out of 415723 possible.
# Found 21731 unique shingles, out of 162865 possible.
# Found 40826 unique shingles, out of 432319 possible.
# Found 83696 unique shingles, out of 1786075 possible.
# Found 42645 unique shingles, out of 338970 possible.
# Found 32098 unique shingles, out of 340507 possible.
# Found 28820 unique shingles, out of 277791 possible.
# Found 48309 unique shingles, out of 783871 possible.
# Found 51084 unique shingles, out of 666718 possible.
# Found 32223 unique shingles, out of 322928 possible.
# Found 32898 unique shingles, out of 397429 possible.
# Found 42798 unique shingles, out of 623453 possible.
# Found 51890 unique shingles, out of 725170 possible.
# Found 26129 unique shingles, out of 314435 possible.
# Found 25537 unique shingles, out of 199669 possible.
# Found 44606 unique shingles, out of 588649 possible.
# Found 31277 unique shingles, out of 362702 possible.
# Found 45671 unique shingles, out of 640476 possible.
# Found 43773 unique shingles, out of 463648 possible.
# Found 25017 unique shingles, out of 182201 possible.
# Found 32408 unique shingles, out of 476167 possible.
# Found 42821 unique shingles, out of 515729 possible.
# Found 24013 unique shingles, out of 306252 possible.
# Found 42613 unique shingles, out of 489106 possible.
# Found 73500 unique shingles, out of 1662534 possible.
# Found 26321 unique shingles, out of 231442 possible.
# Found 40877 unique shingles, out of 343459 possible.
# Found 49123 unique shingles, out of 947835 possible.
# Found 31804 unique shingles, out of 340205 possible.
# Found 12653 unique shingles, out of 69125 possible.
# Found 46278 unique shingles, out of 599371 possible.
# Found 42171 unique shingles, out of 531287 possible.
# Found 41017 unique shingles, out of 747451 possible.
# Found 43619 unique shingles, out of 498375 possible.
# Found 26654 unique shingles, out of 238425 possible.
# Found 31279 unique shingles, out of 523007 possible.
# Found 35374 unique shingles, out of 333875 possible.
# Found 22475 unique shingles, out of 175236 possible.
# Found 35126 unique shingles, out of 467128 possible.
# Found 42207 unique shingles, out of 444625 possible.
# Found 42209 unique shingles, out of 528001 possible.
# Found 29534 unique shingles, out of 282119 possible.
# Found 43036 unique shingles, out of 443363 possible.
# Found 42182 unique shingles, out of 644162 possible.
# Found 34695 unique shingles, out of 430510 possible.
# Found 29418 unique shingles, out of 343282 possible.
# Found 32050 unique shingles, out of 345685 possible.
# Found 41021 unique shingles, out of 449164 possible.
# Found 50317 unique shingles, out of 646539 possible.
# Found 31740 unique shingles, out of 361315 possible.
# Found 31470 unique shingles, out of 292890 possible.
# Found 17181 unique shingles, out of 134973 possible.
# Found 47057 unique shingles, out of 621925 possible.
# Found 24341 unique shingles, out of 174751 possible.
# Found 3481 unique shingles, out of 10960 possible.
# Found 26955 unique shingles, out of 458997 possible.
# Found 4083 unique shingles, out of 11059 possible.
# Found 12965 unique shingles, out of 73777 possible.
# Found 10384 unique shingles, out of 44290 possible.
# Found 8192 unique shingles, out of 28511 possible.
# Found 22996 unique shingles, out of 200887 possible.
# Found 49704 unique shingles, out of 480812 possible.
# Found 40062 unique shingles, out of 424260 possible.
# Found 26453 unique shingles, out of 247194 possible.
# Found 45991 unique shingles, out of 653133 possible.
# Found 42921 unique shingles, out of 587265 possible.
# Found 53292 unique shingles, out of 759470 possible.
# Found 32596 unique shingles, out of 273578 possible.
# Found 33394 unique shingles, out of 552215 possible.
# Found 32848 unique shingles, out of 334694 possible.
# Found 43055 unique shingles, out of 621086 possible.
# Found 41131 unique shingles, out of 498593 possible.
# Found 68482 unique shingles, out of 873820 possible.
# Found 32052 unique shingles, out of 280531 possible.
# Found 33542 unique shingles, out of 321296 possible.
# Found 11644 unique shingles, out of 80880 possible.
# Found 29095 unique shingles, out of 305413 possible.
# Found 46093 unique shingles, out of 541142 possible.
# Found 27449 unique shingles, out of 266886 possible.
# Found 36623 unique shingles, out of 458793 possible.
# Found 44476 unique shingles, out of 702003 possible.
# Found 39008 unique shingles, out of 591188 possible.
# Found 23680 unique shingles, out of 205249 possible.
# Found 32235 unique shingles, out of 356120 possible.
# Found 18279 unique shingles, out of 112820 possible.
# Found 31747 unique shingles, out of 298763 possible.
# Found 12737 unique shingles, out of 94678 possible.
# Found 50472 unique shingles, out of 1239425 possible.
# Found 43420 unique shingles, out of 920461 possible.
# Found 39657 unique shingles, out of 401763 possible.
# Found 42141 unique shingles, out of 742859 possible.
# Found 23529 unique shingles, out of 243599 possible.
# Found 23707 unique shingles, out of 218402 possible.
# Found 36042 unique shingles, out of 331485 possible.
# Found 39288 unique shingles, out of 321381 possible.
# Found 30666 unique shingles, out of 333416 possible.
# Found 29089 unique shingles, out of 313476 possible.
# Found 28144 unique shingles, out of 253263 possible.
# Found 54462 unique shingles, out of 931170 possible.
# Found 30838 unique shingles, out of 315577 possible.
# Found 47514 unique shingles, out of 665409 possible.
# Found 43372 unique shingles, out of 462829 possible.
# Found 36793 unique shingles, out of 742325 possible.
# Found 34062 unique shingles, out of 402420 possible.
# Found 25060 unique shingles, out of 234055 possible.
# Found 27290 unique shingles, out of 247744 possible.
# Found 52495 unique shingles, out of 643607 possible.
# Found 49227 unique shingles, out of 595882 possible.
# Found 45741 unique shingles, out of 602219 possible.
# Found 29075 unique shingles, out of 257156 possible.
# Found 51573 unique shingles, out of 969550 possible.
# Found 32649 unique shingles, out of 352271 possible.
# Found 51220 unique shingles, out of 783740 possible.
# Found 43048 unique shingles, out of 520205 possible.
# Found 23724 unique shingles, out of 164796 possible.
# Found 47989 unique shingles, out of 615311 possible.
# Found 36371 unique shingles, out of 433644 possible.
# Found 18729 unique shingles, out of 110280 possible.
# Found 46105 unique shingles, out of 525795 possible.
# Found 31859 unique shingles, out of 382701 possible.
# Found 34504 unique shingles, out of 386106 possible.
# Found 57505 unique shingles, out of 790490 possible.
# Found 35926 unique shingles, out of 487867 possible.
# Found 41884 unique shingles, out of 571743 possible.
# Found 29676 unique shingles, out of 257792 possible.
# Found 24795 unique shingles, out of 175347 possible.
# Found 33825 unique shingles, out of 474133 possible.
# Found 29570 unique shingles, out of 327519 possible.
# Found 45149 unique shingles, out of 534159 possible.
# Found 49299 unique shingles, out of 585973 possible.
# Found 24301 unique shingles, out of 191646 possible.
# Found 23365 unique shingles, out of 152433 possible.
# Found 37583 unique shingles, out of 355036 possible.
# Found 30619 unique shingles, out of 397319 possible.
# Found 30004 unique shingles, out of 297210 possible.
# Found 43646 unique shingles, out of 492697 possible.
# Found 23588 unique shingles, out of 232492 possible.
# Found 42966 unique shingles, out of 716946 possible.
# Found 11198 unique shingles, out of 56543 possible.
# Found 48764 unique shingles, out of 713207 possible.
# Found 45951 unique shingles, out of 460537 possible.
# Found 46929 unique shingles, out of 1835179 possible.
# Found 19924 unique shingles, out of 132605 possible.
# Found 20043 unique shingles, out of 135322 possible.
# Found 43972 unique shingles, out of 551346 possible.
# Found 24163 unique shingles, out of 224131 possible.
# Found 27652 unique shingles, out of 314142 possible.
# Found 54245 unique shingles, out of 727147 possible.
# Found 41851 unique shingles, out of 520024 possible.
# Found 41581 unique shingles, out of 743762 possible.
# Found 48462 unique shingles, out of 624626 possible.
# Found 26149 unique shingles, out of 271895 possible.
# Found 33930 unique shingles, out of 461267 possible.
# Found 29171 unique shingles, out of 277441 possible.
# Found 42167 unique shingles, out of 491525 possible.
# Found 42311 unique shingles, out of 453390 possible.
# Found 23682 unique shingles, out of 190819 possible.
# Found 50180 unique shingles, out of 979459 possible.
# Found 24379 unique shingles, out of 286543 possible.
# Found 54818 unique shingles, out of 1178596 possible.
# Found 38755 unique shingles, out of 532162 possible.
# Found 57830 unique shingles, out of 811621 possible.
# Found 27535 unique shingles, out of 208659 possible.
# Found 44867 unique shingles, out of 498735 possible.
# Found 29848 unique shingles, out of 284877 possible.
# Found 33409 unique shingles, out of 446930 possible.
# Found 50910 unique shingles, out of 684409 possible.
# Found 31987 unique shingles, out of 439856 possible.
# Found 53295 unique shingles, out of 780323 possible.
# Found 32248 unique shingles, out of 249295 possible.
# Found 27732 unique shingles, out of 240860 possible.
# Found 43595 unique shingles, out of 513331 possible.
# Found 30808 unique shingles, out of 366520 possible.
# Found 30824 unique shingles, out of 392969 possible.
# Found 30832 unique shingles, out of 291402 possible.
# Found 49766 unique shingles, out of 589300 possible.
# Found 27834 unique shingles, out of 306475 possible.
# Found 34818 unique shingles, out of 277804 possible.
# Found 32299 unique shingles, out of 350941 possible.
# Found 24074 unique shingles, out of 188750 possible.
# Found 28772 unique shingles, out of 327443 possible.
# Found 43416 unique shingles, out of 438701 possible.
# Found 45721 unique shingles, out of 543073 possible.
# Found 31076 unique shingles, out of 362790 possible.
# Found 39751 unique shingles, out of 540733 possible.
# Found 27259 unique shingles, out of 249338 possible.
# Found 53709 unique shingles, out of 716788 possible.
# Found 28883 unique shingles, out of 450274 possible.
# Found 68833 unique shingles, out of 2447802 possible.
# Found 56004 unique shingles, out of 799749 possible.
# Found 38527 unique shingles, out of 490664 possible.
# Found 48221 unique shingles, out of 846463 possible.
# Found 34873 unique shingles, out of 415383 possible.
# Found 67365 unique shingles, out of 1120621 possible.
# Found 41300 unique shingles, out of 596833 possible.
# Found 14791 unique shingles, out of 86793 possible.
# Found 28785 unique shingles, out of 320237 possible.
# Found 44304 unique shingles, out of 547870 possible.
# Found 46705 unique shingles, out of 487117 possible.
# Found 24437 unique shingles, out of 209106 possible.
# Found 32606 unique shingles, out of 383201 possible.
# Found 41900 unique shingles, out of 506257 possible.
# Found 35151 unique shingles, out of 388363 possible.
# Found 31409 unique shingles, out of 535477 possible.
# Found 16969 unique shingles, out of 107447 possible.
# Found 22038 unique shingles, out of 208654 possible.
# Found 52758 unique shingles, out of 827118 possible.
# Found 50369 unique shingles, out of 604508 possible.
# Found 54009 unique shingles, out of 769357 possible.
# Found 58621 unique shingles, out of 828534 possible.
# Found 54875 unique shingles, out of 1251280 possible.
# Found 23998 unique shingles, out of 183405 possible.
# Found 50727 unique shingles, out of 856067 possible.
# Found 45708 unique shingles, out of 698632 possible.
# Found 48728 unique shingles, out of 723163 possible.
# Found 33080 unique shingles, out of 1021604 possible.
# Found 23739 unique shingles, out of 290646 possible.
# Found 32655 unique shingles, out of 411026 possible.
# Found 50142 unique shingles, out of 635109 possible.
# Found 34257 unique shingles, out of 330988 possible.
# Found 31261 unique shingles, out of 417813 possible.
# Found 18952 unique shingles, out of 156654 possible.
# Found 44829 unique shingles, out of 518832 possible.
# Found 32070 unique shingles, out of 407280 possible.
# Found 27795 unique shingles, out of 299628 possible.
# Found 43438 unique shingles, out of 685495 possible.
# Found 26864 unique shingles, out of 488853 possible.
# Found 56033 unique shingles, out of 954848 possible.
# Found 40219 unique shingles, out of 415629 possible.
# Found 19886 unique shingles, out of 143436 possible.
# Found 38345 unique shingles, out of 624447 possible.
# Found 45563 unique shingles, out of 556840 possible.
# Found 39178 unique shingles, out of 487214 possible.
# Found 49898 unique shingles, out of 990299 possible.
# Found 29758 unique shingles, out of 507918 possible.
# Found 58873 unique shingles, out of 873103 possible.
# Found 49858 unique shingles, out of 934071 possible.
# Found 45005 unique shingles, out of 450619 possible.
# Found 27597 unique shingles, out of 279267 possible.
# Found 20962 unique shingles, out of 124170 possible.
# Found 46687 unique shingles, out of 458789 possible.
# Found 31848 unique shingles, out of 419749 possible.
# Found 33336 unique shingles, out of 424131 possible.
# Found 19538 unique shingles, out of 98740 possible.
# Found 42838 unique shingles, out of 521111 possible.
# Found 33362 unique shingles, out of 403903 possible.
# Found 47252 unique shingles, out of 586266 possible.
# Found 35641 unique shingles, out of 487136 possible.
# Found 56837 unique shingles, out of 1170127 possible.
# Found 41733 unique shingles, out of 399795 possible.
# Found 27339 unique shingles, out of 256539 possible.
# Found 41160 unique shingles, out of 622880 possible.
# Found 51238 unique shingles, out of 647579 possible.
# Found 29173 unique shingles, out of 288155 possible.
# Found 15878 unique shingles, out of 94476 possible.
# Found 8484 unique shingles, out of 33379 possible.
# Found 32517 unique shingles, out of 414356 possible.
# Found 15949 unique shingles, out of 84973 possible.
# Found 52065 unique shingles, out of 863769 possible.
# Found 18479 unique shingles, out of 162353 possible.
# Found 49174 unique shingles, out of 665673 possible.
# Found 50550 unique shingles, out of 694896 possible.
# Found 28299 unique shingles, out of 273603 possible.
# Found 34746 unique shingles, out of 414666 possible.
# Found 50252 unique shingles, out of 680665 possible.
# Found 20199 unique shingles, out of 120125 possible.
# Found 34240 unique shingles, out of 330023 possible.
# Found 37958 unique shingles, out of 412628 possible.
# Found 23377 unique shingles, out of 174193 possible.
# Found 32793 unique shingles, out of 299341 possible.
# Found 31917 unique shingles, out of 325151 possible.
# Found 56533 unique shingles, out of 729162 possible.
# Found 37316 unique shingles, out of 513794 possible.
# Found 46375 unique shingles, out of 633966 possible.
# Found 27400 unique shingles, out of 214593 possible.
# Found 41148 unique shingles, out of 641622 possible.
# Found 32092 unique shingles, out of 465302 possible.
# Found 35560 unique shingles, out of 421128 possible.
# Found 49486 unique shingles, out of 713782 possible.
# Found 47044 unique shingles, out of 593029 possible.
# Found 42520 unique shingles, out of 756077 possible.
# Found 28883 unique shingles, out of 309322 possible.
# Found 43717 unique shingles, out of 460731 possible.
# Found 31208 unique shingles, out of 352682 possible.
# Found 46562 unique shingles, out of 816811 possible.
# Found 44484 unique shingles, out of 602762 possible.
# Found 29609 unique shingles, out of 304106 possible.
# Found 41978 unique shingles, out of 689602 possible.
# Found 29800 unique shingles, out of 300344 possible.
# Found 43975 unique shingles, out of 512391 possible.
# Found 35037 unique shingles, out of 398968 possible.
# Found 48007 unique shingles, out of 534008 possible.
# Found 18934 unique shingles, out of 95106 possible.
# Found 34681 unique shingles, out of 446652 possible.
# Found 39066 unique shingles, out of 408773 possible.
# Found 40967 unique shingles, out of 581996 possible.
# Found 38975 unique shingles, out of 424512 possible.
# Found 42873 unique shingles, out of 538783 possible.
# Found 32842 unique shingles, out of 293890 possible.
# Found 35526 unique shingles, out of 584831 possible.
# Found 31014 unique shingles, out of 280996 possible.
# Found 51678 unique shingles, out of 676140 possible.
# Found 43475 unique shingles, out of 507332 possible.
# Found 37659 unique shingles, out of 823906 possible.
# Found 33373 unique shingles, out of 367450 possible.
# Found 12724 unique shingles, out of 61733 possible.
# Found 48995 unique shingles, out of 615106 possible.
# Found 29319 unique shingles, out of 299714 possible.
# Found 62933 unique shingles, out of 1528542 possible.
# Found 15800 unique shingles, out of 104411 possible.
# Found 42070 unique shingles, out of 468218 possible.
# Found 32103 unique shingles, out of 442508 possible.
# Found 17643 unique shingles, out of 137668 possible.
# Found 32897 unique shingles, out of 461764 possible.
# Found 38107 unique shingles, out of 397632 possible.
# Found 42545 unique shingles, out of 527828 possible.
# Found 60847 unique shingles, out of 929353 possible.
# Found 30298 unique shingles, out of 370781 possible.
# Found 28025 unique shingles, out of 253087 possible.
# Found 37911 unique shingles, out of 567342 possible.
# Found 46268 unique shingles, out of 523184 possible.
# Found 40813 unique shingles, out of 569386 possible.
# Found 29333 unique shingles, out of 330292 possible.
# Found 76587 unique shingles, out of 1355821 possible.
# Found 46144 unique shingles, out of 639008 possible.
# Found 39841 unique shingles, out of 548051 possible.
# Found 41225 unique shingles, out of 785658 possible.
# Found 50137 unique shingles, out of 605399 possible.
# Found 41687 unique shingles, out of 728421 possible.
# Found 32367 unique shingles, out of 361321 possible.
# Found 51179 unique shingles, out of 718938 possible.
# Found 39293 unique shingles, out of 637308 possible.
# Found 38260 unique shingles, out of 501891 possible.
# Found 51340 unique shingles, out of 626679 possible.
# Found 35666 unique shingles, out of 418185 possible.
# Found 26638 unique shingles, out of 212140 possible.
# Found 64719 unique shingles, out of 902251 possible.
# Found 39791 unique shingles, out of 841289 possible.
# Found 50732 unique shingles, out of 577890 possible.
# Found 44054 unique shingles, out of 712388 possible.
# Found 33209 unique shingles, out of 349856 possible.
# Found 23837 unique shingles, out of 161647 possible.
# Found 42262 unique shingles, out of 509965 possible.
# Found 28688 unique shingles, out of 281480 possible.
# Found 26133 unique shingles, out of 224824 possible.
# Found 43047 unique shingles, out of 480096 possible.
# Found 29238 unique shingles, out of 330438 possible.
# Found 31299 unique shingles, out of 322938 possible.
# Found 31404 unique shingles, out of 396602 possible.
# Found 41820 unique shingles, out of 439160 possible.
# Found 26249 unique shingles, out of 198124 possible.
# Found 36472 unique shingles, out of 357871 possible.
# Found 29135 unique shingles, out of 289671 possible.
# Found 19815 unique shingles, out of 148443 possible.
# Found 39887 unique shingles, out of 419418 possible.
# Found 43683 unique shingles, out of 807017 possible.
# Found 15551 unique shingles, out of 87077 possible.
# Found 46579 unique shingles, out of 738613 possible.
# Found 55255 unique shingles, out of 883444 possible.
# Found 38058 unique shingles, out of 616192 possible.
# Found 46118 unique shingles, out of 559291 possible.
# Found 16797 unique shingles, out of 97847 possible.
# Found 34020 unique shingles, out of 534158 possible.
# Found 37686 unique shingles, out of 340835 possible.
# Found 25522 unique shingles, out of 210163 possible.
# Found 35387 unique shingles, out of 452865 possible.
# Found 26549 unique shingles, out of 201473 possible.
# Found 38728 unique shingles, out of 383703 possible.
# Found 48898 unique shingles, out of 591038 possible.
# Found 35465 unique shingles, out of 327783 possible.
# Found 15943 unique shingles, out of 107967 possible.
# Found 44548 unique shingles, out of 668230 possible.
# Found 42148 unique shingles, out of 374094 possible.
# Found 30111 unique shingles, out of 288815 possible.
# Found 30182 unique shingles, out of 241699 possible.
# Found 43973 unique shingles, out of 548244 possible.
# Found 33532 unique shingles, out of 329563 possible.
# Found 61308 unique shingles, out of 990188 possible.
# Found 56759 unique shingles, out of 857201 possible.
# Found 364 unique shingles, out of 619 possible.
# Found 157 unique shingles, out of 220 possible.
# Found 254 unique shingles, out of 636 possible.
# Found 377 unique shingles, out of 865 possible.
# Found 127 unique shingles, out of 279 possible.
# Found 4952 unique shingles, out of 17179 possible.
# Found 1251 unique shingles, out of 2586 possible.
# Found 435 unique shingles, out of 1258 possible.
# Found 2023 unique shingles, out of 4969 possible.
# Found 489 unique shingles, out of 2540 possible.
# Found 408 unique shingles, out of 1097 possible.
# Found 4473 unique shingles, out of 16771 possible.
# Found 279 unique shingles, out of 587 possible.
# Found 685 unique shingles, out of 935 possible.
# Found 2549 unique shingles, out of 3646 possible.
# Found 84705 unique shingles, out of 901610 possible.
# Found 83854 unique shingles, out of 907915 possible.
# Found 81991 unique shingles, out of 901509 possible.
# Found 90891 unique shingles, out of 904384 possible.
# Found 81949 unique shingles, out of 895883 possible.
# Found 68130 unique shingles, out of 542411 possible.
# Found 81050 unique shingles, out of 899334 possible.
# Found 90255 unique shingles, out of 909050 possible.
# Found 84946 unique shingles, out of 906306 possible.

# %% [markdown]
# ### Define the Jaccard similarity (intersection over union)

# %%
import itertools
def jaccardSim(d1,d2):
    return len(d1.intersection(d2))/len(d1.union(d2))

# itertools.combinations finds all (,n) n-pairs
# then we use a map op on the tuples with jaccardSim
pairs = itertools.combinations(processed_articles, 2)
pair_labels = []
pair_sims = []
for x1, x2 in itertools.combinations(zip(range(len(doc_shingles)),doc_shingles), 2):
    pair_labels.append((x1[0],x2[0]))
    pair_sims.append(jaccardSim(x1[1],x2[1]))
    
print(f"**~~~~~~ True similarity scores ~~~~~~**")
print("Pair\tScore")
print("-"*14)
for pair, score in zip(pair_labels, pair_sims):
    print(f"{pair}\t{score:.3f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# (899, 950)	0.306
# (899, 951)	0.427
# (899, 952)	0.415
# (899, 953)	0.246
# (899, 954)	0.401
# (899, 955)	0.426
# (899, 956)	0.379
# (899, 957)	0.415
# (899, 958)	0.272
# (899, 959)	0.377
# (899, 960)	0.410
# (899, 961)	0.363
# (899, 962)	0.402
# (899, 963)	0.354
# (899, 964)	0.388
# (899, 965)	0.422
# (899, 966)	0.411
# (899, 967)	0.262
# (899, 968)	0.397
# (899, 969)	0.403
# (899, 970)	0.377
# (899, 971)	0.372
# (899, 972)	0.409
# (899, 973)	0.400
# (899, 974)	0.377
# (899, 975)	0.403
# (899, 976)	0.004
# (899, 977)	0.001
# (899, 978)	0.003
# (899, 979)	0.004
# (899, 980)	0.001
# (899, 981)	0.054
# (899, 982)	0.014
# (899, 983)	0.004
# (899, 984)	0.025
# (899, 985)	0.003
# (899, 986)	0.002
# (899, 987)	0.057
# (899, 988)	0.001
# (899, 989)	0.014
# (899, 990)	0.044
# (899, 991)	0.311
# (899, 992)	0.310
# (899, 993)	0.319
# (899, 994)	0.296
# (899, 995)	0.315
# (899, 996)	0.333
# (899, 997)	0.319
# (899, 998)	0.298
# (899, 999)	0.312
# (900, 901)	0.446
# (900, 902)	0.250
# (900, 903)	0.421
# (900, 904)	0.400
# (900, 905)	0.397
# (900, 906)	0.304
# (900, 907)	0.418
# (900, 908)	0.459
# (900, 909)	0.259
# (900, 910)	0.444
# (900, 911)	0.423
# (900, 912)	0.427
# (900, 913)	0.362
# (900, 914)	0.442
# (900, 915)	0.432
# (900, 916)	0.456
# (900, 917)	0.420
# (900, 918)	0.442
# (900, 919)	0.422
# (900, 920)	0.348
# (900, 921)	0.424
# (900, 922)	0.457
# (900, 923)	0.460
# (900, 924)	0.402
# (900, 925)	0.466
# (900, 926)	0.430
# (900, 927)	0.413
# (900, 928)	0.462
# (900, 929)	0.454
# (900, 930)	0.413
# (900, 931)	0.382
# (900, 932)	0.398
# (900, 933)	0.372
# (900, 934)	0.470
# (900, 935)	0.395
# (900, 936)	0.446
# (900, 937)	0.415
# (900, 938)	0.352
# (900, 939)	0.424
# (900, 940)	0.414
# (900, 941)	0.393
# (900, 942)	0.416
# (900, 943)	0.435
# (900, 944)	0.420
# (900, 945)	0.439
# (900, 946)	0.407
# (900, 947)	0.413
# (900, 948)	0.414
# (900, 949)	0.431
# (900, 950)	0.348
# (900, 951)	0.406
# (900, 952)	0.454
# (900, 953)	0.280
# (900, 954)	0.421
# (900, 955)	0.424
# (900, 956)	0.412
# (900, 957)	0.422
# (900, 958)	0.318
# (900, 959)	0.423
# (900, 960)	0.416
# (900, 961)	0.409
# (900, 962)	0.447
# (900, 963)	0.390
# (900, 964)	0.410
# (900, 965)	0.411
# (900, 966)	0.412
# (900, 967)	0.297
# (900, 968)	0.424
# (900, 969)	0.391
# (900, 970)	0.413
# (900, 971)	0.409
# (900, 972)	0.399
# (900, 973)	0.440
# (900, 974)	0.388
# (900, 975)	0.385
# (900, 976)	0.004
# (900, 977)	0.002
# (900, 978)	0.003
# (900, 979)	0.004
# (900, 980)	0.001
# (900, 981)	0.061
# (900, 982)	0.017
# (900, 983)	0.004
# (900, 984)	0.029
# (900, 985)	0.004
# (900, 986)	0.003
# (900, 987)	0.065
# (900, 988)	0.001
# (900, 989)	0.016
# (900, 990)	0.050
# (900, 991)	0.304
# (900, 992)	0.304
# (900, 993)	0.314
# (900, 994)	0.288
# (900, 995)	0.308
# (900, 996)	0.333
# (900, 997)	0.312
# (900, 998)	0.291
# (900, 999)	0.303
# (901, 902)	0.260
# (901, 903)	0.399
# (901, 904)	0.394
# (901, 905)	0.364
# (901, 906)	0.318
# (901, 907)	0.401
# (901, 908)	0.443
# (901, 909)	0.267
# (901, 910)	0.436
# (901, 911)	0.410
# (901, 912)	0.406
# (901, 913)	0.340
# (901, 914)	0.422
# (901, 915)	0.421
# (901, 916)	0.429
# (901, 917)	0.398
# (901, 918)	0.414
# (901, 919)	0.429
# (901, 920)	0.316
# (901, 921)	0.397
# (901, 922)	0.430
# (901, 923)	0.422
# (901, 924)	0.380
# (901, 925)	0.433
# (901, 926)	0.415
# (901, 927)	0.391
# (901, 928)	0.438
# (901, 929)	0.429
# (901, 930)	0.383
# (901, 931)	0.371
# (901, 932)	0.397
# (901, 933)	0.342
# (901, 934)	0.435
# (901, 935)	0.374
# (901, 936)	0.417
# (901, 937)	0.409
# (901, 938)	0.350
# (901, 939)	0.403
# (901, 940)	0.403
# (901, 941)	0.395
# (901, 942)	0.408
# (901, 943)	0.421
# (901, 944)	0.414
# (901, 945)	0.427
# (901, 946)	0.391
# (901, 947)	0.397
# (901, 948)	0.394
# (901, 949)	0.425
# (901, 950)	0.352
# (901, 951)	0.396
# (901, 952)	0.418
# (901, 953)	0.291
# (901, 954)	0.399
# (901, 955)	0.391
# (901, 956)	0.402
# (901, 957)	0.396
# (901, 958)	0.320
# (901, 959)	0.396
# (901, 960)	0.396
# (901, 961)	0.405
# (901, 962)	0.425
# (901, 963)	0.390
# (901, 964)	0.394
# (901, 965)	0.390
# (901, 966)	0.393
# (901, 967)	0.305
# (901, 968)	0.408
# (901, 969)	0.382
# (901, 970)	0.403
# (901, 971)	0.395
# (901, 972)	0.385
# (901, 973)	0.421
# (901, 974)	0.357
# (901, 975)	0.360
# (901, 976)	0.004
# (901, 977)	0.002
# (901, 978)	0.003
# (901, 979)	0.004
# (901, 980)	0.001
# (901, 981)	0.064
# (901, 982)	0.017
# (901, 983)	0.004
# (901, 984)	0.031
# (901, 985)	0.004
# (901, 986)	0.003
# (901, 987)	0.069
# (901, 988)	0.001
# (901, 989)	0.018
# (901, 990)	0.053
# (901, 991)	0.281
# (901, 992)	0.282
# (901, 993)	0.289
# (901, 994)	0.266
# (901, 995)	0.286
# (901, 996)	0.311
# (901, 997)	0.290
# (901, 998)	0.267
# (901, 999)	0.280
# (902, 903)	0.203
# (902, 904)	0.279
# (902, 905)	0.171
# (902, 906)	0.311
# (902, 907)	0.223
# (902, 908)	0.273
# (902, 909)	0.270
# (902, 910)	0.278
# (902, 911)	0.249
# (902, 912)	0.222
# (902, 913)	0.168
# (902, 914)	0.282
# (902, 915)	0.282
# (902, 916)	0.253
# (902, 917)	0.209
# (902, 918)	0.236
# (902, 919)	0.276
# (902, 920)	0.143
# (902, 921)	0.209
# (902, 922)	0.257
# (902, 923)	0.240
# (902, 924)	0.198
# (902, 925)	0.237
# (902, 926)	0.261
# (902, 927)	0.196
# (902, 928)	0.250
# (902, 929)	0.248
# (902, 930)	0.196
# (902, 931)	0.244
# (902, 932)	0.293
# (902, 933)	0.162
# (902, 934)	0.233
# (902, 935)	0.192
# (902, 936)	0.222
# (902, 937)	0.274
# (902, 938)	0.320
# (902, 939)	0.223
# (902, 940)	0.306
# (902, 941)	0.289
# (902, 942)	0.223
# (902, 943)	0.296
# (902, 944)	0.275
# (902, 945)	0.279
# (902, 946)	0.218
# (902, 947)	0.299
# (902, 948)	0.243
# (902, 949)	0.307
# (902, 950)	0.332
# (902, 951)	0.229
# (902, 952)	0.235
# (902, 953)	0.352
# (902, 954)	0.221
# (902, 955)	0.186
# (902, 956)	0.251
# (902, 957)	0.213
# (902, 958)	0.379
# (902, 959)	0.274
# (902, 960)	0.241
# (902, 961)	0.288
# (902, 962)	0.276
# (902, 963)	0.287
# (902, 964)	0.230
# (902, 965)	0.201
# (902, 966)	0.241
# (902, 967)	0.336
# (902, 968)	0.227
# (902, 969)	0.218
# (902, 970)	0.268
# (902, 971)	0.294
# (902, 972)	0.213
# (902, 973)	0.269
# (902, 974)	0.172
# (902, 975)	0.179
# (902, 976)	0.006
# (902, 977)	0.003
# (902, 978)	0.005
# (902, 979)	0.007
# (902, 980)	0.001
# (902, 981)	0.089
# (902, 982)	0.028
# (902, 983)	0.007
# (902, 984)	0.047
# (902, 985)	0.007
# (902, 986)	0.005
# (902, 987)	0.102
# (902, 988)	0.001
# (902, 989)	0.035
# (902, 990)	0.089
# (902, 991)	0.122
# (902, 992)	0.123
# (902, 993)	0.125
# (902, 994)	0.114
# (902, 995)	0.125
# (902, 996)	0.142
# (902, 997)	0.127
# (902, 998)	0.115
# (902, 999)	0.122
# (903, 904)	0.366
# (903, 905)	0.410
# (903, 906)	0.251
# (903, 907)	0.425
# (903, 908)	0.401
# (903, 909)	0.225
# (903, 910)	0.405
# (903, 911)	0.402
# (903, 912)	0.440
# (903, 913)	0.402
# (903, 914)	0.391
# (903, 915)	0.374
# (903, 916)	0.414
# (903, 917)	0.436
# (903, 918)	0.406
# (903, 919)	0.377
# (903, 920)	0.396
# (903, 921)	0.429
# (903, 922)	0.422
# (903, 923)	0.416
# (903, 924)	0.431
# (903, 925)	0.434
# (903, 926)	0.395
# (903, 927)	0.439
# (903, 928)	0.427
# (903, 929)	0.415
# (903, 930)	0.433
# (903, 931)	0.359
# (903, 932)	0.351
# (903, 933)	0.412
# (903, 934)	0.423
# (903, 935)	0.420
# (903, 936)	0.415
# (903, 937)	0.383
# (903, 938)	0.303
# (903, 939)	0.430
# (903, 940)	0.365
# (903, 941)	0.351
# (903, 942)	0.443
# (903, 943)	0.381
# (903, 944)	0.384
# (903, 945)	0.388
# (903, 946)	0.421
# (903, 947)	0.353
# (903, 948)	0.413
# (903, 949)	0.381
# (903, 950)	0.291
# (903, 951)	0.423
# (903, 952)	0.432
# (903, 953)	0.230
# (903, 954)	0.418
# (903, 955)	0.445
# (903, 956)	0.383
# (903, 957)	0.437
# (903, 958)	0.259
# (903, 959)	0.382
# (903, 960)	0.416
# (903, 961)	0.352
# (903, 962)	0.407
# (903, 963)	0.350
# (903, 964)	0.392
# (903, 965)	0.435
# (903, 966)	0.413
# (903, 967)	0.245
# (903, 968)	0.409
# (903, 969)	0.411
# (903, 970)	0.377
# (903, 971)	0.368
# (903, 972)	0.425
# (903, 973)	0.403
# (903, 974)	0.399
# (903, 975)	0.415
# (903, 976)	0.003
# (903, 977)	0.001
# (903, 978)	0.002
# (903, 979)	0.004
# (903, 980)	0.001
# (903, 981)	0.050
# (903, 982)	0.013
# (903, 983)	0.004
# (903, 984)	0.023
# (903, 985)	0.003
# (903, 986)	0.002
# (903, 987)	0.052
# (903, 988)	0.001
# (903, 989)	0.013
# (903, 990)	0.040
# (903, 991)	0.341
# (903, 992)	0.341
# (903, 993)	0.352
# (903, 994)	0.326
# (903, 995)	0.344
# (903, 996)	0.361
# (903, 997)	0.349
# (903, 998)	0.329
# (903, 999)	0.340
# (904, 905)	0.334
# (904, 906)	0.323
# (904, 907)	0.371
# (904, 908)	0.418
# (904, 909)	0.288
# (904, 910)	0.411
# (904, 911)	0.394
# (904, 912)	0.371
# (904, 913)	0.316
# (904, 914)	0.411
# (904, 915)	0.402
# (904, 916)	0.413
# (904, 917)	0.365
# (904, 918)	0.396
# (904, 919)	0.402
# (904, 920)	0.288
# (904, 921)	0.362
# (904, 922)	0.408
# (904, 923)	0.390
# (904, 924)	0.355
# (904, 925)	0.400
# (904, 926)	0.402
# (904, 927)	0.349
# (904, 928)	0.400
# (904, 929)	0.413
# (904, 930)	0.353
# (904, 931)	0.383
# (904, 932)	0.383
# (904, 933)	0.314
# (904, 934)	0.391
# (904, 935)	0.343
# (904, 936)	0.379
# (904, 937)	0.400
# (904, 938)	0.362
# (904, 939)	0.375
# (904, 940)	0.407
# (904, 941)	0.393
# (904, 942)	0.380
# (904, 943)	0.415
# (904, 944)	0.406
# (904, 945)	0.420
# (904, 946)	0.364
# (904, 947)	0.412
# (904, 948)	0.379
# (904, 949)	0.417
# (904, 950)	0.377
# (904, 951)	0.371
# (904, 952)	0.393
# (904, 953)	0.306
# (904, 954)	0.383
# (904, 955)	0.351
# (904, 956)	0.373
# (904, 957)	0.368
# (904, 958)	0.344
# (904, 959)	0.406
# (904, 960)	0.381
# (904, 961)	0.399
# (904, 962)	0.406
# (904, 963)	0.394
# (904, 964)	0.387
# (904, 965)	0.359
# (904, 966)	0.374
# (904, 967)	0.331
# (904, 968)	0.377
# (904, 969)	0.359
# (904, 970)	0.406
# (904, 971)	0.398
# (904, 972)	0.360
# (904, 973)	0.417
# (904, 974)	0.335
# (904, 975)	0.327
# (904, 976)	0.004
# (904, 977)	0.002
# (904, 978)	0.003
# (904, 979)	0.005
# (904, 980)	0.001
# (904, 981)	0.070
# (904, 982)	0.019
# (904, 983)	0.005
# (904, 984)	0.033
# (904, 985)	0.005
# (904, 986)	0.003
# (904, 987)	0.075
# (904, 988)	0.001
# (904, 989)	0.020
# (904, 990)	0.059
# (904, 991)	0.251
# (904, 992)	0.251
# (904, 993)	0.258
# (904, 994)	0.236
# (904, 995)	0.255
# (904, 996)	0.279
# (904, 997)	0.258
# (904, 998)	0.238
# (904, 999)	0.250
# (905, 906)	0.210
# (905, 907)	0.379
# (905, 908)	0.369
# (905, 909)	0.191
# (905, 910)	0.373
# (905, 911)	0.377
# (905, 912)	0.383
# (905, 913)	0.383
# (905, 914)	0.351
# (905, 915)	0.336
# (905, 916)	0.410
# (905, 917)	0.396
# (905, 918)	0.404
# (905, 919)	0.343
# (905, 920)	0.411
# (905, 921)	0.391
# (905, 922)	0.404
# (905, 923)	0.401
# (905, 924)	0.389
# (905, 925)	0.417
# (905, 926)	0.359
# (905, 927)	0.406
# (905, 928)	0.402
# (905, 929)	0.396
# (905, 930)	0.405
# (905, 931)	0.340
# (905, 932)	0.311
# (905, 933)	0.405
# (905, 934)	0.412
# (905, 935)	0.384
# (905, 936)	0.409
# (905, 937)	0.352
# (905, 938)	0.263
# (905, 939)	0.382
# (905, 940)	0.336
# (905, 941)	0.306
# (905, 942)	0.385
# (905, 943)	0.345
# (905, 944)	0.350
# (905, 945)	0.357
# (905, 946)	0.369
# (905, 947)	0.318
# (905, 948)	0.352
# (905, 949)	0.345
# (905, 950)	0.252
# (905, 951)	0.362
# (905, 952)	0.429
# (905, 953)	0.197
# (905, 954)	0.421
# (905, 955)	0.435
# (905, 956)	0.364
# (905, 957)	0.396
# (905, 958)	0.223
# (905, 959)	0.370
# (905, 960)	0.359
# (905, 961)	0.302
# (905, 962)	0.385
# (905, 963)	0.312
# (905, 964)	0.373
# (905, 965)	0.407
# (905, 966)	0.346
# (905, 967)	0.206
# (905, 968)	0.398
# (905, 969)	0.358
# (905, 970)	0.339
# (905, 971)	0.335
# (905, 972)	0.376
# (905, 973)	0.371
# (905, 974)	0.409
# (905, 975)	0.388
# (905, 976)	0.003
# (905, 977)	0.001
# (905, 978)	0.002
# (905, 979)	0.003
# (905, 980)	0.001
# (905, 981)	0.044
# (905, 982)	0.011
# (905, 983)	0.003
# (905, 984)	0.020
# (905, 985)	0.003
# (905, 986)	0.002
# (905, 987)	0.045
# (905, 988)	0.001
# (905, 989)	0.010
# (905, 990)	0.034
# (905, 991)	0.376
# (905, 992)	0.377
# (905, 993)	0.389
# (905, 994)	0.363
# (905, 995)	0.381
# (905, 996)	0.383
# (905, 997)	0.382
# (905, 998)	0.367
# (905, 999)	0.376
# (906, 907)	0.270
# (906, 908)	0.343
# (906, 909)	0.291
# (906, 910)	0.321
# (906, 911)	0.290
# (906, 912)	0.273
# (906, 913)	0.206
# (906, 914)	0.335
# (906, 915)	0.347
# (906, 916)	0.300
# (906, 917)	0.257
# (906, 918)	0.287
# (906, 919)	0.329
# (906, 920)	0.177
# (906, 921)	0.261
# (906, 922)	0.297
# (906, 923)	0.283
# (906, 924)	0.242
# (906, 925)	0.298
# (906, 926)	0.344
# (906, 927)	0.248
# (906, 928)	0.302
# (906, 929)	0.302
# (906, 930)	0.240
# (906, 931)	0.281
# (906, 932)	0.330
# (906, 933)	0.201
# (906, 934)	0.304
# (906, 935)	0.238
# (906, 936)	0.269
# (906, 937)	0.309
# (906, 938)	0.324
# (906, 939)	0.274
# (906, 940)	0.341
# (906, 941)	0.339
# (906, 942)	0.273
# (906, 943)	0.341
# (906, 944)	0.323
# (906, 945)	0.333
# (906, 946)	0.268
# (906, 947)	0.340
# (906, 948)	0.292
# (906, 949)	0.334
# (906, 950)	0.348
# (906, 951)	0.276
# (906, 952)	0.273
# (906, 953)	0.323
# (906, 954)	0.256
# (906, 955)	0.240
# (906, 956)	0.283
# (906, 957)	0.259
# (906, 958)	0.348
# (906, 959)	0.297
# (906, 960)	0.286
# (906, 961)	0.357
# (906, 962)	0.312
# (906, 963)	0.328
# (906, 964)	0.279
# (906, 965)	0.250
# (906, 966)	0.294
# (906, 967)	0.338
# (906, 968)	0.265
# (906, 969)	0.262
# (906, 970)	0.335
# (906, 971)	0.312
# (906, 972)	0.262
# (906, 973)	0.313
# (906, 974)	0.213
# (906, 975)	0.221
# (906, 976)	0.006
# (906, 977)	0.003
# (906, 978)	0.005
# (906, 979)	0.007
# (906, 980)	0.001
# (906, 981)	0.091
# (906, 982)	0.027
# (906, 983)	0.007
# (906, 984)	0.046
# (906, 985)	0.007
# (906, 986)	0.004
# (906, 987)	0.102
# (906, 988)	0.001
# (906, 989)	0.031
# (906, 990)	0.081
# (906, 991)	0.156
# (906, 992)	0.157
# (906, 993)	0.161
# (906, 994)	0.147
# (906, 995)	0.160
# (906, 996)	0.181
# (906, 997)	0.163
# (906, 998)	0.147
# (906, 999)	0.155
# (907, 908)	0.408
# (907, 909)	0.239
# (907, 910)	0.402
# (907, 911)	0.399
# (907, 912)	0.428
# (907, 913)	0.382
# (907, 914)	0.396
# (907, 915)	0.382
# (907, 916)	0.414
# (907, 917)	0.423
# (907, 918)	0.399
# (907, 919)	0.379
# (907, 920)	0.359
# (907, 921)	0.418
# (907, 922)	0.418
# (907, 923)	0.406
# (907, 924)	0.412
# (907, 925)	0.422
# (907, 926)	0.403
# (907, 927)	0.427
# (907, 928)	0.420
# (907, 929)	0.411
# (907, 930)	0.426
# (907, 931)	0.358
# (907, 932)	0.360
# (907, 933)	0.388
# (907, 934)	0.414
# (907, 935)	0.405
# (907, 936)	0.403
# (907, 937)	0.385
# (907, 938)	0.315
# (907, 939)	0.427
# (907, 940)	0.372
# (907, 941)	0.361
# (907, 942)	0.433
# (907, 943)	0.392
# (907, 944)	0.386
# (907, 945)	0.393
# (907, 946)	0.418
# (907, 947)	0.361
# (907, 948)	0.414
# (907, 949)	0.390
# (907, 950)	0.310
# (907, 951)	0.419
# (907, 952)	0.412
# (907, 953)	0.253
# (907, 954)	0.401
# (907, 955)	0.428
# (907, 956)	0.381
# (907, 957)	0.417
# (907, 958)	0.279
# (907, 959)	0.378
# (907, 960)	0.408
# (907, 961)	0.364
# (907, 962)	0.412
# (907, 963)	0.359
# (907, 964)	0.385
# (907, 965)	0.417
# (907, 966)	0.414
# (907, 967)	0.263
# (907, 968)	0.400
# (907, 969)	0.408
# (907, 970)	0.380
# (907, 971)	0.373
# (907, 972)	0.415
# (907, 973)	0.401
# (907, 974)	0.374
# (907, 975)	0.392
# (907, 976)	0.004
# (907, 977)	0.001
# (907, 978)	0.003
# (907, 979)	0.004
# (907, 980)	0.001
# (907, 981)	0.056
# (907, 982)	0.015
# (907, 983)	0.004
# (907, 984)	0.026
# (907, 985)	0.004
# (907, 986)	0.002
# (907, 987)	0.059
# (907, 988)	0.001
# (907, 989)	0.014
# (907, 990)	0.046
# (907, 991)	0.314
# (907, 992)	0.313
# (907, 993)	0.320
# (907, 994)	0.296
# (907, 995)	0.318
# (907, 996)	0.336
# (907, 997)	0.322
# (907, 998)	0.302
# (907, 999)	0.313
# (908, 909)	0.280
# (908, 910)	0.447
# (908, 911)	0.420
# (908, 912)	0.412
# (908, 913)	0.340
# (908, 914)	0.445
# (908, 915)	0.449
# (908, 916)	0.454
# (908, 917)	0.410
# (908, 918)	0.424
# (908, 919)	0.417
# (908, 920)	0.316
# (908, 921)	0.415
# (908, 922)	0.482
# (908, 923)	0.434
# (908, 924)	0.384
# (908, 925)	0.483
# (908, 926)	0.447
# (908, 927)	0.395
# (908, 928)	0.463
# (908, 929)	0.452
# (908, 930)	0.392
# (908, 931)	0.389
# (908, 932)	0.407
# (908, 933)	0.343
# (908, 934)	0.483
# (908, 935)	0.377
# (908, 936)	0.428
# (908, 937)	0.426
# (908, 938)	0.363
# (908, 939)	0.414
# (908, 940)	0.435
# (908, 941)	0.418
# (908, 942)	0.413
# (908, 943)	0.467
# (908, 944)	0.432
# (908, 945)	0.493
# (908, 946)	0.397
# (908, 947)	0.421
# (908, 948)	0.405
# (908, 949)	0.448
# (908, 950)	0.368
# (908, 951)	0.404
# (908, 952)	0.436
# (908, 953)	0.301
# (908, 954)	0.407
# (908, 955)	0.399
# (908, 956)	0.401
# (908, 957)	0.401
# (908, 958)	0.337
# (908, 959)	0.420
# (908, 960)	0.405
# (908, 961)	0.424
# (908, 962)	0.447
# (908, 963)	0.406
# (908, 964)	0.405
# (908, 965)	0.393
# (908, 966)	0.411
# (908, 967)	0.318
# (908, 968)	0.412
# (908, 969)	0.383
# (908, 970)	0.430
# (908, 971)	0.409
# (908, 972)	0.391
# (908, 973)	0.444
# (908, 974)	0.369
# (908, 975)	0.366
# (908, 976)	0.004
# (908, 977)	0.002
# (908, 978)	0.003
# (908, 979)	0.005
# (908, 980)	0.001
# (908, 981)	0.068
# (908, 982)	0.018
# (908, 983)	0.005
# (908, 984)	0.032
# (908, 985)	0.004
# (908, 986)	0.003
# (908, 987)	0.072
# (908, 988)	0.001
# (908, 989)	0.018
# (908, 990)	0.057
# (908, 991)	0.274
# (908, 992)	0.276
# (908, 993)	0.284
# (908, 994)	0.260
# (908, 995)	0.281
# (908, 996)	0.305
# (908, 997)	0.284
# (908, 998)	0.261
# (908, 999)	0.274
# (909, 910)	0.276
# (909, 911)	0.259
# (909, 912)	0.242
# (909, 913)	0.191
# (909, 914)	0.277
# (909, 915)	0.289
# (909, 916)	0.260
# (909, 917)	0.227
# (909, 918)	0.249
# (909, 919)	0.279
# (909, 920)	0.167
# (909, 921)	0.229
# (909, 922)	0.254
# (909, 923)	0.244
# (909, 924)	0.220
# (909, 925)	0.245
# (909, 926)	0.274
# (909, 927)	0.216
# (909, 928)	0.250
# (909, 929)	0.257
# (909, 930)	0.214
# (909, 931)	0.254
# (909, 932)	0.288
# (909, 933)	0.186
# (909, 934)	0.245
# (909, 935)	0.213
# (909, 936)	0.235
# (909, 937)	0.271
# (909, 938)	0.319
# (909, 939)	0.241
# (909, 940)	0.286
# (909, 941)	0.286
# (909, 942)	0.245
# (909, 943)	0.287
# (909, 944)	0.274
# (909, 945)	0.273
# (909, 946)	0.235
# (909, 947)	0.285
# (909, 948)	0.253
# (909, 949)	0.286
# (909, 950)	0.292
# (909, 951)	0.243
# (909, 952)	0.235
# (909, 953)	0.282
# (909, 954)	0.232
# (909, 955)	0.210
# (909, 956)	0.243
# (909, 957)	0.231
# (909, 958)	0.289
# (909, 959)	0.263
# (909, 960)	0.254
# (909, 961)	0.291
# (909, 962)	0.263
# (909, 963)	0.290
# (909, 964)	0.251
# (909, 965)	0.223
# (909, 966)	0.257
# (909, 967)	0.279
# (909, 968)	0.233
# (909, 969)	0.231
# (909, 970)	0.280
# (909, 971)	0.276
# (909, 972)	0.232
# (909, 973)	0.272
# (909, 974)	0.200
# (909, 975)	0.201
# (909, 976)	0.006
# (909, 977)	0.002
# (909, 978)	0.004
# (909, 979)	0.006
# (909, 980)	0.001
# (909, 981)	0.077
# (909, 982)	0.024
# (909, 983)	0.006
# (909, 984)	0.039
# (909, 985)	0.006
# (909, 986)	0.004
# (909, 987)	0.087
# (909, 988)	0.001
# (909, 989)	0.027
# (909, 990)	0.072
# (909, 991)	0.144
# (909, 992)	0.145
# (909, 993)	0.149
# (909, 994)	0.138
# (909, 995)	0.148
# (909, 996)	0.166
# (909, 997)	0.149
# (909, 998)	0.138
# (909, 999)	0.145
# (910, 911)	0.435
# (910, 912)	0.410
# (910, 913)	0.344
# (910, 914)	0.434
# (910, 915)	0.427
# (910, 916)	0.440
# (910, 917)	0.403
# (910, 918)	0.418
# (910, 919)	0.434
# (910, 920)	0.322
# (910, 921)	0.404
# (910, 922)	0.451
# (910, 923)	0.436
# (910, 924)	0.386
# (910, 925)	0.440
# (910, 926)	0.438
# (910, 927)	0.395
# (910, 928)	0.452
# (910, 929)	0.436
# (910, 930)	0.393
# (910, 931)	0.380
# (910, 932)	0.403
# (910, 933)	0.344
# (910, 934)	0.454
# (910, 935)	0.376
# (910, 936)	0.432
# (910, 937)	0.429
# (910, 938)	0.364
# (910, 939)	0.410
# (910, 940)	0.411
# (910, 941)	0.404
# (910, 942)	0.411
# (910, 943)	0.439
# (910, 944)	0.428
# (910, 945)	0.438
# (910, 946)	0.393
# (910, 947)	0.403
# (910, 948)	0.399
# (910, 949)	0.432
# (910, 950)	0.358
# (910, 951)	0.396
# (910, 952)	0.435
# (910, 953)	0.292
# (910, 954)	0.423
# (910, 955)	0.397
# (910, 956)	0.403
# (910, 957)	0.405
# (910, 958)	0.330
# (910, 959)	0.417
# (910, 960)	0.403
# (910, 961)	0.445
# (910, 962)	0.463
# (910, 963)	0.406
# (910, 964)	0.403
# (910, 965)	0.397
# (910, 966)	0.403
# (910, 967)	0.305
# (910, 968)	0.426
# (910, 969)	0.383
# (910, 970)	0.410
# (910, 971)	0.415
# (910, 972)	0.390
# (910, 973)	0.434
# (910, 974)	0.362
# (910, 975)	0.361
# (910, 976)	0.004
# (910, 977)	0.002
# (910, 978)	0.003
# (910, 979)	0.004
# (910, 980)	0.001
# (910, 981)	0.065
# (910, 982)	0.018
# (910, 983)	0.005
# (910, 984)	0.032
# (910, 985)	0.005
# (910, 986)	0.003
# (910, 987)	0.071
# (910, 988)	0.001
# (910, 989)	0.018
# (910, 990)	0.054
# (910, 991)	0.284
# (910, 992)	0.285
# (910, 993)	0.292
# (910, 994)	0.269
# (910, 995)	0.291
# (910, 996)	0.315
# (910, 997)	0.293
# (910, 998)	0.269
# (910, 999)	0.284
# (911, 912)	0.400
# (911, 913)	0.359
# (911, 914)	0.413
# (911, 915)	0.395
# (911, 916)	0.431
# (911, 917)	0.402
# (911, 918)	0.403
# (911, 919)	0.395
# (911, 920)	0.333
# (911, 921)	0.402
# (911, 922)	0.432
# (911, 923)	0.418
# (911, 924)	0.392
# (911, 925)	0.427
# (911, 926)	0.421
# (911, 927)	0.394
# (911, 928)	0.428
# (911, 929)	0.419
# (911, 930)	0.394
# (911, 931)	0.370
# (911, 932)	0.373
# (911, 933)	0.359
# (911, 934)	0.425
# (911, 935)	0.382
# (911, 936)	0.410
# (911, 937)	0.415
# (911, 938)	0.344
# (911, 939)	0.400
# (911, 940)	0.399
# (911, 941)	0.392
# (911, 942)	0.408
# (911, 943)	0.413
# (911, 944)	0.398
# (911, 945)	0.412
# (911, 946)	0.389
# (911, 947)	0.378
# (911, 948)	0.394
# (911, 949)	0.411
# (911, 950)	0.336
# (911, 951)	0.394
# (911, 952)	0.416
# (911, 953)	0.274
# (911, 954)	0.418
# (911, 955)	0.396
# (911, 956)	0.385
# (911, 957)	0.400
# (911, 958)	0.305
# (911, 959)	0.398
# (911, 960)	0.397
# (911, 961)	0.402
# (911, 962)	0.421
# (911, 963)	0.380
# (911, 964)	0.400
# (911, 965)	0.395
# (911, 966)	0.391
# (911, 967)	0.280
# (911, 968)	0.460
# (911, 969)	0.386
# (911, 970)	0.399
# (911, 971)	0.390
# (911, 972)	0.388
# (911, 973)	0.415
# (911, 974)	0.372
# (911, 975)	0.372
# (911, 976)	0.003
# (911, 977)	0.002
# (911, 978)	0.003
# (911, 979)	0.004
# (911, 980)	0.001
# (911, 981)	0.059
# (911, 982)	0.016
# (911, 983)	0.004
# (911, 984)	0.027
# (911, 985)	0.004
# (911, 986)	0.003
# (911, 987)	0.062
# (911, 988)	0.001
# (911, 989)	0.016
# (911, 990)	0.049
# (911, 991)	0.299
# (911, 992)	0.300
# (911, 993)	0.306
# (911, 994)	0.284
# (911, 995)	0.304
# (911, 996)	0.325
# (911, 997)	0.308
# (911, 998)	0.288
# (911, 999)	0.300
# (912, 913)	0.385
# (912, 914)	0.402
# (912, 915)	0.385
# (912, 916)	0.413
# (912, 917)	0.433
# (912, 918)	0.409
# (912, 919)	0.386
# (912, 920)	0.371
# (912, 921)	0.443
# (912, 922)	0.418
# (912, 923)	0.411
# (912, 924)	0.422
# (912, 925)	0.427
# (912, 926)	0.405
# (912, 927)	0.435
# (912, 928)	0.421
# (912, 929)	0.415
# (912, 930)	0.434
# (912, 931)	0.362
# (912, 932)	0.360
# (912, 933)	0.393
# (912, 934)	0.423
# (912, 935)	0.413
# (912, 936)	0.411
# (912, 937)	0.387
# (912, 938)	0.321
# (912, 939)	0.436
# (912, 940)	0.378
# (912, 941)	0.362
# (912, 942)	0.439
# (912, 943)	0.395
# (912, 944)	0.387
# (912, 945)	0.396
# (912, 946)	0.432
# (912, 947)	0.362
# (912, 948)	0.426
# (912, 949)	0.391
# (912, 950)	0.310
# (912, 951)	0.432
# (912, 952)	0.415
# (912, 953)	0.252
# (912, 954)	0.399
# (912, 955)	0.437
# (912, 956)	0.384
# (912, 957)	0.432
# (912, 958)	0.277
# (912, 959)	0.380
# (912, 960)	0.426
# (912, 961)	0.372
# (912, 962)	0.411
# (912, 963)	0.359
# (912, 964)	0.384
# (912, 965)	0.429
# (912, 966)	0.432
# (912, 967)	0.265
# (912, 968)	0.401
# (912, 969)	0.416
# (912, 970)	0.384
# (912, 971)	0.375
# (912, 972)	0.428
# (912, 973)	0.406
# (912, 974)	0.375
# (912, 975)	0.409
# (912, 976)	0.003
# (912, 977)	0.002
# (912, 978)	0.003
# (912, 979)	0.004
# (912, 980)	0.001
# (912, 981)	0.054
# (912, 982)	0.015
# (912, 983)	0.004
# (912, 984)	0.025
# (912, 985)	0.004
# (912, 986)	0.003
# (912, 987)	0.058
# (912, 988)	0.001
# (912, 989)	0.014
# (912, 990)	0.044
# (912, 991)	0.311
# (912, 992)	0.312
# (912, 993)	0.321
# (912, 994)	0.297
# (912, 995)	0.314
# (912, 996)	0.335
# (912, 997)	0.321
# (912, 998)	0.300
# (912, 999)	0.312
# (913, 914)	0.330
# (913, 915)	0.315
# (913, 916)	0.359
# (913, 917)	0.398
# (913, 918)	0.359
# (913, 919)	0.318
# (913, 920)	0.381
# (913, 921)	0.388
# (913, 922)	0.365
# (913, 923)	0.370
# (913, 924)	0.399
# (913, 925)	0.375
# (913, 926)	0.338
# (913, 927)	0.412
# (913, 928)	0.367
# (913, 929)	0.361
# (913, 930)	0.398
# (913, 931)	0.319
# (913, 932)	0.291
# (913, 933)	0.406
# (913, 934)	0.364
# (913, 935)	0.410
# (913, 936)	0.371
# (913, 937)	0.330
# (913, 938)	0.261
# (913, 939)	0.380
# (913, 940)	0.309
# (913, 941)	0.298
# (913, 942)	0.390
# (913, 943)	0.324
# (913, 944)	0.325
# (913, 945)	0.329
# (913, 946)	0.372
# (913, 947)	0.297
# (913, 948)	0.357
# (913, 949)	0.322
# (913, 950)	0.247
# (913, 951)	0.383
# (913, 952)	0.379
# (913, 953)	0.194
# (913, 954)	0.371
# (913, 955)	0.406
# (913, 956)	0.345
# (913, 957)	0.388
# (913, 958)	0.218
# (913, 959)	0.327
# (913, 960)	0.362
# (913, 961)	0.298
# (913, 962)	0.349
# (913, 963)	0.291
# (913, 964)	0.344
# (913, 965)	0.391
# (913, 966)	0.355
# (913, 967)	0.206
# (913, 968)	0.377
# (913, 969)	0.374
# (913, 970)	0.319
# (913, 971)	0.312
# (913, 972)	0.380
# (913, 973)	0.339
# (913, 974)	0.368
# (913, 975)	0.404
# (913, 976)	0.003
# (913, 977)	0.001
# (913, 978)	0.002
# (913, 979)	0.003
# (913, 980)	0.001
# (913, 981)	0.042
# (913, 982)	0.011
# (913, 983)	0.003
# (913, 984)	0.019
# (913, 985)	0.003
# (913, 986)	0.002
# (913, 987)	0.044
# (913, 988)	0.001
# (913, 989)	0.010
# (913, 990)	0.034
# (913, 991)	0.346
# (913, 992)	0.345
# (913, 993)	0.354
# (913, 994)	0.337
# (913, 995)	0.348
# (913, 996)	0.354
# (913, 997)	0.351
# (913, 998)	0.339
# (913, 999)	0.345
# (914, 915)	0.434
# (914, 916)	0.438
# (914, 917)	0.388
# (914, 918)	0.417
# (914, 919)	0.422
# (914, 920)	0.304
# (914, 921)	0.396
# (914, 922)	0.431
# (914, 923)	0.419
# (914, 924)	0.369
# (914, 925)	0.434
# (914, 926)	0.428
# (914, 927)	0.382
# (914, 928)	0.430
# (914, 929)	0.436
# (914, 930)	0.378
# (914, 931)	0.380
# (914, 932)	0.401
# (914, 933)	0.329
# (914, 934)	0.435
# (914, 935)	0.364
# (914, 936)	0.409
# (914, 937)	0.410
# (914, 938)	0.376
# (914, 939)	0.398
# (914, 940)	0.416
# (914, 941)	0.413
# (914, 942)	0.400
# (914, 943)	0.434
# (914, 944)	0.419
# (914, 945)	0.428
# (914, 946)	0.384
# (914, 947)	0.411
# (914, 948)	0.398
# (914, 949)	0.433
# (914, 950)	0.380
# (914, 951)	0.393
# (914, 952)	0.430
# (914, 953)	0.306
# (914, 954)	0.397
# (914, 955)	0.382
# (914, 956)	0.394
# (914, 957)	0.387
# (914, 958)	0.347
# (914, 959)	0.418
# (914, 960)	0.399
# (914, 961)	0.414
# (914, 962)	0.439
# (914, 963)	0.402
# (914, 964)	0.395
# (914, 965)	0.381
# (914, 966)	0.396
# (914, 967)	0.328
# (914, 968)	0.392
# (914, 969)	0.375
# (914, 970)	0.405
# (914, 971)	0.408
# (914, 972)	0.383
# (914, 973)	0.438
# (914, 974)	0.350
# (914, 975)	0.346
# (914, 976)	0.005
# (914, 977)	0.002
# (914, 978)	0.003
# (914, 979)	0.005
# (914, 980)	0.001
# (914, 981)	0.069
# (914, 982)	0.019
# (914, 983)	0.005
# (914, 984)	0.033
# (914, 985)	0.005
# (914, 986)	0.003
# (914, 987)	0.073
# (914, 988)	0.001
# (914, 989)	0.019
# (914, 990)	0.058
# (914, 991)	0.264
# (914, 992)	0.266
# (914, 993)	0.274
# (914, 994)	0.250
# (914, 995)	0.271
# (914, 996)	0.296
# (914, 997)	0.276
# (914, 998)	0.251
# (914, 999)	0.264
# (915, 916)	0.426
# (915, 917)	0.378
# (915, 918)	0.407
# (915, 919)	0.417
# (915, 920)	0.287
# (915, 921)	0.377
# (915, 922)	0.420
# (915, 923)	0.406
# (915, 924)	0.354
# (915, 925)	0.415
# (915, 926)	0.421
# (915, 927)	0.364
# (915, 928)	0.423
# (915, 929)	0.420
# (915, 930)	0.362
# (915, 931)	0.368
# (915, 932)	0.409
# (915, 933)	0.316
# (915, 934)	0.423
# (915, 935)	0.350
# (915, 936)	0.395
# (915, 937)	0.398
# (915, 938)	0.364
# (915, 939)	0.387
# (915, 940)	0.415
# (915, 941)	0.400
# (915, 942)	0.382
# (915, 943)	0.424
# (915, 944)	0.415
# (915, 945)	0.422
# (915, 946)	0.377
# (915, 947)	0.412
# (915, 948)	0.387
# (915, 949)	0.428
# (915, 950)	0.371
# (915, 951)	0.379
# (915, 952)	0.424
# (915, 953)	0.314
# (915, 954)	0.381
# (915, 955)	0.364
# (915, 956)	0.383
# (915, 957)	0.376
# (915, 958)	0.350
# (915, 959)	0.399
# (915, 960)	0.391
# (915, 961)	0.409
# (915, 962)	0.425
# (915, 963)	0.403
# (915, 964)	0.385
# (915, 965)	0.368
# (915, 966)	0.390
# (915, 967)	0.332
# (915, 968)	0.382
# (915, 969)	0.366
# (915, 970)	0.406
# (915, 971)	0.405
# (915, 972)	0.366
# (915, 973)	0.421
# (915, 974)	0.337
# (915, 975)	0.330
# (915, 976)	0.004
# (915, 977)	0.002
# (915, 978)	0.004
# (915, 979)	0.005
# (915, 980)	0.001
# (915, 981)	0.073
# (915, 982)	0.021
# (915, 983)	0.005
# (915, 984)	0.035
# (915, 985)	0.005
# (915, 986)	0.003
# (915, 987)	0.078
# (915, 988)	0.001
# (915, 989)	0.021
# (915, 990)	0.061
# (915, 991)	0.251
# (915, 992)	0.252
# (915, 993)	0.259
# (915, 994)	0.237
# (915, 995)	0.257
# (915, 996)	0.283
# (915, 997)	0.260
# (915, 998)	0.239
# (915, 999)	0.249
# (916, 917)	0.412
# (916, 918)	0.435
# (916, 919)	0.417
# (916, 920)	0.348
# (916, 921)	0.411
# (916, 922)	0.452
# (916, 923)	0.440
# (916, 924)	0.400
# (916, 925)	0.462
# (916, 926)	0.427
# (916, 927)	0.409
# (916, 928)	0.453
# (916, 929)	0.451
# (916, 930)	0.406
# (916, 931)	0.393
# (916, 932)	0.393
# (916, 933)	0.367
# (916, 934)	0.456
# (916, 935)	0.384
# (916, 936)	0.431
# (916, 937)	0.428
# (916, 938)	0.350
# (916, 939)	0.416
# (916, 940)	0.418
# (916, 941)	0.389
# (916, 942)	0.416
# (916, 943)	0.442
# (916, 944)	0.430
# (916, 945)	0.432
# (916, 946)	0.399
# (916, 947)	0.410
# (916, 948)	0.403
# (916, 949)	0.441
# (916, 950)	0.356
# (916, 951)	0.404
# (916, 952)	0.460
# (916, 953)	0.285
# (916, 954)	0.438
# (916, 955)	0.416
# (916, 956)	0.408
# (916, 957)	0.412
# (916, 958)	0.318
# (916, 959)	0.432
# (916, 960)	0.410
# (916, 961)	0.396
# (916, 962)	0.449
# (916, 963)	0.401
# (916, 964)	0.418
# (916, 965)	0.409
# (916, 966)	0.399
# (916, 967)	0.293
# (916, 968)	0.424
# (916, 969)	0.389
# (916, 970)	0.408
# (916, 971)	0.411
# (916, 972)	0.398
# (916, 973)	0.449
# (916, 974)	0.394
# (916, 975)	0.374
# (916, 976)	0.004
# (916, 977)	0.002
# (916, 978)	0.003
# (916, 979)	0.004
# (916, 980)	0.001
# (916, 981)	0.061
# (916, 982)	0.016
# (916, 983)	0.004
# (916, 984)	0.029
# (916, 985)	0.004
# (916, 986)	0.003
# (916, 987)	0.065
# (916, 988)	0.001
# (916, 989)	0.016
# (916, 990)	0.049
# (916, 991)	0.302
# (916, 992)	0.304
# (916, 993)	0.313
# (916, 994)	0.286
# (916, 995)	0.309
# (916, 996)	0.330
# (916, 997)	0.311
# (916, 998)	0.290
# (916, 999)	0.302
# (917, 918)	0.404
# (917, 919)	0.378
# (917, 920)	0.378
# (917, 921)	0.427
# (917, 922)	0.421
# (917, 923)	0.408
# (917, 924)	0.423
# (917, 925)	0.430
# (917, 926)	0.400
# (917, 927)	0.449
# (917, 928)	0.423
# (917, 929)	0.411
# (917, 930)	0.431
# (917, 931)	0.359
# (917, 932)	0.353
# (917, 933)	0.402
# (917, 934)	0.421
# (917, 935)	0.423
# (917, 936)	0.411
# (917, 937)	0.381
# (917, 938)	0.308
# (917, 939)	0.433
# (917, 940)	0.366
# (917, 941)	0.352
# (917, 942)	0.434
# (917, 943)	0.383
# (917, 944)	0.380
# (917, 945)	0.390
# (917, 946)	0.425
# (917, 947)	0.350
# (917, 948)	0.409
# (917, 949)	0.380
# (917, 950)	0.296
# (917, 951)	0.438
# (917, 952)	0.423
# (917, 953)	0.238
# (917, 954)	0.403
# (917, 955)	0.443
# (917, 956)	0.384
# (917, 957)	0.427
# (917, 958)	0.265
# (917, 959)	0.373
# (917, 960)	0.416
# (917, 961)	0.357
# (917, 962)	0.409
# (917, 963)	0.349
# (917, 964)	0.384
# (917, 965)	0.441
# (917, 966)	0.421
# (917, 967)	0.253
# (917, 968)	0.408
# (917, 969)	0.403
# (917, 970)	0.371
# (917, 971)	0.363
# (917, 972)	0.420
# (917, 973)	0.394
# (917, 974)	0.383
# (917, 975)	0.413
# (917, 976)	0.003
# (917, 977)	0.001
# (917, 978)	0.003
# (917, 979)	0.004
# (917, 980)	0.001
# (917, 981)	0.052
# (917, 982)	0.014
# (917, 983)	0.004
# (917, 984)	0.024
# (917, 985)	0.003
# (917, 986)	0.002
# (917, 987)	0.055
# (917, 988)	0.001
# (917, 989)	0.013
# (917, 990)	0.043
# (917, 991)	0.333
# (917, 992)	0.329
# (917, 993)	0.341
# (917, 994)	0.315
# (917, 995)	0.335
# (917, 996)	0.353
# (917, 997)	0.339
# (917, 998)	0.318
# (917, 999)	0.331
# (918, 919)	0.401
# (918, 920)	0.357
# (918, 921)	0.406
# (918, 922)	0.435
# (918, 923)	0.425
# (918, 924)	0.392
# (918, 925)	0.440
# (918, 926)	0.415
# (918, 927)	0.400
# (918, 928)	0.427
# (918, 929)	0.438
# (918, 930)	0.401
# (918, 931)	0.389
# (918, 932)	0.374
# (918, 933)	0.367
# (918, 934)	0.435
# (918, 935)	0.381
# (918, 936)	0.418
# (918, 937)	0.400
# (918, 938)	0.335
# (918, 939)	0.407
# (918, 940)	0.397
# (918, 941)	0.365
# (918, 942)	0.407
# (918, 943)	0.407
# (918, 944)	0.401
# (918, 945)	0.412
# (918, 946)	0.394
# (918, 947)	0.385
# (918, 948)	0.390
# (918, 949)	0.402
# (918, 950)	0.330
# (918, 951)	0.394
# (918, 952)	0.441
# (918, 953)	0.261
# (918, 954)	0.419
# (918, 955)	0.414
# (918, 956)	0.393
# (918, 957)	0.407
# (918, 958)	0.299
# (918, 959)	0.409
# (918, 960)	0.395
# (918, 961)	0.374
# (918, 962)	0.427
# (918, 963)	0.370
# (918, 964)	0.403
# (918, 965)	0.407
# (918, 966)	0.389
# (918, 967)	0.282
# (918, 968)	0.409
# (918, 969)	0.380
# (918, 970)	0.397
# (918, 971)	0.390
# (918, 972)	0.393
# (918, 973)	0.423
# (918, 974)	0.388
# (918, 975)	0.372
# (918, 976)	0.004
# (918, 977)	0.002
# (918, 978)	0.003
# (918, 979)	0.004
# (918, 980)	0.001
# (918, 981)	0.057
# (918, 982)	0.015
# (918, 983)	0.004
# (918, 984)	0.028
# (918, 985)	0.004
# (918, 986)	0.002
# (918, 987)	0.061
# (918, 988)	0.001
# (918, 989)	0.015
# (918, 990)	0.046
# (918, 991)	0.307
# (918, 992)	0.309
# (918, 993)	0.318
# (918, 994)	0.292
# (918, 995)	0.314
# (918, 996)	0.332
# (918, 997)	0.316
# (918, 998)	0.296
# (918, 999)	0.307
# (919, 920)	0.298
# (919, 921)	0.375
# (919, 922)	0.410
# (919, 923)	0.399
# (919, 924)	0.357
# (919, 925)	0.410
# (919, 926)	0.417
# (919, 927)	0.364
# (919, 928)	0.415
# (919, 929)	0.418
# (919, 930)	0.363
# (919, 931)	0.370
# (919, 932)	0.400
# (919, 933)	0.319
# (919, 934)	0.420
# (919, 935)	0.350
# (919, 936)	0.398
# (919, 937)	0.401
# (919, 938)	0.354
# (919, 939)	0.386
# (919, 940)	0.400
# (919, 941)	0.393
# (919, 942)	0.387
# (919, 943)	0.414
# (919, 944)	0.416
# (919, 945)	0.410
# (919, 946)	0.373
# (919, 947)	0.397
# (919, 948)	0.390
# (919, 949)	0.417
# (919, 950)	0.366
# (919, 951)	0.377
# (919, 952)	0.413
# (919, 953)	0.303
# (919, 954)	0.398
# (919, 955)	0.365
# (919, 956)	0.402
# (919, 957)	0.380
# (919, 958)	0.339
# (919, 959)	0.414
# (919, 960)	0.390
# (919, 961)	0.403
# (919, 962)	0.428
# (919, 963)	0.404
# (919, 964)	0.390
# (919, 965)	0.378
# (919, 966)	0.379
# (919, 967)	0.319
# (919, 968)	0.380
# (919, 969)	0.364
# (919, 970)	0.400
# (919, 971)	0.407
# (919, 972)	0.375
# (919, 973)	0.419
# (919, 974)	0.338
# (919, 975)	0.335
# (919, 976)	0.005
# (919, 977)	0.002
# (919, 978)	0.003
# (919, 979)	0.005
# (919, 980)	0.001
# (919, 981)	0.069
# (919, 982)	0.019
# (919, 983)	0.005
# (919, 984)	0.034
# (919, 985)	0.005
# (919, 986)	0.003
# (919, 987)	0.075
# (919, 988)	0.001
# (919, 989)	0.019
# (919, 990)	0.058
# (919, 991)	0.257
# (919, 992)	0.258
# (919, 993)	0.265
# (919, 994)	0.242
# (919, 995)	0.262
# (919, 996)	0.288
# (919, 997)	0.267
# (919, 998)	0.243
# (919, 999)	0.256
# (920, 921)	0.378
# (920, 922)	0.351
# (920, 923)	0.352
# (920, 924)	0.379
# (920, 925)	0.366
# (920, 926)	0.313
# (920, 927)	0.391
# (920, 928)	0.350
# (920, 929)	0.348
# (920, 930)	0.392
# (920, 931)	0.306
# (920, 932)	0.272
# (920, 933)	0.415
# (920, 934)	0.355
# (920, 935)	0.380
# (920, 936)	0.360
# (920, 937)	0.309
# (920, 938)	0.230
# (920, 939)	0.367
# (920, 940)	0.283
# (920, 941)	0.266
# (920, 942)	0.371
# (920, 943)	0.298
# (920, 944)	0.305
# (920, 945)	0.305
# (920, 946)	0.358
# (920, 947)	0.269
# (920, 948)	0.334
# (920, 949)	0.293
# (920, 950)	0.215
# (920, 951)	0.349
# (920, 952)	0.372
# (920, 953)	0.166
# (920, 954)	0.372
# (920, 955)	0.419
# (920, 956)	0.326
# (920, 957)	0.379
# (920, 958)	0.187
# (920, 959)	0.317
# (920, 960)	0.339
# (920, 961)	0.262
# (920, 962)	0.337
# (920, 963)	0.267
# (920, 964)	0.331
# (920, 965)	0.393
# (920, 966)	0.330
# (920, 967)	0.174
# (920, 968)	0.357
# (920, 969)	0.345
# (920, 970)	0.292
# (920, 971)	0.296
# (920, 972)	0.379
# (920, 973)	0.326
# (920, 974)	0.386
# (920, 975)	0.402
# (920, 976)	0.002
# (920, 977)	0.001
# (920, 978)	0.002
# (920, 979)	0.003
# (920, 980)	0.001
# (920, 981)	0.037
# (920, 982)	0.010
# (920, 983)	0.003
# (920, 984)	0.016
# (920, 985)	0.002
# (920, 986)	0.002
# (920, 987)	0.038
# (920, 988)	0.001
# (920, 989)	0.008
# (920, 990)	0.028
# (920, 991)	0.364
# (920, 992)	0.364
# (920, 993)	0.372
# (920, 994)	0.354
# (920, 995)	0.367
# (920, 996)	0.359
# (920, 997)	0.369
# (920, 998)	0.359
# (920, 999)	0.364
# (921, 922)	0.427
# (921, 923)	0.414
# (921, 924)	0.417
# (921, 925)	0.432
# (921, 926)	0.401
# (921, 927)	0.435
# (921, 928)	0.425
# (921, 929)	0.411
# (921, 930)	0.436
# (921, 931)	0.354
# (921, 932)	0.351
# (921, 933)	0.397
# (921, 934)	0.432
# (921, 935)	0.413
# (921, 936)	0.409
# (921, 937)	0.377
# (921, 938)	0.310
# (921, 939)	0.428
# (921, 940)	0.363
# (921, 941)	0.355
# (921, 942)	0.436
# (921, 943)	0.393
# (921, 944)	0.381
# (921, 945)	0.394
# (921, 946)	0.424
# (921, 947)	0.350
# (921, 948)	0.412
# (921, 949)	0.381
# (921, 950)	0.297
# (921, 951)	0.421
# (921, 952)	0.417
# (921, 953)	0.236
# (921, 954)	0.400
# (921, 955)	0.447
# (921, 956)	0.385
# (921, 957)	0.426
# (921, 958)	0.268
# (921, 959)	0.371
# (921, 960)	0.413
# (921, 961)	0.354
# (921, 962)	0.412
# (921, 963)	0.348
# (921, 964)	0.384
# (921, 965)	0.427
# (921, 966)	0.423
# (921, 967)	0.252
# (921, 968)	0.405
# (921, 969)	0.404
# (921, 970)	0.376
# (921, 971)	0.363
# (921, 972)	0.420
# (921, 973)	0.397
# (921, 974)	0.380
# (921, 975)	0.416
# (921, 976)	0.003
# (921, 977)	0.001
# (921, 978)	0.002
# (921, 979)	0.004
# (921, 980)	0.001
# (921, 981)	0.053
# (921, 982)	0.014
# (921, 983)	0.004
# (921, 984)	0.025
# (921, 985)	0.003
# (921, 986)	0.003
# (921, 987)	0.055
# (921, 988)	0.001
# (921, 989)	0.013
# (921, 990)	0.042
# (921, 991)	0.328
# (921, 992)	0.326
# (921, 993)	0.334
# (921, 994)	0.312
# (921, 995)	0.331
# (921, 996)	0.347
# (921, 997)	0.336
# (921, 998)	0.314
# (921, 999)	0.327
# (922, 923)	0.446
# (922, 924)	0.411
# (922, 925)	0.501
# (922, 926)	0.431
# (922, 927)	0.417
# (922, 928)	0.473
# (922, 929)	0.445
# (922, 930)	0.414
# (922, 931)	0.390
# (922, 932)	0.388
# (922, 933)	0.376
# (922, 934)	0.474
# (922, 935)	0.391
# (922, 936)	0.442
# (922, 937)	0.427
# (922, 938)	0.347
# (922, 939)	0.421
# (922, 940)	0.421
# (922, 941)	0.383
# (922, 942)	0.422
# (922, 943)	0.439
# (922, 944)	0.425
# (922, 945)	0.496
# (922, 946)	0.405
# (922, 947)	0.395
# (922, 948)	0.405
# (922, 949)	0.444
# (922, 950)	0.347
# (922, 951)	0.403
# (922, 952)	0.460
# (922, 953)	0.271
# (922, 954)	0.437
# (922, 955)	0.425
# (922, 956)	0.403
# (922, 957)	0.416
# (922, 958)	0.310
# (922, 959)	0.424
# (922, 960)	0.407
# (922, 961)	0.396
# (922, 962)	0.465
# (922, 963)	0.389
# (922, 964)	0.416
# (922, 965)	0.415
# (922, 966)	0.408
# (922, 967)	0.282
# (922, 968)	0.428
# (922, 969)	0.386
# (922, 970)	0.414
# (922, 971)	0.413
# (922, 972)	0.397
# (922, 973)	0.435
# (922, 974)	0.399
# (922, 975)	0.385
# (922, 976)	0.004
# (922, 977)	0.001
# (922, 978)	0.003
# (922, 979)	0.004
# (922, 980)	0.001
# (922, 981)	0.059
# (922, 982)	0.016
# (922, 983)	0.004
# (922, 984)	0.028
# (922, 985)	0.004
# (922, 986)	0.003
# (922, 987)	0.063
# (922, 988)	0.001
# (922, 989)	0.015
# (922, 990)	0.048
# (922, 991)	0.310
# (922, 992)	0.311
# (922, 993)	0.317
# (922, 994)	0.295
# (922, 995)	0.316
# (922, 996)	0.336
# (922, 997)	0.318
# (922, 998)	0.297
# (922, 999)	0.310
# (923, 924)	0.397
# (923, 925)	0.450
# (923, 926)	0.409
# (923, 927)	0.412
# (923, 928)	0.454
# (923, 929)	0.444
# (923, 930)	0.407
# (923, 931)	0.383
# (923, 932)	0.373
# (923, 933)	0.375
# (923, 934)	0.449
# (923, 935)	0.395
# (923, 936)	0.431
# (923, 937)	0.403
# (923, 938)	0.338
# (923, 939)	0.409
# (923, 940)	0.398
# (923, 941)	0.374
# (923, 942)	0.413
# (923, 943)	0.415
# (923, 944)	0.407
# (923, 945)	0.421
# (923, 946)	0.393
# (923, 947)	0.398
# (923, 948)	0.395
# (923, 949)	0.416
# (923, 950)	0.344
# (923, 951)	0.398
# (923, 952)	0.448
# (923, 953)	0.268
# (923, 954)	0.425
# (923, 955)	0.415
# (923, 956)	0.398
# (923, 957)	0.410
# (923, 958)	0.304
# (923, 959)	0.417
# (923, 960)	0.401
# (923, 961)	0.384
# (923, 962)	0.441
# (923, 963)	0.374
# (923, 964)	0.401
# (923, 965)	0.401
# (923, 966)	0.391
# (923, 967)	0.275
# (923, 968)	0.418
# (923, 969)	0.386
# (923, 970)	0.396
# (923, 971)	0.406
# (923, 972)	0.394
# (923, 973)	0.429
# (923, 974)	0.393
# (923, 975)	0.386
# (923, 976)	0.003
# (923, 977)	0.001
# (923, 978)	0.003
# (923, 979)	0.004
# (923, 980)	0.001
# (923, 981)	0.058
# (923, 982)	0.015
# (923, 983)	0.004
# (923, 984)	0.027
# (923, 985)	0.004
# (923, 986)	0.003
# (923, 987)	0.061
# (923, 988)	0.001
# (923, 989)	0.015
# (923, 990)	0.046
# (923, 991)	0.309
# (923, 992)	0.310
# (923, 993)	0.318
# (923, 994)	0.296
# (923, 995)	0.313
# (923, 996)	0.333
# (923, 997)	0.319
# (923, 998)	0.298
# (923, 999)	0.309
# (924, 925)	0.412
# (924, 926)	0.381
# (924, 927)	0.435
# (924, 928)	0.402
# (924, 929)	0.396
# (924, 930)	0.421
# (924, 931)	0.347
# (924, 932)	0.333
# (924, 933)	0.407
# (924, 934)	0.405
# (924, 935)	0.405
# (924, 936)	0.402
# (924, 937)	0.372
# (924, 938)	0.297
# (924, 939)	0.420
# (924, 940)	0.352
# (924, 941)	0.334
# (924, 942)	0.429
# (924, 943)	0.367
# (924, 944)	0.370
# (924, 945)	0.371
# (924, 946)	0.409
# (924, 947)	0.332
# (924, 948)	0.397
# (924, 949)	0.363
# (924, 950)	0.283
# (924, 951)	0.410
# (924, 952)	0.407
# (924, 953)	0.224
# (924, 954)	0.395
# (924, 955)	0.429
# (924, 956)	0.367
# (924, 957)	0.424
# (924, 958)	0.252
# (924, 959)	0.360
# (924, 960)	0.400
# (924, 961)	0.336
# (924, 962)	0.391
# (924, 963)	0.334
# (924, 964)	0.375
# (924, 965)	0.430
# (924, 966)	0.407
# (924, 967)	0.236
# (924, 968)	0.393
# (924, 969)	0.393
# (924, 970)	0.355
# (924, 971)	0.354
# (924, 972)	0.403
# (924, 973)	0.378
# (924, 974)	0.381
# (924, 975)	0.406
# (924, 976)	0.003
# (924, 977)	0.001
# (924, 978)	0.002
# (924, 979)	0.003
# (924, 980)	0.001
# (924, 981)	0.049
# (924, 982)	0.013
# (924, 983)	0.003
# (924, 984)	0.023
# (924, 985)	0.003
# (924, 986)	0.002
# (924, 987)	0.052
# (924, 988)	0.001
# (924, 989)	0.012
# (924, 990)	0.039
# (924, 991)	0.334
# (924, 992)	0.334
# (924, 993)	0.343
# (924, 994)	0.319
# (924, 995)	0.337
# (924, 996)	0.351
# (924, 997)	0.340
# (924, 998)	0.322
# (924, 999)	0.335
# (925, 926)	0.461
# (925, 927)	0.437
# (925, 928)	0.474
# (925, 929)	0.458
# (925, 930)	0.424
# (925, 931)	0.381
# (925, 932)	0.387
# (925, 933)	0.384
# (925, 934)	0.489
# (925, 935)	0.402
# (925, 936)	0.445
# (925, 937)	0.417
# (925, 938)	0.341
# (925, 939)	0.424
# (925, 940)	0.417
# (925, 941)	0.386
# (925, 942)	0.425
# (925, 943)	0.442
# (925, 944)	0.417
# (925, 945)	0.490
# (925, 946)	0.412
# (925, 947)	0.392
# (925, 948)	0.408
# (925, 949)	0.431
# (925, 950)	0.328
# (925, 951)	0.410
# (925, 952)	0.464
# (925, 953)	0.262
# (925, 954)	0.439
# (925, 955)	0.451
# (925, 956)	0.413
# (925, 957)	0.424
# (925, 958)	0.303
# (925, 959)	0.420
# (925, 960)	0.410
# (925, 961)	0.399
# (925, 962)	0.452
# (925, 963)	0.410
# (925, 964)	0.412
# (925, 965)	0.423
# (925, 966)	0.407
# (925, 967)	0.275
# (925, 968)	0.431
# (925, 969)	0.392
# (925, 970)	0.413
# (925, 971)	0.396
# (925, 972)	0.408
# (925, 973)	0.444
# (925, 974)	0.406
# (925, 975)	0.414
# (925, 976)	0.004
# (925, 977)	0.002
# (925, 978)	0.003
# (925, 979)	0.004
# (925, 980)	0.001
# (925, 981)	0.059
# (925, 982)	0.015
# (925, 983)	0.004
# (925, 984)	0.027
# (925, 985)	0.004
# (925, 986)	0.003
# (925, 987)	0.061
# (925, 988)	0.001
# (925, 989)	0.015
# (925, 990)	0.046
# (925, 991)	0.325
# (925, 992)	0.327
# (925, 993)	0.336
# (925, 994)	0.311
# (925, 995)	0.332
# (925, 996)	0.350
# (925, 997)	0.337
# (925, 998)	0.312
# (925, 999)	0.326
# (926, 927)	0.395
# (926, 928)	0.438
# (926, 929)	0.436
# (926, 930)	0.388
# (926, 931)	0.373
# (926, 932)	0.394
# (926, 933)	0.340
# (926, 934)	0.439
# (926, 935)	0.372
# (926, 936)	0.412
# (926, 937)	0.412
# (926, 938)	0.355
# (926, 939)	0.406
# (926, 940)	0.413
# (926, 941)	0.404
# (926, 942)	0.411
# (926, 943)	0.429
# (926, 944)	0.416
# (926, 945)	0.428
# (926, 946)	0.393
# (926, 947)	0.399
# (926, 948)	0.399
# (926, 949)	0.423
# (926, 950)	0.355
# (926, 951)	0.390
# (926, 952)	0.420
# (926, 953)	0.286
# (926, 954)	0.403
# (926, 955)	0.399
# (926, 956)	0.392
# (926, 957)	0.396
# (926, 958)	0.323
# (926, 959)	0.402
# (926, 960)	0.399
# (926, 961)	0.410
# (926, 962)	0.435
# (926, 963)	0.401
# (926, 964)	0.398
# (926, 965)	0.389
# (926, 966)	0.401
# (926, 967)	0.306
# (926, 968)	0.401
# (926, 969)	0.383
# (926, 970)	0.415
# (926, 971)	0.399
# (926, 972)	0.390
# (926, 973)	0.423
# (926, 974)	0.359
# (926, 975)	0.362
# (926, 976)	0.004
# (926, 977)	0.002
# (926, 978)	0.003
# (926, 979)	0.005
# (926, 980)	0.001
# (926, 981)	0.066
# (926, 982)	0.018
# (926, 983)	0.005
# (926, 984)	0.031
# (926, 985)	0.004
# (926, 986)	0.003
# (926, 987)	0.071
# (926, 988)	0.001
# (926, 989)	0.018
# (926, 990)	0.054
# (926, 991)	0.278
# (926, 992)	0.278
# (926, 993)	0.288
# (926, 994)	0.264
# (926, 995)	0.284
# (926, 996)	0.309
# (926, 997)	0.288
# (926, 998)	0.265
# (926, 999)	0.279
# (927, 928)	0.423
# (927, 929)	0.409
# (927, 930)	0.442
# (927, 931)	0.348
# (927, 932)	0.336
# (927, 933)	0.414
# (927, 934)	0.423
# (927, 935)	0.424
# (927, 936)	0.410
# (927, 937)	0.370
# (927, 938)	0.297
# (927, 939)	0.429
# (927, 940)	0.357
# (927, 941)	0.338
# (927, 942)	0.434
# (927, 943)	0.378
# (927, 944)	0.370
# (927, 945)	0.378
# (927, 946)	0.418
# (927, 947)	0.341
# (927, 948)	0.404
# (927, 949)	0.372
# (927, 950)	0.282
# (927, 951)	0.423
# (927, 952)	0.422
# (927, 953)	0.223
# (927, 954)	0.404
# (927, 955)	0.453
# (927, 956)	0.380
# (927, 957)	0.430
# (927, 958)	0.250
# (927, 959)	0.367
# (927, 960)	0.409
# (927, 961)	0.342
# (927, 962)	0.402
# (927, 963)	0.335
# (927, 964)	0.379
# (927, 965)	0.430
# (927, 966)	0.407
# (927, 967)	0.236
# (927, 968)	0.403
# (927, 969)	0.402
# (927, 970)	0.362
# (927, 971)	0.351
# (927, 972)	0.415
# (927, 973)	0.388
# (927, 974)	0.391
# (927, 975)	0.419
# (927, 976)	0.003
# (927, 977)	0.001
# (927, 978)	0.002
# (927, 979)	0.003
# (927, 980)	0.001
# (927, 981)	0.049
# (927, 982)	0.013
# (927, 983)	0.003
# (927, 984)	0.023
# (927, 985)	0.003
# (927, 986)	0.002
# (927, 987)	0.052
# (927, 988)	0.001
# (927, 989)	0.012
# (927, 990)	0.039
# (927, 991)	0.347
# (927, 992)	0.346
# (927, 993)	0.357
# (927, 994)	0.330
# (927, 995)	0.351
# (927, 996)	0.363
# (927, 997)	0.355
# (927, 998)	0.334
# (927, 999)	0.346
# (928, 929)	0.458
# (928, 930)	0.415
# (928, 931)	0.382
# (928, 932)	0.390
# (928, 933)	0.374
# (928, 934)	0.482
# (928, 935)	0.395
# (928, 936)	0.440
# (928, 937)	0.421
# (928, 938)	0.340
# (928, 939)	0.422
# (928, 940)	0.402
# (928, 941)	0.385
# (928, 942)	0.421
# (928, 943)	0.442
# (928, 944)	0.414
# (928, 945)	0.449
# (928, 946)	0.402
# (928, 947)	0.394
# (928, 948)	0.405
# (928, 949)	0.440
# (928, 950)	0.337
# (928, 951)	0.401
# (928, 952)	0.455
# (928, 953)	0.274
# (928, 954)	0.435
# (928, 955)	0.431
# (928, 956)	0.402
# (928, 957)	0.417
# (928, 958)	0.303
# (928, 959)	0.415
# (928, 960)	0.410
# (928, 961)	0.406
# (928, 962)	0.463
# (928, 963)	0.381
# (928, 964)	0.412
# (928, 965)	0.409
# (928, 966)	0.406
# (928, 967)	0.279
# (928, 968)	0.428
# (928, 969)	0.391
# (928, 970)	0.412
# (928, 971)	0.401
# (928, 972)	0.401
# (928, 973)	0.436
# (928, 974)	0.397
# (928, 975)	0.386
# (928, 976)	0.004
# (928, 977)	0.002
# (928, 978)	0.003
# (928, 979)	0.004
# (928, 980)	0.001
# (928, 981)	0.061
# (928, 982)	0.016
# (928, 983)	0.004
# (928, 984)	0.028
# (928, 985)	0.004
# (928, 986)	0.002
# (928, 987)	0.063
# (928, 988)	0.001
# (928, 989)	0.016
# (928, 990)	0.047
# (928, 991)	0.316
# (928, 992)	0.318
# (928, 993)	0.325
# (928, 994)	0.300
# (928, 995)	0.322
# (928, 996)	0.344
# (928, 997)	0.327
# (928, 998)	0.302
# (928, 999)	0.316
# (929, 930)	0.406
# (929, 931)	0.392
# (929, 932)	0.388
# (929, 933)	0.367
# (929, 934)	0.457
# (929, 935)	0.391
# (929, 936)	0.432
# (929, 937)	0.414
# (929, 938)	0.346
# (929, 939)	0.414
# (929, 940)	0.408
# (929, 941)	0.389
# (929, 942)	0.416
# (929, 943)	0.424
# (929, 944)	0.426
# (929, 945)	0.431
# (929, 946)	0.401
# (929, 947)	0.410
# (929, 948)	0.405
# (929, 949)	0.426
# (929, 950)	0.352
# (929, 951)	0.400
# (929, 952)	0.447
# (929, 953)	0.278
# (929, 954)	0.440
# (929, 955)	0.423
# (929, 956)	0.408
# (929, 957)	0.418
# (929, 958)	0.317
# (929, 959)	0.422
# (929, 960)	0.408
# (929, 961)	0.403
# (929, 962)	0.444
# (929, 963)	0.401
# (929, 964)	0.411
# (929, 965)	0.407
# (929, 966)	0.398
# (929, 967)	0.295
# (929, 968)	0.422
# (929, 969)	0.392
# (929, 970)	0.406
# (929, 971)	0.407
# (929, 972)	0.398
# (929, 973)	0.442
# (929, 974)	0.388
# (929, 975)	0.379
# (929, 976)	0.004
# (929, 977)	0.002
# (929, 978)	0.003
# (929, 979)	0.004
# (929, 980)	0.001
# (929, 981)	0.061
# (929, 982)	0.016
# (929, 983)	0.004
# (929, 984)	0.029
# (929, 985)	0.004
# (929, 986)	0.003
# (929, 987)	0.064
# (929, 988)	0.001
# (929, 989)	0.016
# (929, 990)	0.049
# (929, 991)	0.301
# (929, 992)	0.302
# (929, 993)	0.310
# (929, 994)	0.285
# (929, 995)	0.306
# (929, 996)	0.327
# (929, 997)	0.310
# (929, 998)	0.287
# (929, 999)	0.300
# (930, 931)	0.351
# (930, 932)	0.341
# (930, 933)	0.410
# (930, 934)	0.420
# (930, 935)	0.412
# (930, 936)	0.408
# (930, 937)	0.370
# (930, 938)	0.293
# (930, 939)	0.426
# (930, 940)	0.354
# (930, 941)	0.337
# (930, 942)	0.435
# (930, 943)	0.371
# (930, 944)	0.367
# (930, 945)	0.376
# (930, 946)	0.418
# (930, 947)	0.332
# (930, 948)	0.396
# (930, 949)	0.367
# (930, 950)	0.279
# (930, 951)	0.408
# (930, 952)	0.418
# (930, 953)	0.223
# (930, 954)	0.406
# (930, 955)	0.448
# (930, 956)	0.374
# (930, 957)	0.425
# (930, 958)	0.249
# (930, 959)	0.367
# (930, 960)	0.408
# (930, 961)	0.334
# (930, 962)	0.407
# (930, 963)	0.334
# (930, 964)	0.375
# (930, 965)	0.424
# (930, 966)	0.402
# (930, 967)	0.234
# (930, 968)	0.402
# (930, 969)	0.401
# (930, 970)	0.360
# (930, 971)	0.353
# (930, 972)	0.411
# (930, 973)	0.390
# (930, 974)	0.392
# (930, 975)	0.413
# (930, 976)	0.003
# (930, 977)	0.001
# (930, 978)	0.002
# (930, 979)	0.003
# (930, 980)	0.001
# (930, 981)	0.049
# (930, 982)	0.013
# (930, 983)	0.003
# (930, 984)	0.022
# (930, 985)	0.003
# (930, 986)	0.002
# (930, 987)	0.052
# (930, 988)	0.001
# (930, 989)	0.012
# (930, 990)	0.039
# (930, 991)	0.348
# (930, 992)	0.347
# (930, 993)	0.357
# (930, 994)	0.332
# (930, 995)	0.352
# (930, 996)	0.363
# (930, 997)	0.354
# (930, 998)	0.335
# (930, 999)	0.347
# (931, 932)	0.369
# (931, 933)	0.317
# (931, 934)	0.371
# (931, 935)	0.342
# (931, 936)	0.360
# (931, 937)	0.376
# (931, 938)	0.329
# (931, 939)	0.361
# (931, 940)	0.390
# (931, 941)	0.357
# (931, 942)	0.370
# (931, 943)	0.382
# (931, 944)	0.378
# (931, 945)	0.388
# (931, 946)	0.356
# (931, 947)	0.369
# (931, 948)	0.363
# (931, 949)	0.380
# (931, 950)	0.340
# (931, 951)	0.358
# (931, 952)	0.377
# (931, 953)	0.293
# (931, 954)	0.374
# (931, 955)	0.353
# (931, 956)	0.359
# (931, 957)	0.356
# (931, 958)	0.303
# (931, 959)	0.386
# (931, 960)	0.362
# (931, 961)	0.363
# (931, 962)	0.381
# (931, 963)	0.361
# (931, 964)	0.372
# (931, 965)	0.352
# (931, 966)	0.357
# (931, 967)	0.291
# (931, 968)	0.367
# (931, 969)	0.346
# (931, 970)	0.376
# (931, 971)	0.383
# (931, 972)	0.357
# (931, 973)	0.394
# (931, 974)	0.341
# (931, 975)	0.337
# (931, 976)	0.004
# (931, 977)	0.002
# (931, 978)	0.003
# (931, 979)	0.004
# (931, 980)	0.001
# (931, 981)	0.061
# (931, 982)	0.017
# (931, 983)	0.005
# (931, 984)	0.029
# (931, 985)	0.004
# (931, 986)	0.003
# (931, 987)	0.065
# (931, 988)	0.001
# (931, 989)	0.016
# (931, 990)	0.050
# (931, 991)	0.256
# (931, 992)	0.258
# (931, 993)	0.264
# (931, 994)	0.244
# (931, 995)	0.261
# (931, 996)	0.278
# (931, 997)	0.265
# (931, 998)	0.246
# (931, 999)	0.255
# (932, 933)	0.290
# (932, 934)	0.393
# (932, 935)	0.323
# (932, 936)	0.362
# (932, 937)	0.385
# (932, 938)	0.357
# (932, 939)	0.361
# (932, 940)	0.396
# (932, 941)	0.383
# (932, 942)	0.363
# (932, 943)	0.407
# (932, 944)	0.398
# (932, 945)	0.396
# (932, 946)	0.359
# (932, 947)	0.391
# (932, 948)	0.368
# (932, 949)	0.411
# (932, 950)	0.363
# (932, 951)	0.358
# (932, 952)	0.381
# (932, 953)	0.316
# (932, 954)	0.367
# (932, 955)	0.337
# (932, 956)	0.364
# (932, 957)	0.352
# (932, 958)	0.343
# (932, 959)	0.387
# (932, 960)	0.371
# (932, 961)	0.387
# (932, 962)	0.403
# (932, 963)	0.387
# (932, 964)	0.363
# (932, 965)	0.348
# (932, 966)	0.368
# (932, 967)	0.328
# (932, 968)	0.353
# (932, 969)	0.339
# (932, 970)	0.390
# (932, 971)	0.405
# (932, 972)	0.351
# (932, 973)	0.405
# (932, 974)	0.312
# (932, 975)	0.313
# (932, 976)	0.005
# (932, 977)	0.002
# (932, 978)	0.004
# (932, 979)	0.005
# (932, 980)	0.001
# (932, 981)	0.071
# (932, 982)	0.021
# (932, 983)	0.005
# (932, 984)	0.035
# (932, 985)	0.005
# (932, 986)	0.003
# (932, 987)	0.080
# (932, 988)	0.001
# (932, 989)	0.021
# (932, 990)	0.063
# (932, 991)	0.232
# (932, 992)	0.233
# (932, 993)	0.241
# (932, 994)	0.219
# (932, 995)	0.237
# (932, 996)	0.262
# (932, 997)	0.240
# (932, 998)	0.222
# (932, 999)	0.231
# (933, 934)	0.373
# (933, 935)	0.401
# (933, 936)	0.382
# (933, 937)	0.331
# (933, 938)	0.254
# (933, 939)	0.389
# (933, 940)	0.310
# (933, 941)	0.294
# (933, 942)	0.400
# (933, 943)	0.320
# (933, 944)	0.330
# (933, 945)	0.332
# (933, 946)	0.383
# (933, 947)	0.297
# (933, 948)	0.358
# (933, 949)	0.321
# (933, 950)	0.240
# (933, 951)	0.382
# (933, 952)	0.391
# (933, 953)	0.189
# (933, 954)	0.381
# (933, 955)	0.423
# (933, 956)	0.347
# (933, 957)	0.400
# (933, 958)	0.212
# (933, 959)	0.333
# (933, 960)	0.369
# (933, 961)	0.289
# (933, 962)	0.356
# (933, 963)	0.294
# (933, 964)	0.350
# ...
# (956, 962)	0.415
# (956, 963)	0.362
# (956, 964)	0.376
# (956, 965)	0.381
# (956, 966)	0.372
# (956, 967)	0.280
# (956, 968)	0.387
# (956, 969)	0.368
# (956, 970)	0.382
# (956, 971)	0.377
# (956, 972)	0.378
# (956, 973)	0.398
# (956, 974)	0.352
# (956, 975)	0.356
# (956, 976)	0.004
# (956, 977)	0.001
# (956, 978)	0.003
# (956, 979)	0.004
# (956, 980)	0.001
# (956, 981)	0.058
# (956, 982)	0.016
# (956, 983)	0.004
# (956, 984)	0.027
# (956, 985)	0.004
# (956, 986)	0.002
# (956, 987)	0.062
# (956, 988)	0.001
# (956, 989)	0.016
# (956, 990)	0.047
# (956, 991)	0.281
# (956, 992)	0.282
# (956, 993)	0.290
# (956, 994)	0.266
# (956, 995)	0.285
# (956, 996)	0.305
# (956, 997)	0.287
# (956, 998)	0.268
# (956, 999)	0.279
# (957, 958)	0.269
# (957, 959)	0.377
# (957, 960)	0.414
# (957, 961)	0.351
# (957, 962)	0.406
# (957, 963)	0.354
# (957, 964)	0.387
# (957, 965)	0.430
# (957, 966)	0.414
# (957, 967)	0.252
# (957, 968)	0.405
# (957, 969)	0.403
# (957, 970)	0.372
# (957, 971)	0.371
# (957, 972)	0.419
# (957, 973)	0.400
# (957, 974)	0.382
# (957, 975)	0.403
# (957, 976)	0.003
# (957, 977)	0.001
# (957, 978)	0.002
# (957, 979)	0.004
# (957, 980)	0.001
# (957, 981)	0.052
# (957, 982)	0.014
# (957, 983)	0.003
# (957, 984)	0.024
# (957, 985)	0.003
# (957, 986)	0.002
# (957, 987)	0.054
# (957, 988)	0.001
# (957, 989)	0.013
# (957, 990)	0.041
# (957, 991)	0.322
# (957, 992)	0.323
# (957, 993)	0.332
# (957, 994)	0.310
# (957, 995)	0.327
# (957, 996)	0.344
# (957, 997)	0.331
# (957, 998)	0.310
# (957, 999)	0.323
# (958, 959)	0.338
# (958, 960)	0.300
# (958, 961)	0.346
# (958, 962)	0.331
# (958, 963)	0.348
# (958, 964)	0.289
# (958, 965)	0.259
# (958, 966)	0.297
# (958, 967)	0.376
# (958, 968)	0.281
# (958, 969)	0.270
# (958, 970)	0.327
# (958, 971)	0.352
# (958, 972)	0.270
# (958, 973)	0.337
# (958, 974)	0.223
# (958, 975)	0.229
# (958, 976)	0.006
# (958, 977)	0.003
# (958, 978)	0.005
# (958, 979)	0.006
# (958, 980)	0.001
# (958, 981)	0.087
# (958, 982)	0.027
# (958, 983)	0.006
# (958, 984)	0.043
# (958, 985)	0.006
# (958, 986)	0.004
# (958, 987)	0.098
# (958, 988)	0.001
# (958, 989)	0.029
# (958, 990)	0.081
# (958, 991)	0.162
# (958, 992)	0.162
# (958, 993)	0.167
# (958, 994)	0.153
# (958, 995)	0.166
# (958, 996)	0.188
# (958, 997)	0.168
# (958, 998)	0.154
# (958, 999)	0.162
# (959, 960)	0.382
# (959, 961)	0.390
# (959, 962)	0.440
# (959, 963)	0.393
# (959, 964)	0.399
# (959, 965)	0.379
# (959, 966)	0.373
# (959, 967)	0.303
# (959, 968)	0.388
# (959, 969)	0.360
# (959, 970)	0.399
# (959, 971)	0.412
# (959, 972)	0.374
# (959, 973)	0.431
# (959, 974)	0.375
# (959, 975)	0.339
# (959, 976)	0.004
# (959, 977)	0.002
# (959, 978)	0.003
# (959, 979)	0.005
# (959, 980)	0.001
# (959, 981)	0.066
# (959, 982)	0.017
# (959, 983)	0.005
# (959, 984)	0.032
# (959, 985)	0.004
# (959, 986)	0.003
# (959, 987)	0.070
# (959, 988)	0.001
# (959, 989)	0.017
# (959, 990)	0.053
# (959, 991)	0.265
# (959, 992)	0.267
# (959, 993)	0.277
# (959, 994)	0.252
# (959, 995)	0.272
# (959, 996)	0.293
# (959, 997)	0.274
# (959, 998)	0.254
# (959, 999)	0.265
# (960, 961)	0.378
# (960, 962)	0.408
# (960, 963)	0.367
# (960, 964)	0.379
# (960, 965)	0.406
# (960, 966)	0.418
# (960, 967)	0.284
# (960, 968)	0.393
# (960, 969)	0.399
# (960, 970)	0.388
# (960, 971)	0.384
# (960, 972)	0.415
# (960, 973)	0.407
# (960, 974)	0.354
# (960, 975)	0.381
# (960, 976)	0.004
# (960, 977)	0.002
# (960, 978)	0.003
# (960, 979)	0.004
# (960, 980)	0.001
# (960, 981)	0.059
# (960, 982)	0.016
# (960, 983)	0.004
# (960, 984)	0.027
# (960, 985)	0.004
# (960, 986)	0.002
# (960, 987)	0.062
# (960, 988)	0.001
# (960, 989)	0.016
# (960, 990)	0.048
# (960, 991)	0.286
# (960, 992)	0.286
# (960, 993)	0.294
# (960, 994)	0.271
# (960, 995)	0.290
# (960, 996)	0.313
# (960, 997)	0.294
# (960, 998)	0.275
# (960, 999)	0.285
# (961, 962)	0.396
# (961, 963)	0.388
# (961, 964)	0.371
# (961, 965)	0.342
# (961, 966)	0.373
# (961, 967)	0.340
# (961, 968)	0.383
# (961, 969)	0.350
# (961, 970)	0.411
# (961, 971)	0.382
# (961, 972)	0.351
# (961, 973)	0.402
# (961, 974)	0.312
# (961, 975)	0.314
# (961, 976)	0.005
# (961, 977)	0.002
# (961, 978)	0.004
# (961, 979)	0.005
# (961, 980)	0.001
# (961, 981)	0.076
# (961, 982)	0.021
# (961, 983)	0.005
# (961, 984)	0.036
# (961, 985)	0.005
# (961, 986)	0.003
# (961, 987)	0.081
# (961, 988)	0.001
# (961, 989)	0.022
# (961, 990)	0.063
# (961, 991)	0.228
# (961, 992)	0.230
# (961, 993)	0.236
# (961, 994)	0.216
# (961, 995)	0.235
# (961, 996)	0.261
# (961, 997)	0.238
# (961, 998)	0.217
# (961, 999)	0.230
# (962, 963)	0.401
# (962, 964)	0.403
# (962, 965)	0.407
# (962, 966)	0.401
# (962, 967)	0.295
# (962, 968)	0.412
# (962, 969)	0.386
# (962, 970)	0.408
# (962, 971)	0.424
# (962, 972)	0.393
# (962, 973)	0.449
# (962, 974)	0.384
# (962, 975)	0.363
# (962, 976)	0.004
# (962, 977)	0.001
# (962, 978)	0.003
# (962, 979)	0.004
# (962, 980)	0.001
# (962, 981)	0.064
# (962, 982)	0.017
# (962, 983)	0.005
# (962, 984)	0.030
# (962, 985)	0.004
# (962, 986)	0.003
# (962, 987)	0.069
# (962, 988)	0.001
# (962, 989)	0.017
# (962, 990)	0.052
# (962, 991)	0.296
# (962, 992)	0.296
# (962, 993)	0.303
# (962, 994)	0.279
# (962, 995)	0.302
# (962, 996)	0.324
# (962, 997)	0.305
# (962, 998)	0.281
# (962, 999)	0.294
# (963, 964)	0.378
# (963, 965)	0.342
# (963, 966)	0.372
# (963, 967)	0.323
# (963, 968)	0.357
# (963, 969)	0.348
# (963, 970)	0.391
# (963, 971)	0.397
# (963, 972)	0.346
# (963, 973)	0.413
# (963, 974)	0.311
# (963, 975)	0.310
# (963, 976)	0.005
# (963, 977)	0.002
# (963, 978)	0.004
# (963, 979)	0.005
# (963, 980)	0.001
# (963, 981)	0.073
# (963, 982)	0.020
# (963, 983)	0.006
# (963, 984)	0.036
# (963, 985)	0.005
# (963, 986)	0.003
# (963, 987)	0.079
# (963, 988)	0.001
# (963, 989)	0.022
# (963, 990)	0.062
# (963, 991)	0.231
# (963, 992)	0.232
# (963, 993)	0.239
# (963, 994)	0.219
# (963, 995)	0.236
# (963, 996)	0.260
# (963, 997)	0.238
# (963, 998)	0.220
# (963, 999)	0.231
# (964, 965)	0.383
# (964, 966)	0.377
# (964, 967)	0.276
# (964, 968)	0.385
# (964, 969)	0.370
# (964, 970)	0.390
# (964, 971)	0.379
# (964, 972)	0.376
# (964, 973)	0.408
# (964, 974)	0.381
# (964, 975)	0.357
# (964, 976)	0.004
# (964, 977)	0.001
# (964, 978)	0.003
# (964, 979)	0.004
# (964, 980)	0.001
# (964, 981)	0.060
# (964, 982)	0.016
# (964, 983)	0.004
# (964, 984)	0.027
# (964, 985)	0.004
# (964, 986)	0.003
# (964, 987)	0.062
# (964, 988)	0.001
# (964, 989)	0.015
# (964, 990)	0.048
# (964, 991)	0.290
# (964, 992)	0.290
# (964, 993)	0.299
# (964, 994)	0.276
# (964, 995)	0.296
# (964, 996)	0.315
# (964, 997)	0.298
# (964, 998)	0.278
# (964, 999)	0.290
# (965, 966)	0.406
# (965, 967)	0.241
# (965, 968)	0.403
# (965, 969)	0.392
# (965, 970)	0.368
# (965, 971)	0.362
# (965, 972)	0.415
# (965, 973)	0.394
# (965, 974)	0.390
# (965, 975)	0.403
# (965, 976)	0.003
# (965, 977)	0.001
# (965, 978)	0.002
# (965, 979)	0.004
# (965, 980)	0.001
# (965, 981)	0.050
# (965, 982)	0.013
# (965, 983)	0.004
# (965, 984)	0.023
# (965, 985)	0.003
# (965, 986)	0.002
# (965, 987)	0.053
# (965, 988)	0.001
# (965, 989)	0.012
# (965, 990)	0.041
# (965, 991)	0.334
# (965, 992)	0.334
# (965, 993)	0.344
# (965, 994)	0.319
# (965, 995)	0.338
# (965, 996)	0.353
# (965, 997)	0.341
# (965, 998)	0.323
# (965, 999)	0.334
# (966, 967)	0.287
# (966, 968)	0.382
# (966, 969)	0.394
# (966, 970)	0.386
# (966, 971)	0.377
# (966, 972)	0.420
# (966, 973)	0.401
# (966, 974)	0.344
# (966, 975)	0.375
# (966, 976)	0.004
# (966, 977)	0.002
# (966, 978)	0.003
# (966, 979)	0.004
# (966, 980)	0.001
# (966, 981)	0.060
# (966, 982)	0.016
# (966, 983)	0.005
# (966, 984)	0.028
# (966, 985)	0.004
# (966, 986)	0.003
# (966, 987)	0.065
# (966, 988)	0.001
# (966, 989)	0.016
# (966, 990)	0.050
# (966, 991)	0.279
# (966, 992)	0.278
# (966, 993)	0.287
# (966, 994)	0.263
# (966, 995)	0.281
# (966, 996)	0.305
# (966, 997)	0.286
# (966, 998)	0.267
# (966, 999)	0.277
# (967, 968)	0.270
# (967, 969)	0.259
# (967, 970)	0.313
# (967, 971)	0.314
# (967, 972)	0.257
# (967, 973)	0.315
# (967, 974)	0.209
# (967, 975)	0.216
# (967, 976)	0.006
# (967, 977)	0.002
# (967, 978)	0.005
# (967, 979)	0.007
# (967, 980)	0.001
# (967, 981)	0.086
# (967, 982)	0.027
# (967, 983)	0.007
# (967, 984)	0.046
# (967, 985)	0.007
# (967, 986)	0.004
# (967, 987)	0.098
# (967, 988)	0.001
# (967, 989)	0.030
# (967, 990)	0.081
# (967, 991)	0.150
# (967, 992)	0.150
# (967, 993)	0.155
# (967, 994)	0.141
# (967, 995)	0.153
# (967, 996)	0.174
# (967, 997)	0.156
# (967, 998)	0.142
# (967, 999)	0.150
# (968, 969)	0.383
# (968, 970)	0.379
# (968, 971)	0.372
# (968, 972)	0.390
# (968, 973)	0.402
# (968, 974)	0.388
# (968, 975)	0.388
# (968, 976)	0.003
# (968, 977)	0.001
# (968, 978)	0.002
# (968, 979)	0.004
# (968, 980)	0.001
# (968, 981)	0.054
# (968, 982)	0.015
# (968, 983)	0.004
# (968, 984)	0.025
# (968, 985)	0.003
# (968, 986)	0.002
# (968, 987)	0.057
# (968, 988)	0.001
# (968, 989)	0.014
# (968, 990)	0.043
# (968, 991)	0.322
# (968, 992)	0.323
# (968, 993)	0.329
# (968, 994)	0.309
# (968, 995)	0.328
# (968, 996)	0.342
# (968, 997)	0.330
# (968, 998)	0.311
# (968, 999)	0.322
# (969, 970)	0.363
# (969, 971)	0.356
# (969, 972)	0.396
# (969, 973)	0.382
# (969, 974)	0.354
# (969, 975)	0.381
# (969, 976)	0.003
# (969, 977)	0.001
# (969, 978)	0.002
# (969, 979)	0.004
# (969, 980)	0.001
# (969, 981)	0.053
# (969, 982)	0.014
# (969, 983)	0.004
# (969, 984)	0.025
# (969, 985)	0.003
# (969, 986)	0.002
# (969, 987)	0.057
# (969, 988)	0.001
# (969, 989)	0.014
# (969, 990)	0.044
# (969, 991)	0.300
# (969, 992)	0.300
# (969, 993)	0.309
# (969, 994)	0.288
# (969, 995)	0.304
# (969, 996)	0.322
# (969, 997)	0.309
# (969, 998)	0.291
# (969, 999)	0.301
# (970, 971)	0.417
# (970, 972)	0.371
# (970, 973)	0.410
# (970, 974)	0.336
# (970, 975)	0.333
# (970, 976)	0.004
# (970, 977)	0.002
# (970, 978)	0.003
# (970, 979)	0.005
# (970, 980)	0.001
# (970, 981)	0.069
# (970, 982)	0.019
# (970, 983)	0.005
# (970, 984)	0.034
# (970, 985)	0.004
# (970, 986)	0.003
# (970, 987)	0.074
# (970, 988)	0.001
# (970, 989)	0.020
# (970, 990)	0.059
# (970, 991)	0.255
# (970, 992)	0.255
# (970, 993)	0.263
# (970, 994)	0.241
# (970, 995)	0.260
# (970, 996)	0.282
# (970, 997)	0.262
# (970, 998)	0.243
# (970, 999)	0.253
# (971, 972)	0.363
# (971, 973)	0.421
# (971, 974)	0.335
# (971, 975)	0.328
# (971, 976)	0.004
# (971, 977)	0.002
# (971, 978)	0.003
# (971, 979)	0.005
# (971, 980)	0.001
# (971, 981)	0.067
# (971, 982)	0.019
# (971, 983)	0.005
# (971, 984)	0.033
# (971, 985)	0.004
# (971, 986)	0.003
# (971, 987)	0.073
# (971, 988)	0.001
# (971, 989)	0.019
# (971, 990)	0.058
# (971, 991)	0.249
# (971, 992)	0.251
# (971, 993)	0.257
# (971, 994)	0.237
# (971, 995)	0.254
# (971, 996)	0.276
# (971, 997)	0.257
# (971, 998)	0.237
# (971, 999)	0.249
# (972, 973)	0.387
# (972, 974)	0.371
# (972, 975)	0.408
# (972, 976)	0.003
# (972, 977)	0.001
# (972, 978)	0.002
# (972, 979)	0.003
# (972, 980)	0.001
# (972, 981)	0.053
# (972, 982)	0.014
# (972, 983)	0.004
# (972, 984)	0.025
# (972, 985)	0.003
# (972, 986)	0.002
# (972, 987)	0.056
# (972, 988)	0.001
# (972, 989)	0.014
# (972, 990)	0.044
# (972, 991)	0.307
# (972, 992)	0.308
# (972, 993)	0.315
# (972, 994)	0.294
# (972, 995)	0.311
# (972, 996)	0.329
# (972, 997)	0.315
# (972, 998)	0.297
# (972, 999)	0.305
# (973, 974)	0.370
# (973, 975)	0.355
# (973, 976)	0.004
# (973, 977)	0.002
# (973, 978)	0.003
# (973, 979)	0.005
# (973, 980)	0.001
# (973, 981)	0.066
# (973, 982)	0.018
# (973, 983)	0.004
# (973, 984)	0.031
# (973, 985)	0.004
# (973, 986)	0.003
# (973, 987)	0.070
# (973, 988)	0.001
# (973, 989)	0.018
# (973, 990)	0.054
# (973, 991)	0.281
# (973, 992)	0.280
# (973, 993)	0.289
# (973, 994)	0.266
# (973, 995)	0.287
# (973, 996)	0.309
# (973, 997)	0.289
# (973, 998)	0.266
# (973, 999)	0.279
# (974, 975)	0.389
# (974, 976)	0.003
# (974, 977)	0.001
# (974, 978)	0.002
# (974, 979)	0.003
# (974, 980)	0.001
# (974, 981)	0.044
# (974, 982)	0.012
# (974, 983)	0.003
# (974, 984)	0.020
# (974, 985)	0.003
# (974, 986)	0.002
# (974, 987)	0.046
# (974, 988)	0.001
# (974, 989)	0.010
# (974, 990)	0.034
# (974, 991)	0.341
# (974, 992)	0.341
# (974, 993)	0.352
# (974, 994)	0.330
# (974, 995)	0.344
# (974, 996)	0.349
# (974, 997)	0.347
# (974, 998)	0.333
# (974, 999)	0.341
# (975, 976)	0.003
# (975, 977)	0.001
# (975, 978)	0.002
# (975, 979)	0.003
# (975, 980)	0.001
# (975, 981)	0.044
# (975, 982)	0.012
# (975, 983)	0.003
# (975, 984)	0.020
# (975, 985)	0.003
# (975, 986)	0.002
# (975, 987)	0.047
# (975, 988)	0.001
# (975, 989)	0.011
# (975, 990)	0.035
# (975, 991)	0.335
# (975, 992)	0.333
# (975, 993)	0.341
# (975, 994)	0.323
# (975, 995)	0.338
# (975, 996)	0.347
# (975, 997)	0.341
# (975, 998)	0.326
# (975, 999)	0.335
# (976, 977)	0.085
# (976, 978)	0.047
# (976, 979)	0.186
# (976, 980)	0.058
# (976, 981)	0.055
# (976, 982)	0.014
# (976, 983)	0.068
# (976, 984)	0.061
# (976, 985)	0.053
# (976, 986)	0.021
# (976, 987)	0.030
# (976, 988)	0.016
# (976, 989)	0.016
# (976, 990)	0.012
# (976, 991)	0.002
# (976, 992)	0.002
# (976, 993)	0.002
# (976, 994)	0.002
# (976, 995)	0.002
# (976, 996)	0.002
# (976, 997)	0.002
# (976, 998)	0.002
# (976, 999)	0.002
# (977, 978)	0.105
# (977, 979)	0.060
# (977, 980)	0.033
# (977, 981)	0.027
# (977, 982)	0.014
# (977, 983)	0.100
# (977, 984)	0.019
# (977, 985)	0.068
# (977, 986)	0.033
# (977, 987)	0.032
# (977, 988)	0.061
# (977, 989)	0.014
# (977, 990)	0.007
# (977, 991)	0.001
# (977, 992)	0.001
# (977, 993)	0.001
# (977, 994)	0.001
# (977, 995)	0.001
# (977, 996)	0.001
# (977, 997)	0.001
# (977, 998)	0.001
# (977, 999)	0.001
# (978, 979)	0.021
# (978, 980)	0.027
# (978, 981)	0.024
# (978, 982)	0.029
# (978, 983)	0.115
# (978, 984)	0.024
# (978, 985)	0.025
# (978, 986)	0.012
# (978, 987)	0.030
# (978, 988)	0.027
# (978, 989)	0.024
# (978, 990)	0.017
# (978, 991)	0.001
# (978, 992)	0.001
# (978, 993)	0.002
# (978, 994)	0.001
# (978, 995)	0.002
# (978, 996)	0.002
# (978, 997)	0.002
# (978, 998)	0.001
# (978, 999)	0.001
# (979, 980)	0.093
# (979, 981)	0.028
# (979, 982)	0.024
# (979, 983)	0.020
# (979, 984)	0.056
# (979, 985)	0.076
# (979, 986)	0.033
# (979, 987)	0.027
# (979, 988)	0.006
# (979, 989)	0.025
# (979, 990)	0.012
# (979, 991)	0.002
# (979, 992)	0.002
# (979, 993)	0.002
# (979, 994)	0.002
# (979, 995)	0.002
# (979, 996)	0.003
# (979, 997)	0.002
# (979, 998)	0.002
# (979, 999)	0.002
# (980, 981)	0.009
# (980, 982)	0.005
# (980, 983)	0.079
# (980, 984)	0.037
# (980, 985)	0.035
# (980, 986)	0.059
# (980, 987)	0.014
# (980, 988)	0.002
# (980, 989)	0.004
# (980, 990)	0.001
# (980, 991)	0.001
# (980, 992)	0.001
# (980, 993)	0.001
# (980, 994)	0.001
# (980, 995)	0.001
# (980, 996)	0.001
# (980, 997)	0.001
# (980, 998)	0.001
# (980, 999)	0.001
# (981, 982)	0.106
# (981, 983)	0.040
# (981, 984)	0.096
# (981, 985)	0.031
# (981, 986)	0.017
# (981, 987)	0.197
# (981, 988)	0.008
# (981, 989)	0.044
# (981, 990)	0.082
# (981, 991)	0.034
# (981, 992)	0.033
# (981, 993)	0.035
# (981, 994)	0.032
# (981, 995)	0.034
# (981, 996)	0.039
# (981, 997)	0.035
# (981, 998)	0.032
# (981, 999)	0.034
# (982, 983)	0.038
# (982, 984)	0.040
# (982, 985)	0.034
# (982, 986)	0.043
# (982, 987)	0.115
# (982, 988)	0.003
# (982, 989)	0.036
# (982, 990)	0.041
# (982, 991)	0.009
# (982, 992)	0.009
# (982, 993)	0.009
# (982, 994)	0.008
# (982, 995)	0.009
# (982, 996)	0.010
# (982, 997)	0.009
# (982, 998)	0.008
# (982, 999)	0.009
# (983, 984)	0.027
# (983, 985)	0.022
# (983, 986)	0.038
# (983, 987)	0.056
# (983, 988)	0.013
# (983, 989)	0.028
# (983, 990)	0.019
# (983, 991)	0.002
# (983, 992)	0.002
# (983, 993)	0.002
# (983, 994)	0.002
# (983, 995)	0.002
# (983, 996)	0.003
# (983, 997)	0.002
# (983, 998)	0.002
# (983, 999)	0.002
# (984, 985)	0.043
# (984, 986)	0.015
# (984, 987)	0.098
# (984, 988)	0.008
# (984, 989)	0.057
# (984, 990)	0.067
# (984, 991)	0.015
# (984, 992)	0.015
# (984, 993)	0.015
# (984, 994)	0.014
# (984, 995)	0.015
# (984, 996)	0.018
# (984, 997)	0.015
# (984, 998)	0.014
# (984, 999)	0.015
# (985, 986)	0.363
# (985, 987)	0.047
# (985, 988)	0.015
# (985, 989)	0.024
# (985, 990)	0.014
# (985, 991)	0.002
# (985, 992)	0.002
# (985, 993)	0.002
# (985, 994)	0.002
# (985, 995)	0.002
# (985, 996)	0.002
# (985, 997)	0.002
# (985, 998)	0.002
# (985, 999)	0.002
# (986, 987)	0.033
# (986, 988)	0.006
# (986, 989)	0.013
# (986, 990)	0.008
# (986, 991)	0.001
# (986, 992)	0.001
# (986, 993)	0.001
# (986, 994)	0.001
# (986, 995)	0.001
# (986, 996)	0.002
# (986, 997)	0.001
# (986, 998)	0.001
# (986, 999)	0.001
# (987, 988)	0.010
# (987, 989)	0.049
# (987, 990)	0.089
# (987, 991)	0.034
# (987, 992)	0.034
# (987, 993)	0.035
# (987, 994)	0.032
# (987, 995)	0.035
# (987, 996)	0.040
# (987, 997)	0.035
# (987, 998)	0.032
# (987, 999)	0.034
# (988, 989)	0.004
# (988, 990)	0.004
# (988, 991)	0.001
# (988, 992)	0.001
# (988, 993)	0.001
# (988, 994)	0.001
# (988, 995)	0.001
# (988, 996)	0.001
# (988, 997)	0.001
# (988, 998)	0.001
# (988, 999)	0.001
# (989, 990)	0.085
# (989, 991)	0.007
# (989, 992)	0.008
# (989, 993)	0.008
# (989, 994)	0.007
# (989, 995)	0.008
# (989, 996)	0.009
# (989, 997)	0.008
# (989, 998)	0.007
# (989, 999)	0.007
# (990, 991)	0.028
# (990, 992)	0.026
# (990, 993)	0.028
# (990, 994)	0.025
# (990, 995)	0.027
# (990, 996)	0.031
# (990, 997)	0.027
# (990, 998)	0.026
# (990, 999)	0.026
# (991, 992)	0.485
# (991, 993)	0.488
# (991, 994)	0.485
# (991, 995)	0.492
# (991, 996)	0.468
# (991, 997)	0.493
# (991, 998)	0.488
# (991, 999)	0.494
# (992, 993)	0.494
# (992, 994)	0.489
# (992, 995)	0.498
# (992, 996)	0.466
# (992, 997)	0.497
# (992, 998)	0.484
# (992, 999)	0.491
# (993, 994)	0.489
# (993, 995)	0.493
# (993, 996)	0.471
# (993, 997)	0.494
# (993, 998)	0.481
# (993, 999)	0.491
# (994, 995)	0.492
# (994, 996)	0.460
# (994, 997)	0.491
# (994, 998)	0.492
# (994, 999)	0.487
# (995, 996)	0.473
# (995, 997)	0.508
# (995, 998)	0.487
# (995, 999)	0.489
# (996, 997)	0.485
# (996, 998)	0.455
# (996, 999)	0.468
# (997, 998)	0.486
# (997, 999)	0.494
# (998, 999)	0.496

# %%
# Take union of all sets. Convert to an array and assign
# each element an integer based on position in array
fullset = set.union(*doc_shingles)
shingle_dict = dict(zip(list(fullset),range(len(fullset))))
print(f"There are {len(shingle_dict)} shingles")
# Out:
# There are 1039942 shingles

# %%
# shingle_dict

# %% [markdown]
# ### 3. Define the MinHash class, capable of creating a signature matrix
#
# Note: this only takes sets as input (not matrices) allowing us to efficiently deal with sparse matrices

# %%
# Create a hash function
# define as a callable class, so that we only
# intialize random functions once
class HashManager():
    def __init__(self, shingle_dict):
        self.shingle_dict = shingle_dict
        self.N = len(shingle_dict)
        self.params = None
        
    def _initParams(self, n_sig):
        self.params = np.random.randint(self.N, size=[n_sig,2])
    
    def _permuteRow(self, row):
        return (self.params@np.array([1,row]))%self.N
    
    def __call__(self, docs, n_sig, init=True):
        # Initialize if we change signature matrix length
        # or if we request to re-initialize
        if self.params is None or len(self.params) != n_sig or init:
            self._initParams(n_sig)
            
        #initialize signature matrix
        sig = np.full((n_sig, len(docs)), np.inf)
        
        # each doc in docs is assumed to be an iterable object
        for j, doc in enumerate(docs):
            for shingle in doc:
                orig_row = shingle_dict[shingle]
                curr_col = self._permuteRow(orig_row)
                sig[:,j] = np.minimum(sig[:,j],curr_col)
        return sig.astype(int)
    
# run some tests:
try:
    print("Initialization test: ", end="")
    hm = HashManager(shingle_dict)
    print("passed")

    print("Set parameters to right size: ", end="")
    hm._initParams(n_sig=4)
    assert(hm.params.shape == (4,2))
    print("passed")

    print("Permuting a row integer returns array: ", end="")
    curr_col = hm._permuteRow(3)
    assert(curr_col.shape == (4,))
    print("passed")

    print("Compute minhashed signature matrix: ", end="")
    hm(doc_shingles, 4)
    print("passed")
except Exception as e:
    print("failure")
    print(e.args)
# Out:
# Initialization test: passed
# Set parameters to right size: failure
# ("name 'np' is not defined",)

# %%
hm = HashManager(shingle_dict)

# %% [markdown]
# ### 4. Use MinHashing to compute similarity scores, and see how well it does

# %%
def trueSimScores(doc_shingles):
    pair_labels = []
    pair_sims = []
    idxs = range(len(doc_shingles))
    for x1, x2 in itertools.combinations(zip(idxs,doc_shingles), 2):
        pair_labels.append((x1[0], x2[0]))
        pair_sims.append(jaccardSim(x1[1], x2[1]))
    return dict(zip(pair_labels, pair_sims))
    
def sigSimScores(sig_mat):
#     cols = [sig_mat[:,i] for i in range(sig_mat.shape[1])]
    cols = sig_mat.T
    idxs = range(sig_mat.shape[1])
    
    pair_labels = []
    pair_sims = []
    for (i,col1), (j,col2) in itertools.combinations(zip(idxs, cols),2):
        pair_labels.append((i,j))
        pair_sims.append(np.mean(col1==col2))
    
    return dict(zip(pair_labels, pair_sims))

def printScoreComparison(true_dict, approx_dict):
    print(f"**~~~~~~ Similarity score comparison ~~~~~~**")
    print("Pair\t\tApprox\t\tTrue\t\t%Error")
    for pair, true_value in true_dict.items():
        approx_value = approx_dict[pair]
        err = 100*abs(true_value-approx_value)/true_value
        print(f"{pair}\t\t{approx_value:.3f}\t\t{true_value:.3f}\t\t{err:.2f}")

def candidatePairs(score_dict, threshold):
    return set(pair for pair, scr in score_dict.items() if scr>=threshold)

def accMatrix(true_dict, approx_dict, threshold):
    true_pairs = candidatePairs(true_dict, threshold)
    approx_pairs = candidatePairs(approx_dict, threshold)
    false_negatives = len(true_pairs - approx_pairs)
    false_positives = len(approx_pairs - true_pairs)
    print(f"False negatives: {false_negatives}")
    print(f"Potential false positives: {false_positives}")

sig_mat = hm(doc_shingles, 10)
true_score_dict = trueSimScores(doc_shingles)
approx_score_dict = sigSimScores(sig_mat)
printScoreComparison(true_score_dict, approx_score_dict)

print("True pairs:",candidatePairs(true_score_dict, 0.25))
print("Candidate pairs:",candidatePairs(approx_score_dict, 0.25))
accMatrix(true_score_dict, approx_score_dict, 0.4)

# print(f"**~~~~~~ Approximate similarity scores ~~~~~~**")
# print("Pair\t\tApproximate Score\t\tTrue Score")
# print("-"*14)
# for pair, score in sigSimScores(sig_mat):
#     print(f"{pair}\t{score:.3f}")
    
# print(f"**~~~~~~ True similarity scores ~~~~~~**")
# print("Pair\tScore")
# print("-"*14)
# for pair, score in zip(pair_labels, pair_sims):
#     print(f"{pair}\t{score:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0fb97028927a> in <module>()
#      40     print(f"Potential false positives: {false_positives}")
#      41
# ---> 42 sig_mat = hm(doc_shingles, 10)
#      43 true_score_dict = trueSimScores(doc_shingles)
#      44 approx_score_dict = sigSimScores(sig_mat)
#
# <ipython-input-10-a01afdc9c1c1> in __call__(self, docs, n_sig, init)
#      18         # or if we request to re-initialize
#      19         if self.params is None or len(self.params) != n_sig or init:
# ---> 20             self._initParams(n_sig)
#      21
#      22         #initialize signature matrix
#
# <ipython-input-10-a01afdc9c1c1> in _initParams(self, n_sig)
#       9
#      10     def _initParams(self, n_sig):
# ---> 11         self.params = np.random.randint(self.N, size=[n_sig,2])
#      12
#      13     def _permuteRow(self, row):
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Adding Locality Sensitive Hashing: preliminary band-structure theory, how to choose band size

# %% [markdown]
# ### Effects of changing b,r at fixed n

# %% [markdown]
# Now implement Locality-sensitive hashing. We use a band structure on the signature matrix. If the matrix has $n$ rows, then we divide it into $b$ bands each of width $r$, such that
# $$n = b*r$$
#
# Let $p$ be the true similarity score (match percent) between a pair. The probability of matching every integer in a band is
#
# $$\text{prob. one band doesn't match } = 1-p^r$$
#
# Now the probability that NONE of the $b$ bands match is given by
#
# $$\text{prob. no bands match } = (1-p^r)^b$$
#
# Therefore, the probability that at least one band matches, is
#
# $$P(\geq 1\text{ match}) = 1-(1-p^r)^b$$
#
# Now, we want this to be our criteria for a candidate pair. That is, two signatures columns are a candidate pair if $P \geq 1/2$. We will see in the plot below, that as the signature matrix increases, we can tune $r$ and $b$ to approximately be a step function around the true value of $p$. The goal is to find as few candidate pairs as possible, while also making sure we find them all.
#
# Draw a vertical line at the true p value
# The area UNDER the curve $P(x<p)$ represents the rate of potential false positives
#
# the area ABOVE the curce $P(x\geq p)$ represents the rate of false negatives
#
# For various values of $r$, $b$, we plot the result below

# %%
import matplotlib.pyplot as plt
n = 200
ops = [(2,100),(4,50),(10,20),(20,10),(50,4),(100,2)]
yval = lambda p,r,b: 1-(1-p**r)**b
pts = np.linspace(0,1,100)
yval(pts,.2,.2)
for op in ops:
    plt.plot(pts, yval(pts,op[0],op[1]), label=op)
plt.plot(pts,0*pts+0.5,'k--', label="P=1/2")
plt.plot([0.4,0.4],[0,1], 'k-.')
plt.legend()
plt.xlabel('p')
plt.ylabel('Probability')
plt.title("legend: (r,b). p_true=0.4 (vertical line)")
plt.show()

# %% [markdown]
# ### Effects of changing n while adjusting b,r to keep P=1/2 argument constant

# %% [markdown]
# Now let's solve for the optimal values r,b.
#
# We suppose that we *fix* $n,r,b$. Given these, we determine at which approximate point $p$ is the crossover. We should find $p=p(b,r)$. Afterwards, we can then approximately solve for $r,b$ to be a desired $p$
#
# We begin with for $P=1/2$.
# $$1/2 = 1-(1-p^r)^b$$
# $$ 1-p^r = 2^{-1/b}$$
# $$p = (1-2^{-1/b})^{1/r} = (1-e^{-(1/b)\ln2})^{1/r} \approx (1/b)^{1/r}*\text{const}$$
#
# Finally, if we fix $r$ and $p$, we can find the required bands to be about
# $$ b \approx 1/p^r
#
# Takeaways:
#
# increasing r ->
# * moves the curve right.
# * more the false negatives
# * means lower chance to match
#
# increasing b ->
# * moves the curve left.
# * more false positives
# * means higher chance to match
#
# increasing n ->
# * the curve approaches a step function.
# * fewer false anythings
# * always good!
#
# Now watch what happens as we pick the optimal r,b and then increase n.
#
# We will try to keep p centered around $p=0.5$

# %%
x = np.linspace(0,1,100)

b,r = 5, 3
y = 1-(1-x**r)**b
plt.plot(x,y,'r-',label=f"b={b},r={r}, n={b*r}")

b,r = 40, 6
y = 1-(1-x**r)**b
plt.plot(x,y,'b-',label=f"b={b}, r={r}, n={b*r}")

b,r = 150, 8
y = 1-(1-x**r)**b
plt.plot(x,y,'g-',label=f"b={b}, r={r}, n={b*r}")

b,r = 700, 10
y = 1-(1-x**r)**b
plt.plot(x,y,'g-',label=f"b={b}, r={r}, n={b*r}")


plt.plot(x,0*x+0.5,'k--')
plt.plot([0.5,0.5],[0,1],'k--')
plt.legend()
plt.show()

# %% [markdown]
# Now, we use all of the above to try to optimize our Localitly Sensitive Hash function from before.
#
# Let's say we want a threshold of $p=0.3$. We can calculate $b\approx p^{-r}$ for the number of bands.
#
# For the first 6 values of band size we determine we should keep
#
# $r=1 \to b=3,\,n=3$
#
# $r=2 \to b=11,\,n=22$
#
# $r=3 \to b=37,\,n=111$
#
# $r=4 \to b=123,\,n=492$
#
# $r=5 \to b=412,\,n=2060$
#
# Let's try the intermediate choice, and use round numbers $n=120$, $b=40$, $r=3$
#
# Let's see how good our results are using the previous defined functions. We first need to construct the banded similarity measure to be used on the signature matrix. Put this into a function

# %% [markdown]
# ### Brute force banded candidate pair function, for checking hash method later

# %%
def bandedCandidatePair(col1, col2, b, r):
    """Returns a boolean if the two columns are a candidate pair
    inputs must obey n=len(col1)=len(col2)=b*r"""
    n = len(col1)
    assert(n==b*r)
    assert(n==len(col2))
    truth_array = (col1==col2)
    return any(all(band) for band in np.array_split(truth_array,b))

def bandedCandidatePairs(sig_mat, b, r):
    d = sig_mat.shape[1]
    idxs = range(d)
    cols = [sig_mat[:,i] for i in range(d)]
    pairs = set()
    for (i,col1), (j,col2) in itertools.combinations(zip(idxs,cols),2):
        if bandedCandidatePair(col1,col2,b,r):
            pairs.add((i,j))
    return pairs

# set p = 0.3 arbitrarily
p = 0.3
n = 120
b = 30
r = 4

# see how many candidate pairs we got right!
sig_mat = hm(doc_shingles, n)
true_score_dict = trueSimScores(doc_shingles)
approx_score_dict = sigSimScores(sig_mat)
print("True pairs:",candidatePairs(true_score_dict, p))
print("LSH pairs:",bandedCandidatePairs(sig_mat, b, r))
print("Vanilla MinHash pairs:",candidatePairs(approx_score_dict, p))
# accMatrix(true_score_dict, approx_score_dict, 0.4)

# sig_mat = hm(doc_shingles, n)
# true_score_dict = trueSimScores(doc_shingles)
printScoreComparison(true_score_dict, approx_score_dict)
# Out:
# True pairs: {(3, 4), (0, 4)}
# LSH pairs: {(3, 4), (1, 4)}
# Vanilla MinHash pairs: {(3, 4), (1, 4), (0, 4)}
# **~~~~~~ Similarity score comparison ~~~~~~**
# Pair		Approx		True		%Error
# (0, 1)		0.133		0.093		43.01
# (0, 2)		0.167		0.069		141.99
# (0, 3)		0.158		0.050		217.42
# (0, 4)		0.417		0.336		23.93
# (1, 2)		0.175		0.081		116.14
# (1, 3)		0.150		0.051		191.81
# (1, 4)		0.300		0.294		1.87
# (2, 3)		0.167		0.052		222.44
# (2, 4)		0.217		0.083		161.13
# (3, 4)		0.550		0.400		37.43

# %% [markdown]
# ### Finally, we perform the fast candidate pair search, using a hash table of band and column id's

# %% [markdown]
# Lastly, we will improve upon the whole efficiency by performing the comparisons of banded pairs in $\mathcal{O}(n)$ time as opposed to $\mathcal{O}(n^2)$
#
# For each band of a column, we place a copy of the column index into a hash table, with key the row values.
#
# For example, let col=[4,2,5,6]. This might band to say [(4,2),(5,6)], and we ould enter into a dictionary d={(4,2):[col,...], (5,6):[col,...], ...}

# %%
def fastCandidatePairs(sig_mat, b, r):
    n, d = sig_mat.shape
    assert(n==b*r)
    hashbuckets = collections.defaultdict(set)
    bands = np.array_split(sig_mat, b, axis=0)
    for i,band in enumerate(bands):
        for j in range(d):
            # The last value must be made a string, to prevent accidental
            # key collisions of r+1 integers when we really only want
            # keys of r integers plus a band index
            band_id = tuple(list(band[:,j])+[str(i)])
            hashbuckets[band_id].add(j)
    candidate_pairs = set()
    for bucket in hashbuckets.values():
        if len(bucket) > 1:
            for pair in itertools.combinations(bucket, 2):
                candidate_pairs.add(pair)
    return candidate_pairs


# to make sure it works, 
# compare with the brute force method on a few trials

# set p = 0.3 arbitrarily
p = 0.3
n = 120
b = 30
r = 4

# see how many candidate pairs we got right!
sig_mat = hm(doc_shingles, n)
true_score_dict = trueSimScores(doc_shingles)
approx_score_dict = sigSimScores(sig_mat)
print('True pairs:\t', candidatePairs(true_score_dict, p))
print("True LSH pairs:\t", bandedCandidatePairs(sig_mat, b, r))
print("Fast LSH pairs:\t", fastCandidatePairs(sig_mat, b, r))
print("MinHash pairs:\t", candidatePairs(approx_score_dict, p))
# Out:
# True pairs:	 {(3, 4), (0, 4)}
# True LSH pairs:	 {(3, 4), (1, 4)}
# Fast LSH pairs:	 {(3, 4), (1, 4)}
# MinHash pairs:	 {(3, 4), (1, 4), (0, 4)}

# %% [markdown]
# # Part II: vector similarity

# %%
def cossim(u,v):
    norm = np.linalg.norm(u)*np.linalg.norm(v)
    cosine = u@v/norm
    ang = np.arccos(cosine)
    return 1-ang/np.pi

# %% [markdown]
# ## Generate data
#
# We create N random vectors of dimension D. We then reassign 5 of these to be artifically close to another set of 5. This is done by setting them equal and adding a small amount of noise.
#
# By artificially making some vectors closer to others, we can easily tune the target similarity threshold, allowing us to experiment better.

# %%
# get some random data points
N = 1000
D= 50
A = np.random.randn(N,D)
# artificially make some similar to others
A[5] = A[99] +np.random.randn(D)*0.05
A[20] = A[85] +np.random.randn(D)*0.15
A[13] = A[19] +np.random.randn(D)*0.25
A[56] = A[71] +np.random.randn(D)*0.5
A[45] = A[49] +np.random.randn(D)*0.66

# %% [markdown]
# ## Brute force calculation baseline
#
# This is straightforward. We compute the cosine similarity of every possible pair, and keep only those that are at or above the chosen threshold
#
# We know beforehand that the smallest "artificially most similar" pair is going to be around ~0.82, so we set the threshold to be 0.8.
#
# In practice, setting the threshold is an art, and depends on how similar we want things to really be.

# %%
true_pairs_dict = {}

thresh = 0.8

start = time.time()
for (i,u),(j,v) in itertools.combinations([(i,x) for i,x in enumerate(A)],2):
    val = cossim(u,v)
    if val > thresh:
        true_pairs_dict[(i,j)] = val
t_brute = time.time()-start

# save just the keys without the values. Easier to compare later to LSH
true_pairs = set(true_pairs_dict.keys())

print(f"Brute force calculation time: {t_brute:.3f}")
print(f"Discovered pairs:")
for k, v in true_pairs_dict.items():
    print(f"Pair: {k},\tSimilarity: {v:.2f}.")
# Out:
# Brute force calculation time: 6.184
# Discovered pairs:
# Pair: (5, 99),	Similarity: 0.98.
# Pair: (13, 19),	Similarity: 0.92.
# Pair: (20, 85),	Similarity: 0.95.
# Pair: (45, 49),	Similarity: 0.82.
# Pair: (56, 71),	Similarity: 0.86.

# %% [markdown]
# ## Locality Sensitive Hashing approach

# %% [markdown]
# ### Find r, b parameters given threshold
#
# We must have that D%b==0, that is the number of bands divides the dimension. That's our only constraint. Remember, higher n is always better!
#
# There's no magic here, we just trial and error some combinations until we get near the desired threshold, in this case 0.75 (chosen in the previous cell)

# %%
b, r = 50, 18

n = b*r
print(f"Transition probability: {(1/b)**(1/r):.2f}")
# Out:
# Transition probability: 0.80

# %% [markdown]
# ### Compute LSH pairs
#
# Let $S$ be the signature matrix and $R$ be the matrix of random hyperplanes.
#
# In the code implementation, we work with the transpose of our equations. This means that $S = (N,D)$, and so we have to split into bands across axis=1

# %%
start = time.time()

# Compute signature matrix
R = A@np.random.randn(D,n)
S = np.where(R>0,1,0)

# Break into bands
S = np.split(S, b, axis=1)

# column vector to convert binary vector to integer e.g. (1,0,1)->5
binary_column = 2**np.arange(r).reshape(-1,1)

# convert each band into a single integer, 
# i.e. convert band matrices to band columns
S = np.hstack([M@binary_column for M in S])

# Every value in the matrix represents a hash bucket assignment
# For every bucket in row i, add index i to that bucket
d = collections.defaultdict(set)
with np.nditer(S,flags=['multi_index']) as it:
    for x in it:
        d[int(x)].add(it.multi_index[0])
        
# For every bucket, find all pairs. These are the LSH pairs.
candidate_pairs = set()
for k,v in d.items():
    if len(v) > 1:
        for pair in itertools.combinations(v,2):
            candidate_pairs.add(tuple(sorted(pair)))

# Finally, perform the actually similarity computation
# to weed out false positive
lsh_pairs = set()
for (i,j) in candidate_pairs:
    if cossim(A[i],A[j]) > thresh:
        lsh_pairs.add((i,j))
        
t_lsh = time.time()-start

print(f"LSH calculation time: {t_lsh:.3f}")
# Out:
# LSH calculation time: 0.249

# %% [markdown]
# ## Compare the two methods
#
# The above should show that we get a factor of about 25x speedup, while simultaneously finding all pairs, with no false negatives!
#
# Very useful!

# %%
print(f"t_brute: {t_brute:.3f}\t t_lsh: {t_lsh:.3f}. Speed-up: {t_brute/t_lsh:.0f}x")
print("True pairs: ", pairs_true)
print("LSH pairs: ", lsh_pairs)
print(f"Candidate pairs: {len(candidate_pairs)}.\n\
False negatives: {len(pairs_true-lsh_pairs)}")
# Out:
# t_brute: 6.142	 t_lsh: 0.249. Speed-up: 25x
# True pairs:  {(45, 49), (20, 85), (56, 71), (13, 19), (5, 99)}
# LSH pairs:  {(45, 49), (20, 85), (56, 71), (13, 19), (5, 99)}
# Candidate pairs: 4876.
# False negatives: 0
