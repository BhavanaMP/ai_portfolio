# %%
import tensorflow as tf
import numpy as np
import random
from tensorflow.keras.datasets import mnist, cifar10
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten, Activation
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import LambdaCallback
import matplotlib.pyplot as plt

# %% [markdown]
# ##Data Loading

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
labels = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
num_classes = 10
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## Function to Pre-process the data

# %%
def preprocess(images, labels, placeholder=""):
  images = (images / 255)
  images = images.reshape((-1, 28, 28, 1))
  labels = tf.keras.utils.to_categorical(labels, num_classes)
  print("{} shape {}, {}".format(placeholder, images.shape, labels.shape))
  return images, labels

# %% [markdown]
# ##Actual Model Configurations

# %%
def model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), strides=(3, 3), padding='same', activation='relu', input_shape=(28, 28, 1)))
    model.add(Conv2D(64, kernel_size=(3, 3), strides=(3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3), strides=(3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(32))
    model.add(Dropout(0.2))
    model.add(Dense(32))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ## Create and fit model

# %%
model = model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 10, 10, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 64)         0
#  )
#
#  dropout (Dropout)           (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Preprocessing the data

# %%
x_train, y_train = preprocess(x_train, y_train, "Train Data")
x_test, y_test = preprocess(x_test, y_test, "Test Data")
# Out:
# Train Data shape (60000, 28, 28, 1), (60000, 10)
# Test Data shape (10000, 28, 28, 1), (10000, 10)

# %% [markdown]
# ##Model Training and Validation

# %%
model.fit(x_train, y_train,
          batch_size=64,
          epochs=25,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 133/938 [===>..........................] - ETA: 10s - loss: 0.0589 - accuracy: 0.5364
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b9ca26273cdf> in <module>()
#       2           batch_size=64,
#       3           epochs=25,
# ----> 4           validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
# Assessing base model accuracy on regular images
print("Base accuracy on regular images:", model.evaluate(x=x_test, y=y_test, verbose=0))
# Out:
# Base accuracy on regular images: [0.0027881991118192673, 0.9825999736785889]

# %% [markdown]
# ## Untargeted Attack(Fast gradient sign method)
# ###Function to create adversarial pattern by calculating gradient w.r.to input using tf.sign.

# %%
def adversarial_pattern(image, label):
    image = tf.cast(image, tf.float32)
    
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.MSE(label, prediction)
    
    gradient = tape.gradient(loss, image)
    
    signed_gradient = tf.sign(gradient)
    
    return signed_gradient

# %% [markdown]
# ##Targeted Attack

# %%
def adversarial_target_pattern(image, label, target):
    image = tf.cast(image, tf.float32)
    
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        originalLoss = tf.keras.losses.MSE(label, prediction)
        targetLoss = tf.keras.losses.MSE(target, prediction)
        totalLoss = originalLoss + targetLoss

    gradient = tape.gradient(totalLoss, image)
    
    signed_gradient = tf.sign(gradient)
    
    return signed_gradient

# %% [markdown]
# ## Displaying single adversarial example

# %%
image = x_train[0]
image_label = y_train[0]
target_class = tf.reshape(tf.one_hot(0, num_classes),[1, num_classes])
# set one target_class to one
perturbations = adversarial_pattern(image.reshape((1, 28, 28, 1)), image_label).numpy()
perturbation_target = adversarial_target_pattern(image.reshape((1, 28, 28, 1)), 
                                    image_label, target_class).numpy()
adversarial = image + perturbations * 0.1 #small constant to perturbations
adversarial = tf.clip_by_value(adversarial, 0, 1.0)
adversarial_target = image - perturbation_target * 0.1 #small constant to perturbations
adversarial_target = tf.clip_by_value(adversarial_target, 0, 1.0)


print("Actual input image prediction - {}".format(
    labels[model.predict(image.reshape((1, 28, 28, 1))).argmax()]))
print("Adversarial input image prediction - {}".format(
    labels[model.predict(adversarial).argmax()]))
print("Adversarial target input image prediction - {}".format(
    labels[model.predict(adversarial_target).argmax()]))

plt.show()
#Display the adversarial image
print(adversarial.shape)
plt.imshow(adversarial.numpy().reshape((28, 28)))
print(adversarial_target.shape)
plt.imshow(adversarial_target.numpy().reshape((28, 28)))

plt.show()
# Out:
# Actual input image prediction - three
# Adversarial input image prediction - three
# Adversarial target input image prediction - five
# (1, 28, 28, 1)
# (1, 28, 28, 1)

# %% [markdown]
# ## Adversarial data generator

# %%
def generate_adversarials(batch_size):
    while True:
        x = []
        y = []
        for batch in range(batch_size):

            label = y_train[batch]
            image = x_train[batch]
            
            perturbations = adversarial_pattern(image.reshape((1, 28, 28, 1)), label).numpy()
            
            
            epsilon = 0.1
            adversarial = image + perturbations * epsilon
            adversarial = tf.clip_by_value(adversarial, 0, 1.0)
            
            x.append(adversarial)
            y.append(y_train[batch])
        
        
        x = np.asarray(x).reshape((batch_size, 28, 28, 1))
        y = np.asarray(y)
        
        yield x, y

# %%
# Generate and visualize 10 adversarial images
adversarials, correct_labels = next(generate_adversarials(10))
for adversarial, correct_label in zip(adversarials, correct_labels):
    print('Prediction Label:', 
          labels[model.predict(adversarial.reshape((1, 28, 28, 1))).argmax()], 
          ' Ground Truth:', labels[correct_label.argmax()])
    plt.imshow(adversarial.reshape(28, 28))
    plt.show()
# Out:
# Prediction Label: three  Ground Truth: five
# Prediction Label: zero  Ground Truth: zero
# Prediction Label: four  Ground Truth: four
# Prediction Label: one  Ground Truth: one
# Prediction Label: four  Ground Truth: nine
# Prediction Label: two  Ground Truth: two
# Prediction Label: three  Ground Truth: one
# Prediction Label: three  Ground Truth: three
# Prediction Label: one  Ground Truth: one
# Prediction Label: four  Ground Truth: four

# %% [markdown]
# ## Adversarial data generation

# %%
x_adversarial_train, y_adversarial_train = next(generate_adversarials(20000))
x_adversarial_test, y_adversarial_test = next(generate_adversarials(10000))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-2e1a8f36383b> in <module>()
# ----> 1 x_adversarial_train, y_adversarial_train = next(generate_adversarials(20000))
#       2 x_adversarial_test, y_adversarial_test = next(generate_adversarials(10000))
#
# <ipython-input-14-85ff87fd3c16> in generate_adversarials(batch_size)
#       9             image = x_train[N]
#      10
# ---> 11             perturbations = adversarial_pattern(image.reshape((1, 28, 28, 1)), label).numpy()
#      12
#      13
#
# <ipython-input-6-1aed2a54dc44> in adversarial_pattern(image, label)
#       4     with tf.GradientTape() as tape:
#       5         tape.watch(image)
# ----> 6         prediction = model(image)
#       7         loss = tf.keras.losses.MSE(label, prediction)
#       8
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in call(self, inputs, training, mask)
#     371       if not self.built:
#     372         self._init_graph_network(self.inputs, self.outputs)
# --> 373       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     374
#     375     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     450     """
#     451     return self._run_internal_graph(
# --> 452         inputs, training=training, mask=mask)
#     453
#     454   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     587
#     588         args, kwargs = node.map_arguments(tensor_dict)
# --> 589         outputs = node.layer(*args, **kwargs)
#     590
#     591         # Update tensor_dict.
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/convolutional.py in call(self, inputs)
#     244       inputs = tf.pad(inputs, self._compute_causal_padding(inputs))
#     245
# --> 246     outputs = self.convolution_op(inputs, self.kernel)
#     247
#     248     if self.use_bias:
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/convolutional.py in convolution_op(self, inputs, kernel)
#     236         dilations=list(self.dilation_rate),
#     237         data_format=self._tf_data_format,
# --> 238         name=self.__class__.__name__)
#     239
#     240   def call(self, inputs):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1157       data_format=data_format,
#    1158       dilations=dilations,
# -> 1159       name=name)
#    1160
#    1161
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1289           data_format=data_format,
#    1290           dilations=dilations,
# -> 1291           name=name)
#    1292     else:
#    1293       if channel_index == 1:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2765         data_format=data_format,
#    2766         dilations=dilations,
# -> 2767         name=name)
#    2768   return squeeze_batch_dims(
#    2769       input,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     927         "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding", padding,
#     928         "explicit_paddings", explicit_paddings, "data_format", data_format,
# --> 929         "dilations", dilations)
#     930       return _result
#     931     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Assess base model on adversarial data
print("Base accuracy on adversarial images:", model.evaluate(x=x_adversarial_test, y=y_adversarial_test, verbose=0))
# Out:
# Base accuracy on adversarial images: [0.053898490965366364, 0.6827999949455261]

# %% [markdown]
# ##Adversarial Training

# %%
model = model()
model.fit(x_adversarial_train, y_adversarial_train,
          batch_size=32,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 6s 9ms/step - loss: 0.0016 - accuracy: 0.9901 - val_loss: 0.0070 - val_accuracy: 0.9585
# Epoch 2/10
# 625/625 [==============================] - 6s 10ms/step - loss: 7.5997e-05 - accuracy: 0.9995 - val_loss: 0.0067 - val_accuracy: 0.9612
# Epoch 3/10
# 625/625 [==============================] - 6s 9ms/step - loss: 8.7349e-05 - accuracy: 0.9995 - val_loss: 0.0081 - val_accuracy: 0.9550
# Epoch 4/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.1091e-04 - accuracy: 0.9994 - val_loss: 0.0078 - val_accuracy: 0.9557
# Epoch 5/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.1088e-04 - accuracy: 0.9992 - val_loss: 0.0072 - val_accuracy: 0.9592
# Epoch 6/10
# 625/625 [==============================] - 6s 10ms/step - loss: 6.2338e-05 - accuracy: 0.9997 - val_loss: 0.0097 - val_accuracy: 0.9454
# Epoch 7/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.1521e-04 - accuracy: 0.9993 - val_loss: 0.0122 - val_accuracy: 0.9332
# Epoch 8/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.7927e-04 - accuracy: 0.9988 - val_loss: 0.0110 - val_accuracy: 0.9399
# Epoch 9/10
# 625/625 [==============================] - 6s 9ms/step - loss: 6.2424e-05 - accuracy: 0.9996 - val_loss: 0.0106 - val_accuracy: 0.9417
# Epoch 10/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.2277e-04 - accuracy: 0.9990 - val_loss: 0.0124 - val_accuracy: 0.9318

# %%
# Assess defended model on adversarial data
print("Defended accuracy on adversarial images:", model.evaluate(x=x_adversarial_test, y=y_adversarial_test, verbose=0))

# Assess defended model on regular data
print("Defended accuracy on regular images:", model.evaluate(x=x_test, y=y_test, verbose=0))
# Out:
# Defended accuracy on adversarial images: [3.24834925148825e-20, 1.0]
# Defended accuracy on regular images: [0.012352542020380497, 0.9318000078201294]

# %%
x_adversarial_test, y_adversarial_test = next(generate_adversarials(10000))
print("Defended accuracy on adversarial images:", model.evaluate(x=x_adversarial_test, y=y_adversarial_test, verbose=0))
# Out:
# Defended accuracy on adversarial images: [0.004402328748255968, 0.9710000157356262]

# %% [markdown]
# ##Targeted adversarial generation

# %%
def generate_adversarials_target(batch_size):
    while True:
        x = []
        y = []
        for batch in range(batch_size):
            target_class = tf.reshape(tf.one_hot(0, num_classes),[1, num_classes])
            label = y_train[batch]
            image = x_train[batch]
            
            perturbations = adversarial_target_pattern(image.reshape((1, 28, 28, 1)), label, target_class).numpy()
            
            
            epsilon = 0.1
            adversarial = image - perturbations * epsilon
            adversarial = tf.clip_by_value(adversarial, 0, 1.0)
            
            x.append(adversarial)
            y.append(y_train[batch])
        
        
        x = np.asarray(x).reshape((batch_size, 28, 28, 1))
        y = np.asarray(y)
        
        yield x, y

# %%
# Generate and visualize 10 adversarial images
adversarials, correct_labels = next(generate_adversarials_target(10))
for adversarial_target, correct_label in zip(adversarials, correct_labels):
    print('Prediction Label:', 
          labels[model.predict(adversarial_target.reshape((1, 28, 28, 1))).argmax()], 
          ' Ground Truth:', labels[correct_label.argmax()])
    plt.imshow(adversarial_target.reshape(28, 28))
    plt.show()
# Out:
# Prediction Label: five  Ground Truth: five
# Prediction Label: zero  Ground Truth: zero
# Prediction Label: four  Ground Truth: four
# Prediction Label: one  Ground Truth: one
# Prediction Label: nine  Ground Truth: nine
# Prediction Label: two  Ground Truth: two
# Prediction Label: three  Ground Truth: one
# Prediction Label: three  Ground Truth: three
# Prediction Label: one  Ground Truth: one
# Prediction Label: four  Ground Truth: four

# %%
x_adversarial_train, y_adversarial_train = next(generate_adversarials_target(20000))
x_adversarial_test, y_adversarial_test = next(generate_adversarials_target(10000))

# %%
# Assess base model on adversarial data
print("Base accuracy on adversarial images:", model.evaluate(x=x_adversarial_test, y=y_adversarial_test, verbose=0))
# Out:
# Base accuracy on adversarial images: [1.1270103073002247e-08, 1.0]

# %%
# call model again to get a new model
model = model()
model.fit(x_adversarial_train, y_adversarial_train,
          batch_size=32,
          epochs=10,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 6s 9ms/step - loss: 2.1612e-04 - accuracy: 0.9987 - val_loss: 0.0096 - val_accuracy: 0.9477
# Epoch 2/10
# 625/625 [==============================] - 6s 9ms/step - loss: 3.0403e-05 - accuracy: 0.9998 - val_loss: 0.0114 - val_accuracy: 0.9372
# Epoch 3/10
# 625/625 [==============================] - 6s 9ms/step - loss: 3.9987e-05 - accuracy: 0.9998 - val_loss: 0.0154 - val_accuracy: 0.9166
# Epoch 4/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.0996e-04 - accuracy: 0.9994 - val_loss: 0.0132 - val_accuracy: 0.9294
# Epoch 5/10
# 625/625 [==============================] - 6s 10ms/step - loss: 1.2272e-04 - accuracy: 0.9992 - val_loss: 0.0142 - val_accuracy: 0.9235
# Epoch 6/10
# 625/625 [==============================] - 6s 10ms/step - loss: 5.3243e-05 - accuracy: 0.9997 - val_loss: 0.0120 - val_accuracy: 0.9348
# Epoch 7/10
# 625/625 [==============================] - 6s 9ms/step - loss: 4.4018e-05 - accuracy: 0.9998 - val_loss: 0.0155 - val_accuracy: 0.9164
# Epoch 8/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.6909e-04 - accuracy: 0.9990 - val_loss: 0.0114 - val_accuracy: 0.9388
# Epoch 9/10
# 625/625 [==============================] - 6s 9ms/step - loss: 1.1159e-04 - accuracy: 0.9994 - val_loss: 0.0128 - val_accuracy: 0.9310
# Epoch 10/10
# 625/625 [==============================] - 6s 10ms/step - loss: 1.8716e-04 - accuracy: 0.9990 - val_loss: 0.0151 - val_accuracy: 0.9188
