# %% [markdown]
# https://www.datacamp.com/tutorial/what-is-topic-modeling
#
# https://python-textbook.pythonhumanities.com/04_topic_modeling/04_01_02_topic_modeling_concepts.html
#
# https://youtube.com/playlist?list=PL2VXyKi-KpYttggRATQVmgFcQst3z6OlX&si=edFCyp_XWZf9-QfH

# %%
# Check if gensim is installed, install if not
try:
    import gensim
except ImportError:
    # !pip install --upgrade gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 75.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 91.3 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 52.3 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
try:
    import pyLDAvis
except ImportError:
    # !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.10.2)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (75.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.6.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->pyLDAvis) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pyLDAvis) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.17.2)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 50.3 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1

# %%
import numpy
numpy.__version__
# Out:
# '2.0.2'

# %%
import scipy
scipy.__version__
# Out:
# '1.13.1'

# %%
import gensim
gensim.__version__
# Out:
# '4.3.3'

# %% [markdown]
# ### Why Topic Modelling?###
#
# Topic modeling is a frequently used approach to discover hidden semantic patterns portrayed by a **text corpus** and automatically **identify topics** and **draw conclusions** that exist inside it.
#
# Namely, it’s a type of statistical modeling that leverages **unsupervised machine learning** to analyze and **identify clusters or groups** of similar words within a body of text.
#
# Eg: A topic modeling algorithm may be deployed to determine whether the contents of a document imply it’s an invoice, complaint, or contract.
#
# ---
# Topic Modelling can be done using **rules based** or **machine learnung based**
# ---
# ### Rules-Based Methods
# A simple approach to the identification of topics in a collection of documents is what we would call a rules-based approach. Here, we could argue that documents in which certain words appear indicate a specific topic. This manual approach may yield good results. For example, if I had a 100,000 documents and I knew that some dealt with medical details, I could look for a handful of terms, such as doctor, medicine, hospital, etc. to extract those documents as dealing with a topic of medical.
#
# The **key problem** with this approach is **scale**. We cannot practically construct lists like this for all possible topics, especially if we do not know the topics found within a corpus. Further, constructing lists like this requires detailed knowledge about a subject. For these reasons, a rules-based approach to classifying documents is not practical for large corpora.
#
# ### Machine Learning-Based Methods
# Another option to identify topics in a text is via a machine learning-based approach. In this method, we do not give a computer system a set of rules, rather we let the computer generate its own rules to identify topics in a corpus.
#
# This is done in two different ways:
# - supervised
# - unsupervised learning.
#
# In supervised learning, we know the key subjects in a corpus. We give a computer system a set of documents with their corresponding label to teach it to identify the characteristics that make that particular topic or class unique. This is mostly used for **text classification**.
#
# In unsupervised learning, we do not know the topics of our documents and, instead, we want let the system identify those topics and cluster (or group together) the ones of a high degree of similarity together. We then examine the words that occur the most frequently in each cluster to get a sense of the topics at hand.
#
# The classic example for machine learning topic modeling is **LDA, or Latent Dirichlet Allocation**
#
# ---

# %% [markdown]
# ## 1. Topics vs. Clusters
#
# Topics are labels assigned to textual data that detail the subjects contained within a given text.
#
# Texts that share common terms are clustered together by similarity. A cluster is nothing more than a collection of similar pieces of data. When we are working with texts, a cluster is a collection of texts that have similar overlapping themes.
#
# - **Cluster**
#   - **Hard assignment**: each document belongs to exactly one group.
#   - Representation: centroids or prototypes.
#   - Example: K‑means partitions documents into disjoint sets.
#
# - **Topic**
#   - **Soft mixture**: each document is a weighted combination of topics.
#   - Representation: topics are distributions over words, documents are distributions over topics.
#   - A document might be, say, 70 % Topic A and 30 % Topic B.
#
# | Aspect           | Clustering               | Topic Modeling                          |
# |------------------|--------------------------|-----------------------------------------|
# | Assignment       | Hard (one cluster/doc)   | Soft (mixture of topics/doc)            |
# | Representation   | Centroid/prototype       | Probability distribution over words     |
# | Use‑case         | Partitioning             | Thematic exploration, mixed membership  |
#
# ---

# %% [markdown]
# ## Latent Semantic Analysis (LSA)
#
# LSA uses Singular Value Decomposition (SVD) to reduce the dimensionality of a document-term matrix, highlighting the latent semantic relationships between words and documents.
#
# 1. **Construct** the document–term matrix
#    \begin{equation}
#      X(DTM) \in \mathbb{R}^{D \times V},\quad X_{d,w} = \text{count or TF‑IDF}
#    \end{equation}
#    Once we have our document-term matrix X, which is very sparse, very noisy, and very redundant across its many dimensions. As a result, to find the few latent topics that capture the relationships among the words and documents, we want to perform dimensionality reduction on X. This dimensionality reduction can be performed using truncated SVD.
#
# 2. **Truncated SVD** (rank \(r\)):
#
#     In essence,
#     SVD, or singular value decomposition, is a technique in linear algebra that factorizes any matrix M into the product of 3 separate matrices: $M=U \times \Sigma \times V$, where (U) is a left singular vector matrix, $\Sigma$ is a diagonal matrix containing singular values of M and (V) is a right singular vector matrix. Singular values are real, non-negative numbers derived from a matrix through a process called Singular Value Decomposition (SVD). Specifically, they are the square roots of the eigenvalues of the matrix $M^TM$ (or $MM^T$ for real matrices), where $M^T$ is the transpose of M. They represent the "magnitude" of the transformation associated with the matrix. These values, along with corresponding singular vectors, allow for a matrix to be decomposed into a product of three matrices, providing insights into its properties and structure.
#
#     Critically, truncated SVD reduces dimensionality by selecting only the t largest singular values, and only keeping the first t columns of U and V. In this case, t is a hyperparameter we can select and adjust to reflect the number of topics we want to find
#
#     \begin{equation}
#      X = U\,\Sigma\,V^\top,
#      \quad
#      U\in\mathbb{R}^{D\times t},\;
#      \Sigma\in\mathbb{R}^{t\times t},\;
#      V\in\mathbb{R}^{V\times t}.
#     \end{equation}
#
#    Intuitively, think of this as only keeping the t most significant dimensions in our transformed space.
#    In this case, $U \in\mathbb{R}^{(D \times t)}$ emerges as our document-topic matrix, and $V \in\mathbb{R}^{(V \times t)}$ becomes our term-topic matrix. In both U and V, the columns correspond to one of our t topics. In U, rows represent document vectors expressed in terms of topics; in V, rows represent term vectors expressed in terms of topics.
#
#     With these document vectors and term vectors, we can now easily apply measures such as cosine similarity to evaluate:
#
#     - the similarity of different documents
#     - the similarity of different words
#     - the similarity of terms (or “queries”) and documents (which becomes useful in information retrieval, when we want to retrieve passages most relevant to our search query).
#
# 3. **Interpretation**
#    - Topics = the $r$ singular vectors (columns of $V$).
#    - Document embeddings = rows of $U\Sigma$.
#    - Word embeddings = rows of $V\Sigma$.
#
# **Key**: purely algebraic, can yield negative weights, fast closed‑form solution.
#
# ---

# %% [markdown]
# ### Eigen Vectors and EIgen Values
#
# In linear algebra, an eigenvector of a matrix(matrix=group of vectors) is a non-zero vector that, when a linear transformation is applied to it, is scaled by a constant (the eigenvalue). This means the eigenvector's direction remains unchanged, and the eigenvalue indicates the amount by which the vector is stretched or shrunk.
#
# **Eigenvectors:**
#
# These are special vectors associated with a matrix that don't change direction when the matrix is applied to them. They are also called characteristic vectors.
#
# **Eigenvalues:**
# These are the scalar values that represent how much the eigenvector is stretched or shrunk after the linear transformation.
#
# **Linear Transformation:**
# In the context of eigenvalues and eigenvectors, a linear transformation is represented by a matrix, and it's a function that maps vectors to other vectors, often involving scaling and rotation.
#
# **The Equation:**
# The relationship between an eigenvector (v), its corresponding eigenvalue (λ), and the matrix (A) is expressed as: Av = λv. This equation states that when matrix A is applied to the eigenvector v, the result is the same as scaling v by the eigenvalue λ

# %% [markdown]
# ## Latent Dirichlet Allocation (LDA)
#
# Similar to LSA, LDA is also an unsupervised technique that doesn't require labeled data. But, LDA uses a **probabilistic generative model** to infer the topics and their word distributions in a corpus. LDA assumes each document is a mixture of topics and attempts to uncover the underlying topic distributions for each document and the words within each topic.
#
# In essence, both techniques aim to uncover hidden topics in text data, but **LSA does so through a mathematical reduction of the data's complexity**, while **LDA uses a statistical model to infer the topics based on probabilities**.
#
# A **probabilistic** generative model:
#
# - For each document $d$:
#   1. Draw topic proportions
#     \begin{equation}
#      \theta_d \sim \mathrm{Dirichlet}(\alpha)
#     \end{equation}
#   2. For each word position \(n\):
#      - Draw topic
#        \begin{equation}
#         z_{d,n}\sim\mathrm{Categorical}(\theta_d)
#         \end{equation}
#      - Draw word
#        \begin{equation}
#         w_{d,n}\sim\mathrm{Categorical}(\varphi_{z_{d,n}})
#         \end{equation}
#
# - **Inference** (Gibbs sampling or variational Bayes) recovers:
#   - $\Theta = [\theta_d]\in\mathbb{R}^{D\times K} $ (doc × topic).
#   - $\Phi = [\varphi_k]\in\mathbb{R}^{K\times V} $ (topic × word).
#
# **Key**: topics are probability distributions, documents mix topics under a Dirichlet prior.
#
# ---
#
# Note:
#
# Both LSA (Latent Semantic Analysis) and LDA (Latent Dirichlet Allocation) are unsupervised machine learning techniques used for topic modeling, but they differ in their approach. LSA is a mathematical method based on dimensionality reduction using SVD, while LDA is a probabilistic model that learns the underlying topics and their distributions in a corpus.
#
# But if we know the underlying topics beforehand based on domain knowledge, we can treat these known topics as labels and turn the topic modeling to supervised multi-class text classification
#
# ---
#
# Intuition of LDA(Latent Dirichlet Allocation):
#
# LDA assumes:
#
# - Each document is a **mixture of topics** (like a recipe).
# - Each topic is a **distribution over words** (like a flavor profile).
#
# You give LDA a bunch of documents, and it tries to **reverse-engineer**:
# - What the topics are.
# - How much of each topic appears in each document.
# - Which words are strongly associated with each topic.
#
# ---
#
# ### Analogy: Pizza and Toppings
#
# Think of documents as pizzas and topics as toppings.
#
# - Each pizza (document) has some mixture of toppings (topics).
# - Each topping has certain ingredients (words).
#
# LDA looks at all the pizzas and tries to figure out:
# - What are the standard toppings (topics)?
# - Which toppings are on which pizza?
#
# ---
#
# ### What it gives you:
#
# 1. **Topic–Word Distribution** (e.g., Topic 2 is 40% "war", 30% "army", 30% "soldier")
# 2. **Document–Topic Distribution** (e.g., Document 7 is 70% Topic 2, 30% Topic 5)
#
# ---
#
# ### Key Concepts:
#
# - **Dirichlet distributions**: Priors that enforce sparsity (i.e., documents prefer a few topics; topics prefer a few words).
# - **Bag-of-words assumption**: Ignores word order, only cares about word counts.
#
# ---
#
# ### Summary:
#
# > **LDA = Soft clustering of words into topics, and soft clustering of documents into those topics.**
#
# Unlike K-means clustering which does hard assigment of docs to clusters.
#
# You don’t tell it what topics to use — it **finds them** based on patterns in word co-occurrence.
#
# ---
#
# Note: This is different from Linear Discirminant Analysis which is dimensionality reduction technique. Linear Discirminant Analysis is a supervised technique that utilizes class labels to find the feature subspace that maximizes class separability. Principal Component Analysis is an unsupervised technique(linear dimensionality reduction) and does not use class labels during dimensionality reduction. PCA is a widely used technique that transforms data into a lower-dimensional space by identifying the principal components, which capture the most variance in the data. t-Distributed Stochastic Neighbor Embedding t-SNE is a non-linear dimensionality reduction technique often used for data visualization, allowing for the exploration of relationships between data points in a lower-dimensional space
#
# ---

# %% [markdown]
# ## Non‑negative Matrix Factorization (NMF)
#
# An **algebraic** factorization of \(X\):
#
# \begin{equation}
#   X \;\approx\; W\,H,
#   \quad
#   W\in\mathbb{R}_{\ge0}^{D\times K},\;
#   H\in\mathbb{R}_{\ge0}^{K\times V}.
# \end{equation}
#
# - $W_{d,k}$: strength of topic $k$ in doc $d$.
# - $H_{k,w}$: weight of word $w$ in topic $k$.
# - Solved via multiplicative updates or alternating least squares.
#
# **Key**: non‑negativity yields interpretable “parts‑based” topics without probabilistic priors.
#
# ---

# %% [markdown]
# ## Advanced Extensions
#
# - **Correlated Topic Model (CTM)**
#   - Replaces Dirichlet on $\theta_d$ with a logistic normal, allowing topics to correlate.
# - **Hierarchical Dirichlet Process (HDP)**
#   - A nonparametric Bayesian model that **infers** the number of topics $K$ from data.
#
# ---

# %% [markdown]
# ## Workflow
#
# 1. **Preprocess** text: tokenize, remove stop‑words, (optionally) stem/lemmatize.
# 2. **Build** document–term matrix $X$.
# 3. **Choose** model & hyperparameters
#    - LSA: rank $r$.
#    - LDA/NMF: number of topics $K$
#    - HDP: no fixed $K$.
# 4. **Fit** model → obtain document $\times$ topic and topic $\times$ word factors.
# 5. **Inspect** results:
#    - Top‑$N$ words per topic $(\max_w \varphi_{k,w}$ or highest $H_{k,w}$).
#    - Topic proportions per document ($\theta_d$ or $W_{d,k}$).

# %% [markdown]
# ### Summary
#
# - **LSA** uses **SVD** to get latent dimensions (topics) but allows negative weights and lacks a probabilistic foundation.
# - **LDA** is a fully **probabilistic** model that treats documents as mixtures of topics under Dirichlet priors.
# - **NMF** is an **algebraic**, non‑negative factorization yielding interpretable soft topics.
# - **CTM** and **HDP** extend LDA for correlated topics and automatically determined topic counts, respectively.
#
# Each method offers a different balance of **speed**, **interpretability**, and **modeling assumptions**, but all aim to uncover the hidden thematic structure in text through **soft, overlapping groupings** of words and documents.
#
# | Feature            | LSA (SVD)            | LDA                        | NMF                        |
# |--------------------|----------------------|----------------------------|----------------------------|
# | Core method        | SVD (eigenvectors)   | Generative Bayesian model  | Constrained matrix factor. |
# | Topic vectors      | Real (±)             | Probabilities (≥0, sum 1)  | Weights (≥0)               |
# | Document mixture   | Real weights         | Dirichlet mixtures         | Real weights               |
# | Interpretability   | Medium               | High                       | High                       |
# | Complexity         | One SVD              | Iterative inference        | Iterative updates          |
#
# ---

# %% [markdown]
# ### Unsupervised Topic Modelling
# - TF-IDF Vectorized Representation
# - K-Means Clustering

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/NLP/data/trc_dn.json .
# !cp /content/drive/MyDrive/Colab\ Notebooks/NLP/data/months.json .

# %%
from textwrap import indent
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
import numpy as np

import json
import re
import string

def load_json(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data

def write_json(file_path, data):
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, file_path, indent=4)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# TF-IDF
def preprocess_text(stop_words, text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"AC\/\d{1,4}\/\d{1,4}", "", text)
    text = text.split()
    clean_text = []
    for w in text:
        if w not in stop_words and not w.isdigit():
            clean_text.append(w)
    clean_text = " ".join(clean_text)
    while "  " in clean_text:
        clean_text = clean_text.replace("  ", " ")
    return clean_text

def clean_data(docs):
    final_docs = []
    stop_words = stopwords.words("english")
    months = load_json("./months.json")
    stop_words = stop_words + months
    for doc in docs:
        cleaned_doc = preprocess_text(stop_words, doc)
        final_docs.append(cleaned_doc)
    return final_docs

# Prepare data
input_file_path = "./trc_dn.json"
docs = load_json(input_file_path)["descriptions"]
cleaned_docs = clean_data(docs)

# Tf-IDF vectorization
vectorizer = TfidfVectorizer(lowercase=True, stop_words="english", max_df=10, min_df=3, max_features=100, ngram_range=(1, 3))
vectors = vectorizer.fit_transform(cleaned_docs)  # (21747, 100)
feature_names = vectorizer.get_feature_names_out()

# Clustering
k=20
model = KMeans(n_clusters=k, init="k-means++", max_iter=300, n_init=1)
model.fit(vectors)  # (21747,)
# Out:
# KMeans(n_clusters=20, n_init=1)

# %%
clusters = model.cluster_centers_
clusters_sort = clusters.argsort()[:, ::-1]
feature_names = vectorizer.get_feature_names_out()

# %%
vectors.shape, type(clusters), clusters.shape, feature_names.shape, clusters_sort.shape
# Out:
# ((21747, 100), numpy.ndarray, (20, 100), (100,), (20, 100))

# %% [markdown]
# **What KMeans doing here?**
#
# Initializes k=20 random centroids in 100-dimensional space.
#
# Iteratively:
# - Assigns each document to the nearest centroid (based on Euclidean distance).
# - Updates the centroids as the mean of all documents assigned to that cluster.
#
# **What is the output of model.cluster_centers_?**
#
# Shape: (20, 100) → 20 cluster centroids, each with 100 TF-IDF dimensions.
# Each centroid is an average vector of all documents in that cluster.
# That's why, the cluster centers have the same features as your original TF-IDF vectors because KMeans never changes the feature space, it just groups and averages.
#
# Note: Each feature index corresponds to a TF-IDF term. We can interpret each cluster center by looking at its top TF-IDF terms — the most representative terms for that cluster.

# %%
topk = 10

for centroid in range(k):
    print(f"Cluster: {centroid}")
    print("\n")
    # Access the topk features per each centroid
    idxs = clusters_sort[centroid, :topk]
    for idx in idxs:
        print(feature_names[idx])
    print("\n")
# Out:
# Cluster: 0
#
#
# tvl july conflict
# steadville
# shot alleged
# supporters suspected proanc
# rates boycott
# mr ndlovu
# motherwell
# supporters supporters
# mufc
# coerced ifp
#
#
# Cluster: 1
#
#
# member disappeared
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 2
#
#
# conduct
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 3
#
#
# recruited military
# recruited military training
# ac19990030 ac19990197
# ac19990031 ac19990188
# ac19990031 ac19990188 ac19990030
# tsineng
# traffic officers
# terms
# supporters supporters
# tvl july conflict
#
#
# Cluster: 4
#
#
# xaba
# unita
# tvl july conflict
# tsineng
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 5
#
#
# distributing
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 6
#
#
# terms
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 7
#
#
# injured ifpsupporting residents
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 8
#
#
# killed thirty houses
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 9
#
#
# claims
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 10
#
#
# october perpetrator granted
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# supporters swanieville near
# terms
# supporters supporters
# steadville
#
#
# Cluster: 11
#
#
# hostage
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 12
#
#
# chief mangope
# funds
# xaba
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 13
#
#
# door
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 14
#
#
# colonel
# xaba
# tvl july conflict
# unita
# traffic officers
# terms
# supporters swanieville near
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 15
#
#
# ratanda heidelberg transvaal
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# supporters swanieville near
# terms
# supporters supporters
# steadville
#
#
# Cluster: 16
#
#
# presence area
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# supporters swanieville near
# terms
# supporters supporters
# steadville
#
#
# Cluster: 17
#
#
# rand tvl september
# rand tvl
# xaba
# unita
# tsineng
# tvl july conflict
# traffic officers
# terms
# supporters supporters
# steadville
#
#
# Cluster: 18
#
#
# supporters swanieville near
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# terms
# supporters suspected proanc
# supporters supporters
# steadville
#
#
# Cluster: 19
#
#
# poqo members
# xaba
# tvl july conflict
# unita
# tsineng
# traffic officers
# supporters swanieville near
# terms
# supporters supporters
# steadville

# %%
topk = 10
with open ("./trc_results.txt", "w", encoding="utf-8") as f:
    for centroid in range(k):
        f.write(f"Cluster: {centroid}")
        f.write("\n")
        # Access the topk features per each centroid
        features = clusters[centroid]
        for feat_idx in clusters_sort[centroid, :10]:
            f.write (' %s' % feature_names[feat_idx],)
            f.write("\n")
        f.write("\n")
        f.write("\n")

# %%
# Plotting the clusters using PCA
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Just 5 clusters for visualization purpose
k=5
model = KMeans(n_clusters=k, init="k-means++", max_iter=300, n_init=1)
kmean_indices = model.fit_predict(vectors) # both fit and predicts the clusters indices that each docs belongs to # shape (21747,) - think of it like test step, but we are just passing our train data itself
#(21747,)

# Dimensionality reduction
pca = PCA(n_components=2)
scatter_plot_points = pca.fit_transform(vectors.toarray())  # (21747, 100)
print(scatter_plot_points.shape, type(scatter_plot_points)) # (21747, 2), ndarray

# Plotting
fig, axes = plt.subplots(figsize=(15, 15))
colors = ["red", "green", "blue", "yellow", "orange"]
axes.scatter(scatter_plot_points[:, 0], scatter_plot_points[:, 1], c=[colors[idx] for idx in kmean_indices], alpha=0.6)

# Annotate with doc names (first 5 chars)
names = load_json(input_file_path)["names"]
for idx, name in enumerate(names):
    name = name[0:5]  # get the names(just first 5 chars) of related each doc
    axes.annotate(text=name, xy=(scatter_plot_points[idx, 0], scatter_plot_points[idx, 1]), fontsize=8)
plt.savefig("topic_clusters.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# (21747, 2) <class 'numpy.ndarray'>

# %% [markdown]
# ### UnSupervised Topic Modeling
#
# - TF-IDF Vector representation
# - LSA with Truncated SVD

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/NLP/data/trc_dn.json .
# !cp /content/drive/MyDrive/Colab\ Notebooks/NLP/data/months.json .

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords
nltk.download("stopwords")

import matplotlib.pyplot as plt
import numpy as np
import string
import json
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def load_json(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data

# TF-IDF
def preprocess_text(stop_words, text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"AC\/\d{1,4}\/\d{1,4}", "", text)
    text = text.split()
    clean_text = []
    for w in text:
        if w not in stop_words and not w.isdigit():
            clean_text.append(w)
    clean_text = " ".join(clean_text)
    while "  " in clean_text:
        clean_text = clean_text.replace("  ", " ")
    return clean_text

def clean_data(docs):
    final_docs = []
    stop_words = stopwords.words("english")
    months = load_json("./months.json")
    stop_words = stop_words + months
    for doc in docs:
        cleaned_doc = preprocess_text(stop_words, doc)
        final_docs.append(cleaned_doc)
    return final_docs

# Prepare data
input_file_path = "./trc_dn.json"
docs = load_json(input_file_path)["descriptions"]
cleaned_docs = clean_data(docs)

# Tf-IDF vectorization
vectorizer = TfidfVectorizer(lowercase=True, stop_words="english", max_df=10, min_df=3, max_features=100, ngram_range=(1, 3))
# gives original matrix M = (N_docs, n_features)

# LSA
trunc_svd_lsa = TruncatedSVD(n_components=100,  # num of topics
                             algorithm="randomized",
                             n_iter=10)

# pipeline of tf-idf + SVD, fit to and applied to documents:
svd_transformer = Pipeline([("tfidf", vectorizer),
                            ("lsa", trunc_svd_lsa)])

# U → Left singular vectors → (N_docs, n_components) → document-topic matrix
# S → Diagonal matrix of singular values → (n_components,) → captures strength of each topic
# Vᵗ → Right singular vectors → (n_components, N_features) → topic-word matrix

svd_matrix = svd_transformer.fit_transform(cleaned_docs)  # U = (N_docs, n_components)
# svd_matrix can later be used to compare documents, compare words, or compare queries with documents

# Get the components (topics) from the SVD
components = trunc_svd_lsa.components_  # Vt - shape: (n_components, n_features) -> (topics, wordvectors)

# Get the TF-IDF feature names
feature_names = vectorizer.get_feature_names_out()

# For each topic, get top-k words
top_k = 10
for topic_idx, topic_weights in enumerate(components):
    top_feature_indices = topic_weights.argsort()[::-1][:top_k]
    top_features = [feature_names[i] for i in top_feature_indices]
    print(f"Topic {topic_idx + 1}: {', '.join(top_features)}")
# Out:
# Topic 1: conduct, kutloanong, ratanda heidelberg transvaal, motherwell, supporters suspected proanc, mr ndlovu, xaba, hostage, member ancyl, rent increases
# Topic 2: steadville, killed thirty houses, supporters suspected proanc, terms, arson attack alleged, kutloanong, mufc, supporters swanieville near, commander vlakplaas applied, rent increases
# Topic 3: supporters supporters, commanders, member disappeared, mr ndlovu, rates boycott, distributing, commander vlakplaas applied, dladla, killed thirty houses, motherwell
# Topic 4: mufc, october perpetrator granted, guguletu seven, injuries result, xaba, presence area, tvl july conflict, injured vehicle, funds, chief mangope
# Topic 5: dladla, coerced ifp, killed thousand homes, guguletu seven, mr ndlovu, supporters suspected proanc, assaulted killed, kutloanong, xaba, rates boycott
# Topic 6: supporters swanieville near, injured vehicle, rates boycott, mr ndlovu, commanders, employer, commander vlakplaas applied, steadville, presence area, claims
# Topic 7: injuries result, assaulted killed, shot alleged, xaba, steadville, motherwell, supporters swanieville near, injured ifpsupporting residents, distributing, claims
# Topic 8: injured limpet placed, door, mr ndlovu, ratanda heidelberg transvaal, october perpetrator granted, commanders, killed thousand homes, member disappeared, dam, assaulted killed
# Topic 9: claims, hostage, injured vehicle, kutloanong, killed thirty houses, motherwell, dladla, injured ifpsupporting residents, shot alleged, carnarvon
# Topic 10: shot alleged, terms, rent increases, member ancyl, presence area, hostage, arson attack alleged, tvl july conflict, injuries result, rates boycott
# Topic 11: mr ndlovu, tvl july conflict, shot alleged, carnarvon, terms, motherwell, kutloanong, distributing, azasm, injured ifpsupporting residents
# Topic 12: injured ifpsupporting residents, injured limpet placed, dladla, tvl july conflict, motherwell, employer, commander vlakplaas applied, killed thousand homes, terms, carnarvon
# Topic 13: member disappeared, killed thirty houses, guguletu seven, assaulted killed, rates boycott, presence area, rent increases, member ancyl, coerced ifp, steadville
# Topic 14: claims, tvl july conflict, ac19990031 ac19990188 ac19990030, recruited military, ac19990031 ac19990188, ac19990030 ac19990197, recruited military training, injured limpet placed, commander vlakplaas applied, carnarvon
# Topic 15: october perpetrator granted, chief mangope, funds, tvl july conflict, mr ndlovu, supporters supporters, member ancyl, rent increases, ratanda heidelberg transvaal, rand tvl
# Topic 16: commander vlakplaas applied, presence area, kutloanong, member ancyl, rent increases, azasm, funds, chief mangope, motherwell, door
# Topic 17: injuries result, rates boycott, kutloanong, motherwell, commander vlakplaas applied, guguletu seven, commanders, injured ifpsupporting residents, supporters suspected proanc, arson attack alleged
# Topic 18: presence area, employer, kutloanong, claims, motherwell, killed thousand homes, october perpetrator granted, mufc, supporters supporters, coerced ifp
# Topic 19: injured limpet placed, motherwell, rand tvl, rand tvl september, coerced ifp, dam, presence area, steadville, arson attack alleged, dladla
# Topic 20: claims, arson attack alleged, member ancyl, rent increases, motherwell, conduct, member disappeared, coerced ifp, mr ndlovu, tvl july conflict
# Topic 21: xaba, injured limpet placed, ratanda heidelberg transvaal, arson attack alleged, supporters supporters, mufc, kutloanong, azasm, assaulted killed, member ancyl
# Topic 22: azasm, steadville, presence area, assaulted killed, claims, chief mangope, funds, motherwell, injuries result, ratanda heidelberg transvaal
# Topic 23: abbots poort, supporters supporters, journalist, removing, member disappeared, distributing, commanders, rates boycott, saso, unita
# Topic 24: employer, commanders, injured ifpsupporting residents, ratanda heidelberg transvaal, injured home attacked, killed severely injured, killed severely, claims, injured limpet placed, mr ndlovu
# Topic 25: distributing, door, hostage, presence area, tvl july conflict, motherwell, guguletu seven, ratanda heidelberg transvaal, claims, supporters swanieville near
# Topic 26: supporters suspected proanc, presence area, mufc, kutloanong, carnarvon, door, member disappeared, azasm, rates boycott, dam
# Topic 27: injuries result, killed thirty houses, xaba, arson attack alleged, claims, ratanda heidelberg transvaal, hostage, dladla, distributing, mr ndlovu
# Topic 28: guguletu seven, supporters suspected proanc, dam, rand tvl september, rand tvl, terms, claims, xaba, presence area, injured home attacked
# Topic 29: assaulted killed, door, arson attack alleged, commanders, dam, supporters supporters, supporters swanieville near, october perpetrator granted, presence area, rent increases
# Topic 30: injured vehicle, terms, injured limpet placed, ratanda heidelberg transvaal, injured ifpsupporting residents, carnarvon, supporters suspected proanc, presence area, kutloanong, distributing
# Topic 31: commander vlakplaas applied, distributing, dam, terms, injured home attacked, killed severely injured, killed severely, injured vehicle, presence area, member ancyl
# Topic 32: guguletu seven, injured limpet placed, member disappeared, distributing, chief mangope, funds, employer, supporters swanieville near, kutloanong, terms
# Topic 33: claims, member disappeared, commander vlakplaas applied, carnarvon, injuries result, tvl july conflict, supporters supporters, steadville, killed thirty houses, conduct
# Topic 34: supporters swanieville near, shot alleged, presence area, ratanda heidelberg transvaal, mufc, guguletu seven, carnarvon, arson attack alleged, door, assaulted killed
# Topic 35: commanders, killed thousand homes, xaba, steadville, presence area, carnarvon, dladla, door, terms, tvl july conflict
# Topic 36: injuries result, killed thirty houses, ratanda heidelberg transvaal, tvl july conflict, dam, dladla, kutloanong, mufc, commanders, supporters swanieville near
# Topic 37: killed thousand homes, mufc, rates boycott, injuries result, commanders, carnarvon, hostage, distributing, member ancyl, rent increases
# Topic 38: terms, mufc, rates boycott, guguletu seven, motherwell, hostage, coerced ifp, commander vlakplaas applied, door, steadville
# Topic 39: supporters supporters, dladla, conduct, rates boycott, door, steadville, killed thirty houses, dam, october perpetrator granted, guguletu seven
# Topic 40: dam, xaba, supporters swanieville near, killed thousand homes, member disappeared, carnarvon, terms, killed thirty houses, rates boycott, conduct
# Topic 41: door, member disappeared, october perpetrator granted, injured home attacked, killed severely, killed severely injured, motherwell, rand tvl september, rand tvl, terms
# Topic 42: carnarvon, hostage, supporters swanieville near, coerced ifp, guguletu seven, october perpetrator granted, killed thirty houses, supporters supporters, injured limpet placed, commanders
# Topic 43: coerced ifp, injured ifpsupporting residents, kutloanong, dam, supporters swanieville near, steadville, commanders, member disappeared, chief mangope, funds
# Topic 44: conduct, rand tvl september, rand tvl, october perpetrator granted, tvl july conflict, kutloanong, distributing, shot alleged, killed thousand homes, mufc
# Topic 45: member disappeared, commanders, ratanda heidelberg transvaal, azasm, october perpetrator granted, conduct, member ancyl, rent increases, supporters suspected proanc, distributing
# Topic 46: bafokeng, bophuthatswana september, bophuthatswana security, cosatu official, employer, door, claims, october perpetrator granted, guguletu seven, steadville
# Topic 47: removing, local crossroads leader, flat, pholile, arson attack april, mcilongo, employer, door, steadville, dam
# Topic 48: african security force, saso, bethal, flat, pholile, commanders, employer, injured ifpsupporting residents, coerced ifp, hostage
# Topic 49: flat, pholile, arson attack april, mcilongo, bophuthatswana police detention, tsineng, assaulted killed, injured ifpsupporting residents, conduct, hostage
# Topic 50: bophuthatswana police detention, tsineng, removing, local crossroads leader, bafokeng, mufc, bophuthatswana security, arson attack alleged, bophuthatswana september, african security force
# Topic 51: member arrested tortured, journalist, port elizabeth security, elizabeth security, member port, member port elizabeth, african security force, saso, door, bethal
# Topic 52: private security, security guard shot, guard shot, journalist, local crossroads leader, coerced ifp, colonel, gangraped, bafokeng, removing
# Topic 53: bophuthatswana security, bophuthatswana september, cosatu official, member arrested tortured, private security, bethal, guard shot, security guard shot, flat, local crossroads leader
# Topic 54: journalist, bophuthatswana security, bophuthatswana september, cosatu official, killed sap, traffic officers, amaqabane, nkowa, member ancyl, chief mangope
# Topic 55: gangraped, colonel, killed sap, middelburg police, african security force, member ancyl, amaqabane, traffic officers, killed severely injured, killed severely
# Topic 56: basotho, amaqabane, poqo members, middelburg police, pholile, sofasonke, injured home attacked, african security force, chief mangope, backed
# Topic 57: colonel, amaqabane, funds, basotho, flat, bethal, poqo members, saso, middelburg police, member ancyl
# Topic 58: member ancyl, funds, poqo members, african security force, pholile, middelburg police, injured home attacked, gangraped, removing, arson attack alleged
# Topic 59: poqo members, traffic officers, flat, chief mangope, african security force, middelburg police, killed severely, killed severely injured, rent increases, nkowa
# Topic 60: sofasonke, flat, basotho, backed, nkowa, killed severely, killed severely injured, funds, african security force, middelburg police
# Topic 61: nkowa, amaqabane, killed sap, poqo members, sofasonke, member ancyl, traffic officers, colonel, backed, funds
# Topic 62: traffic officers, gangraped, funds, bethal, flat, killed sap, basotho, saso, middelburg police, rent increases
# Topic 63: basotho, nkowa, member ancyl, injured home attacked, colonel, chief mangope, traffic officers, flat, gangraped, bethal
# Topic 64: middelburg police, nkowa, poqo members, rent increases, colonel, killed sap, pholile, funds, african security force, basotho
# Topic 65: middelburg police, nkowa, bethal, member ancyl, chief mangope, saso, killed severely, killed severely injured, flat, traffic officers
# Topic 66: middelburg police, injured home attacked, sofasonke, traffic officers, backed, colonel, funds, member ancyl, nkowa, african security force
# Topic 67: killed sap, traffic officers, member ancyl, basotho, poqo members, funds, african security force, colonel, pholile, sofasonke
# Topic 68: injured home attacked, killed sap, flat, gangraped, middelburg police, amaqabane, chief mangope, african security force, member ancyl, poqo members
# Topic 69: bethal, sofasonke, poqo members, gangraped, member ancyl, middelburg police, colonel, saso, backed, chief mangope
# Topic 70: local crossroads leader, arson attack april, mcilongo, gangraped, injured home attacked, nkowa, african security force, colonel, funds, member arrested tortured
# Topic 71: eagles, eagles club, local crossroads leader, arson attack april, basotho, mcilongo, rent increases, middelburg police, injured home attacked, gangraped
# Topic 72: member port elizabeth, member port, elizabeth security, port elizabeth security, african security force, arson attack april, mcilongo, bethal, tsineng, local crossroads leader
# Topic 73: unita, mk soldiers, saso, member port elizabeth, member port, backed, local crossroads leader, tsineng, nkowa, pholile
# Topic 74: tsineng, bethal, african security force, bophuthatswana security, arson attack april, colonel, mcilongo, basotho, cosatu official, bafokeng
# Topic 75: bophuthatswana september, saso, tsineng, local crossroads leader, shandu, backed, middelburg police, unita, dam, mk soldiers
# Topic 76: saso, tsineng, bophuthatswana security, arson attack april, mcilongo, member port, member port elizabeth, backed, cosatu official, elizabeth security
# Topic 77: arson attack april, mcilongo, removing, bethal, unita, african security force, backed, mk soldiers, ivory park, ivory
# Topic 78: backed, ivory park, ivory, shandu, tsineng, gangraped, saso, local crossroads leader, funds, killed sap
# Topic 79: shandu, sofasonke, ivory, ivory park, azasm, coerced ifp, guguletu seven, saso, supporters swanieville near, ac19990030 ac19990197
# Topic 80: shandu, backed, bethal, african security force, azasm, mcilongo, bophuthatswana security, coerced ifp, guguletu seven, member arrested tortured
# Topic 81: committee led, committee led mr, led mr, shandu, kwelerha, saso, mcilongo, bophuthatswana security, flat, bafokeng
# Topic 82: port elizabeth security, elizabeth security, cosatu official, bophuthatswana september, committee led, committee led mr, led mr, pholile, private security, amaqabane
# Topic 83: cosatu official, bophuthatswana september, member port elizabeth, member port, journalist, member arrested tortured, kwelerha, led mr, committee led, committee led mr
# Topic 84: kwelerha, arson attack april, bophuthatswana security, port elizabeth security, elizabeth security, removing, bafokeng, dam, security guard shot, guard shot
# Topic 85: mcilongo, local crossroads leader, flat, pholile, kwelerha, cosatu official, elizabeth security, port elizabeth security, unita, mk soldiers
# Topic 86: private security, ac19990031 ac19990188, bethal, ac19990030 ac19990197, eagles club, member port elizabeth, member port, kwelerha, recruited military, recruited military training
# Topic 87: mk soldiers, eagles, pholile, security guard shot, guard shot, mcilongo, backed, flat, bophuthatswana security, member arrested tortured
# Topic 88: eagles club, african security force, mk soldiers, journalist, recruited military, recruited military training, rent increases, tsineng, ac19990031 ac19990188, employer
# Topic 89: elizabeth security, led mr, guard shot, ac19990031 ac19990188 ac19990030, ivory, ac19990030 ac19990197, arson attack alleged, backed, gangraped, commanders
# Topic 90: member port elizabeth, killed severely, ivory, committee led mr, ac19990031 ac19990188 ac19990030, elizabeth security, security guard shot, recruited military training, recruited military, committee led
# Topic 91: committee led mr, ac19990031 ac19990188, ac19990031 ac19990188 ac19990030, port elizabeth security, guard shot, ivory park, ac19990030 ac19990197, member port, killed severely injured, hostage
# Topic 92: killed severely injured, ivory, recruited military, recruited military training, committee led mr, port elizabeth security, guard shot, led mr, member port elizabeth, door
# Topic 93: committee led, ivory, ac19990031 ac19990188, guard shot, elizabeth security, ac19990031 ac19990188 ac19990030, killed severely injured, member port, ac19990030 ac19990197, shot alleged
# Topic 94: rand tvl, recruited military, door, conduct, motherwell, supporters suspected proanc, commander vlakplaas applied, distributing, kutloanong, terms
# Topic 95: recruited military, rand tvl september, xaba, assaulted killed, injured ifpsupporting residents, dladla, mufc, rates boycott, injured vehicle, injured limpet placed
# Topic 96: ivory, security guard shot, killed severely, member port, committee led mr, elizabeth security, ac19990031 ac19990188 ac19990030, ac19990030 ac19990197, recruited military, recruited military training
# Topic 97: ac19990031 ac19990188 ac19990030, port elizabeth security, led mr, committee led, ac19990030 ac19990197, security guard shot, killed severely injured, ivory, member port elizabeth, eagles club
# Topic 98: security guard shot, ac19990031 ac19990188, killed severely injured, led mr, member port elizabeth, elizabeth security, ivory, employer, kwelerha, rates boycott
# Topic 99: ac19990031 ac19990188, led mr, ivory, port elizabeth security, killed severely, guard shot, member port elizabeth, middelburg police, colonel, member disappeared
# Topic 100: ac19990030 ac19990197, elizabeth security, led mr, guard shot, ivory, october perpetrator granted, carnarvon, tvl july conflict, rand tvl september, rand tvl

# %%
feature_names
# Out:
# array(['abbots poort', 'ac19990030 ac19990197', 'ac19990031 ac19990188',
#        'ac19990031 ac19990188 ac19990030', 'african security force',
#        'amaqabane', 'arson attack alleged', 'arson attack april',
#        'assaulted killed', 'azasm', 'backed', 'bafokeng', 'basotho',
#        'bethal', 'bophuthatswana police detention',
#        'bophuthatswana security', 'bophuthatswana september', 'carnarvon',
#        'chief mangope', 'claims', 'coerced ifp', 'colonel',
#        'commander vlakplaas applied', 'commanders', 'committee led',
#        'committee led mr', 'conduct', 'cosatu official', 'dam',
#        'distributing', 'dladla', 'door', 'eagles', 'eagles club',
#        'elizabeth security', 'employer', 'flat', 'funds', 'gangraped',
#        'guard shot', 'guguletu seven', 'hostage', 'injured home attacked',
#        'injured ifpsupporting residents', 'injured limpet placed',
#        'injured vehicle', 'injuries result', 'ivory', 'ivory park',
#        'journalist', 'killed sap', 'killed severely',
#        'killed severely injured', 'killed thirty houses',
#        'killed thousand homes', 'kutloanong', 'kwelerha', 'led mr',
#        'local crossroads leader', 'mcilongo', 'member ancyl',
#        'member arrested tortured', 'member disappeared', 'member port',
#        'member port elizabeth', 'middelburg police', 'mk soldiers',
#        'motherwell', 'mr ndlovu', 'mufc', 'nkowa',
#        'october perpetrator granted', 'pholile', 'poqo members',
#        'port elizabeth security', 'presence area', 'private security',
#        'rand tvl', 'rand tvl september', 'ratanda heidelberg transvaal',
#        'rates boycott', 'recruited military',
#        'recruited military training', 'removing', 'rent increases',
#        'saso', 'security guard shot', 'shandu', 'shot alleged',
#        'sofasonke', 'steadville', 'supporters supporters',
#        'supporters suspected proanc', 'supporters swanieville near',
#        'terms', 'traffic officers', 'tsineng', 'tvl july conflict',
#        'unita', 'xaba'], dtype=object)

# %%
components.shape
# Out:
# (100, 100)

# %%
svd_matrix.shape
# Out:
# (21747, 100)

# %% [markdown]
# components_ is a matrix where each row is a "topic", and each column is a TF-IDF feature (word/ngram).
#
# Higher values in a row mean the feature contributes more to that topic.
#
# Sorting helps you get the top k features that best describe each top

# %%
# Self Practice
def load_json(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data

# TF-IDF
def preprocess_text(stop_words, text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"AC\/\d{1,4}\/\d{1,4}", "", text)
    text = text.split()
    clean_text = []
    for w in text:
        if w not in stop_words and not w.isdigit():
            clean_text.append(w)
    clean_text = " ".join(clean_text)
    while "  " in clean_text:
        clean_text = clean_text.replace("  ", " ")
    return clean_text

def clean_data(docs):
    final_docs = []
    stop_words = stopwords.words("english")
    months = load_json("./months.json")
    stop_words = stop_words + months
    for doc in docs:
        cleaned_doc = preprocess_text(stop_words, doc)
        final_docs.append(cleaned_doc)
    return final_docs

# Prepare data
input_file_path = "./trc_dn.json"
docs = load_json(input_file_path)["descriptions"]
cleaned_docs = clean_data(docs)

# tf-idf
vectorizer = TfidfVectorizer(lowercase=True, stop_words="english", max_features=100, max_df=10, min_df=5, ngram_range=(1, 3))
# lsa
svd_lsa = TruncatedSVD(n_components=100, n_iter=100, algorithm="randomized")
# pipe
pipe = Pipeline([
    ("tfidf", vectorizer),
    ("lda", svd_lsa)
])

svd_matrix = pipe.fit_transform(cleaned_docs) # n_components, n_features

feature_names = vectorizer.get_feature_names_out()
components = svd_lsa.components_

topk=10
for topic_id, topic_vector in enumerate(components):
    idxs = topic_vector.argsort()[::-1][:topk]
    topics = [feature_names[idx] for idx in idxs]
    print(f"Topic {topic_id + 1}: {', '.join(topics)}")
# Out:
# Topic 1: place political, employer, june operatives sadf, guguletu seven, bafokeng, uprising mr, dladla, mr ndlovu, terms, supreme court
# Topic 2: taxi ac19990225, june operatives sadf, guguletu seven, teargassed members sap, local crossroads leader, dladla, azasm, pietersburg transvaal january, chief mangope, survived explosion
# Topic 3: ac19980026, june operatives sadf, paterson cape, kutloanong, bafokeng, phola park residents, teargassed members sap, survived explosion, employer, charged sabotage
# Topic 4: xaba, guguletu seven, chief mangope, supporters supporters, charged arson, carnarvon, employer, pietersburg transvaal january, survived explosion, security unit
# Topic 5: congress kyc khutsong, june severely, pietermaritzburg november intensifying, teargassed members sap, employer, xaba, charges withdrawn, supporters supporters, tension conflict, place ongoing
# Topic 6: pinetown natal april, place political, pietermaritzburg november intensifying, pietermaritzburg political conflict, place ongoing political, place ongoing, piet retief ambushes, kakamas, kakamas cape, paterson cape
# Topic 7: mr ndlovu, bafokeng, flat, pholile, place ongoing, place ongoing political, suspected proanc, suspected proanc lost, supporters suspected proanc, dam
# Topic 8: ac2000250, charged convicted sentenced, azasm, employer, june severely, charges withdrawn, paterson cape, pietermaritzburg november intensifying, pietermaritzburg political conflict, local crossroads leader
# Topic 9: pietermaritzburg political conflict, piet retief ambushes, june operatives sadf, coerced ifp membership, coerced ifp, pietersburg transvaal january, supporters supporters, chief mangope, xaba, kakamas cape
# Topic 10: local crossroads leader, ac2000250, mr ndlovu, place political, steadville, june severely, xaba, door, terms, supreme court
# Topic 11: distributing, piet retief ambushes, ac2000250, pietermaritzburg november intensifying, presence area, ac19980026, flat, pholile, taxi ac19990225, security unit
# Topic 12: pietermaritzburg political conflict, azasm, kabokweni, kabokweni kangwane, security unit, uprising mr, june operatives sadf, motherwell, pholile, flat
# Topic 13: dladla, june operatives sadf, door, june severely, chief mangope, ac19980026, charged arson, carnarvon, kabokweni, kabokweni kangwane
# Topic 14: tension conflict, charges withdrawn, chief mangope, pietersburg transvaal january, uprising mr, june severely, dam, terms, supreme, supreme court
# Topic 15: place political, kutloanong, ac2000250, paterson cape, security unit, dladla, motherwell, dam, uprising mr, charges withdrawn
# Topic 16: motherwell, ac2000250, bafokeng, guguletu seven, phola park residents, kakamas cape, kakamas, presence area, survived explosion, suspected proanc lost
# Topic 17: congress kyc khutsong, uprising mr, flat, pholile, ac19980026, steadville, presence area, xaba, mr ndlovu, kutloanong
# Topic 18: june detained emergency, aberdeen, aberdeen cape, ac19980026, carnarvon, local crossroads leader, kutloanong, flat, paterson cape, phola park residents
# Topic 19: june severely, ac19980026, chief mangope, survived explosion, kutloanong, bafokeng, pietersburg transvaal january, dam, door, congress kyc khutsong
# Topic 20: paterson cape, pinetown natal april, employer, congress kyc khutsong, kutloanong, uprising mr, dladla, distributing, kakamas cape, kakamas
# Topic 21: supporters supporters, kutloanong, ac2000250, taxi ac19990225, presence area, teargassed members sap, kakamas cape, kakamas, kabokweni, kabokweni kangwane
# Topic 22: uprising people, distributing, paterson cape, teargassed members sap, chief mangope, place political, security unit, tension conflict, guguletu seven, pietersburg transvaal january
# Topic 23: dam, presence area, azasm, paterson cape, taxi ac19990225, terms, supreme, supreme court, bafokeng, xaba
# Topic 24: tension conflict, local crossroads leader, charged convicted sentenced, motherwell, pietersburg transvaal january, presence area, security unit, dladla, pinetown natal april, place ongoing
# Topic 25: bafokeng, congress kyc khutsong, security unit, mr ndlovu, paterson cape, azasm, piet retief ambushes, charged sabotage, ac19980026, dladla
# Topic 26: presence area, charged sabotage, june severely, distributing, place political, survived explosion, uprising mr, xaba, place ongoing political, place ongoing
# Topic 27: security unit, pinetown natal april, kutloanong, mr ndlovu, taxi ac19990225, chief mangope, bafokeng, charges withdrawn, dam, door
# Topic 28: employer, taxi ac19990225, steadville, charged arson, carnarvon, coerced ifp membership, coerced ifp, dam, place political, survived explosion
# Topic 29: local crossroads leader, xaba, charges withdrawn, taxi ac19990225, paterson cape, kabokweni, kabokweni kangwane, uprising people, pietermaritzburg political conflict, ac19980026
# Topic 30: place political, azasm, pietersburg transvaal january, phola park residents, dladla, congress kyc khutsong, chief mangope, motherwell, taxi ac19990225, steadville
# Topic 31: phola park residents, chief mangope, june operatives sadf, paterson cape, place political, survived explosion, security unit, ac2000250, taxi ac19990225, piet retief ambushes
# Topic 32: survived explosion, door, teargassed members sap, uprising people, coerced ifp membership, coerced ifp, employer, uprising mr, ac2000250, taxi ac19990225
# Topic 33: steadville, chief mangope, dladla, piet retief ambushes, flat, pholile, charges withdrawn, supporters supporters, security unit, carnarvon
# Topic 34: motherwell, chief mangope, teargassed members sap, pietermaritzburg november intensifying, ac19980026, paterson cape, taxi ac19990225, uprising mr, june severely, presence area
# Topic 35: distributing, azasm, ac2000250, june operatives sadf, survived explosion, place ongoing political, place ongoing, pinetown natal april, mr ndlovu, supporters supporters
# Topic 36: steadville, charges withdrawn, pietermaritzburg political conflict, june operatives sadf, presence area, phola park residents, paterson cape, bafokeng, mr ndlovu, uprising people
# Topic 37: uprising people, pinetown natal april, june operatives sadf, presence area, dam, dladla, charged sabotage, kakamas, kakamas cape, teargassed members sap
# Topic 38: supporters supporters, teargassed members sap, guguletu seven, pietermaritzburg political conflict, dam, charges withdrawn, place political, june operatives sadf, azasm, supreme
# Topic 39: pietermaritzburg november intensifying, tension conflict, place political, chief mangope, pietermaritzburg political conflict, charged sabotage, bafokeng, uprising people, supporters supporters, pietersburg transvaal january
# Topic 40: june severely, paterson cape, security unit, guguletu seven, supporters supporters, coerced ifp membership, coerced ifp, june operatives sadf, charged sabotage, kabokweni
# Topic 41: door, employer, charged sabotage, presence area, kutloanong, kabokweni kangwane, kabokweni, tension conflict, pietermaritzburg political conflict, supreme
# Topic 42: charged sabotage, charges withdrawn, coerced ifp membership, coerced ifp, uprising mr, ac2000250, xaba, phola park residents, place ongoing political, place ongoing
# Topic 43: mr ndlovu, charged convicted sentenced, charged arson, carnarvon, presence area, supporters supporters, ac19980026, kakamas cape, kakamas, taxi ac19990225
# Topic 44: tension conflict, uprising mr, dladla, june severely, door, taxi ac19990225, xaba, flat, pholile, pinetown natal april
# Topic 45: pietermaritzburg november intensifying, phola park residents, security unit, presence area, uprising mr, employer, steadville, local crossroads leader, place ongoing, place ongoing political
# Topic 46: bafokeng, door, ac2000250, steadville, uprising people, taxi ac19990225, uprising mr, pietermaritzburg november intensifying, kabokweni, kabokweni kangwane
# Topic 47: door, charges withdrawn, kakamas, kakamas cape, presence area, azasm, xaba, charged convicted sentenced, place political, pholile
# Topic 48: motherwell, uprising people, charged convicted sentenced, june operatives sadf, uprising mr, charged sabotage, taxi ac19990225, june severely, dladla, place political
# Topic 49: door, local crossroads leader, azasm, distributing, charged arson, carnarvon, bafokeng, uprising people, place political, phola park residents
# Topic 50: taxi driver, parties, ivory, ivory park, african security force, saso, bethal, police raided, mufc, club mufc
# Topic 51: african security force, saso, bethal, police raided, tension conflict, guguletu seven, mr ndlovu, chief mangope, azasm, ac19980026
# Topic 52: mufc, club mufc, african security force, police raided, saso, bethal, xaba, basotho, chief mangope, door
# Topic 53: journalist, port elizabeth security, elizabeth security, private security, guard shot, security guard shot, mufc, club mufc, african security force, colonel
# Topic 54: private security, security guard shot, guard shot, bethal, mufc, police raided, club mufc, mr ndlovu, sofasonke, phola park residents
# Topic 55: police raided, bethal, saso, journalist, elizabeth security, port elizabeth security, nkowa, eagles, charged convicted sentenced, eagles club
# Topic 56: nkowa, traffic officers, middelburg police, gangraped, carnarvon, poqo members, flat, terms, sofasonke, backed
# Topic 57: gangraped, terms, middelburg police, pholile, amaqabane, sofasonke, colonel, backed, charged arson, police raided
# Topic 58: traffic officers, amaqabane, poqo members, basotho, terms, charged arson, pholile, charged sabotage, uprising people, motherwell
# Topic 59: poqo members, tsineng, pholile, amaqabane, gangraped, sofasonke, supreme court, supreme, backed, middelburg police
# Topic 60: terms, amaqabane, nkowa, carnarvon, tsineng, flat, eagles, eagles club, charged sabotage, dladla
# Topic 61: amaqabane, flat, middelburg police, supreme, supreme court, sofasonke, charged arson, backed, traffic officers, shandu
# Topic 62: tsineng, middelburg police, terms, charged arson, flat, sofasonke, colonel, basotho, backed, poqo members
# Topic 63: gangraped, flat, basotho, charged arson, middelburg police, tsineng, terms, eagles, eagles club, dam
# Topic 64: carnarvon, middelburg police, colonel, amaqabane, basotho, tsineng, poqo members, traffic officers, terms, flat
# Topic 65: tsineng, supreme, supreme court, gangraped, traffic officers, colonel, nkowa, carnarvon, amaqabane, pholile
# Topic 66: gangraped, sofasonke, basotho, amaqabane, flat, backed, colonel, nkowa, tsineng, terms
# Topic 67: poqo members, colonel, gangraped, flat, charged arson, terms, azasm, mr ndlovu, survived explosion, june severely
# Topic 68: june detained emergency, ac19980026, carnarvon, local crossroads leader, kutloanong, paterson cape, flat, phola park residents, uprising people, employer
# Topic 69: amaqabane, nkowa, charged arson, traffic officers, colonel, basotho, pholile, poqo members, terms, teargassed members sap
# Topic 70: eagles, eagles club, amaqabane, middelburg police, tsineng, unita, terms, traffic officers, colonel, saso
# Topic 71: saso, bethal, taxi driver, tsineng, sofasonke, gangraped, charged arson, flat, nkowa, middelburg police
# Topic 72: parties, ivory, ivory park, saso, bethal, charged arson, amaqabane, presence area, eagles, eagles club
# Topic 73: unita, mk soldiers, saso, carnarvon, shandu, cosatu official, basotho, uprising people, uprising mr, pinetown natal april
# Topic 74: bethal, african security force, shandu, sofasonke, unita, cosatu official, mk soldiers, poqo members, flat, basotho
# Topic 75: backed, mcilongo, bethal, port elizabeth security, elizabeth security, african security force, parties, unita, middelburg police, terms
# Topic 76: mcilongo, shandu, sofasonke, door, distributing, bethal, azasm, local crossroads leader, june severely, carnarvon
# Topic 77: shandu, backed, saso, basotho, pholile, police raided, terms, colonel, kutloanong, pietersburg transvaal january
# Topic 78: port elizabeth security, elizabeth security, parties, sofasonke, bethal, cosatu official, shandu, police raided, pholile, eagles club
# Topic 79: ivory, ivory park, taxi driver, elizabeth security, port elizabeth security, backed, cosatu official, saso, african security force, police raided
# Topic 80: cosatu official, led mr, committee led, committee led mr, shandu, mcilongo, nkowa, pholile, kwelerha, gangraped
# Topic 81: cosatu official, saso, mufc, parties, club mufc, journalist, basotho, nkowa, flat, june severely
# Topic 82: kwelerha, parties, teargassed members sap, coerced ifp, pietermaritzburg november intensifying, ivory, ivory park, mr ndlovu, dladla, shandu
# Topic 83: phoyco, chief mangope, eagles club, police raided, congress kyc khutsong, tension conflict, june operatives sadf, ac19980026, guguletu seven, supporters supporters
# Topic 84: private security, mk soldiers, distributing, dladla, pietermaritzburg political conflict, dam, june severely, steadville, guguletu seven, backed
# Topic 85: mk soldiers, journalist, club mufc, eagles, backed, port elizabeth security, elizabeth security, charged convicted sentenced, amaqabane, charged arson
# Topic 86: club mufc, eagles, basotho, unita, taxi driver, backed, parties, uprising people, flat, ivory park
# Topic 87: eagles club, club mufc, taxi driver, parties, african security force, saso, ac19980026, basotho, port elizabeth security, elizabeth security
# Topic 88: kakamas cape, kabokweni kangwane, security guard shot, committee led, coerced ifp, port elizabeth security, ivory park, aberdeen cape, pietermaritzburg november intensifying, ac2000250
# Topic 89: coerced ifp, committee led mr, port elizabeth security, guard shot, ivory park, kabokweni kangwane, kakamas, journalist, saso, survived explosion
# Topic 90: place ongoing political, pietersburg transvaal january, place political, pinetown natal april, pietermaritzburg november intensifying, ac2000250, dladla, mr ndlovu, presence area, phola park residents
# Topic 91: ivory, committee led, port elizabeth security, coerced ifp, kabokweni kangwane, guard shot, kakamas, ac19980026, poqo members, steadville
# Topic 92: committee led, coerced ifp, elizabeth security, kakamas, ivory park, kabokweni, guard shot, mr ndlovu, supreme, supreme court
# Topic 93: elizabeth security, committee led mr, security guard shot, coerced ifp membership, ivory, kabokweni, kakamas, cosatu official, paterson cape, azasm
# Topic 94: supporters suspected proanc, supreme court, local crossroads leader, dladla, teargassed members sap, place ongoing, survived explosion, june operatives sadf, june severely, steadville
# Topic 95: guard shot, kabokweni kangwane, elizabeth security, led mr, coerced ifp membership, kakamas cape, ivory, gangraped, terms, flat
# Topic 96: suspected proanc, supreme court, pietersburg transvaal january, dladla, chief mangope, taxi ac19990225, congress kyc khutsong, phola park residents, pietermaritzburg november intensifying, uprising people
# Topic 97: kabokweni kangwane, kakamas, security guard shot, port elizabeth security, ivory park, coerced ifp, committee led, carnarvon, basotho, chief mangope
# Topic 98: supreme, supporters suspected proanc, mr ndlovu, distributing, kabokweni, place ongoing, kabokweni kangwane, xaba, supporters supporters, azasm
# Topic 99: led mr, elizabeth security, coerced ifp, security guard shot, ivory, kabokweni, kakamas cape, aberdeen cape, ac19980026, journalist
# Topic 100: aberdeen, kakamas cape, kabokweni kangwane, security guard shot, committee led, coerced ifp, ivory park, sofasonke, port elizabeth security, colonel

# %% [markdown]
# ### Unsupervised Topic Modeling
# - LDA with Genism
# - Lemmatization with spaCy

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")

from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

import pyLDAvis
import pyLDAvis.gensim

import json
import re

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Gensim Dictionary and id2word

# %%
# Example of how genism Dictionary works
import gensim
from gensim.corpora import Dictionary

# Your tokenized documents (after preprocessing, bigrams/trigrams etc.)
docs = [
    ["human", "interface", "computer"],
    ["survey", "user", "computer", "system", "response", "time"],
    ["eps", "user", "interface", "system"],
    ["system", "human", "system", "eps"],
    ["user", "response", "time"],
    ["trees"],
    ["graph", "trees"],
    ["graph", "minors", "trees"],
    ["graph", "minors", "survey"]
]

# Create a dictionary from the docs
id2word = Dictionary(docs)
print(id2word.token2id)  # returns token: idx in the alphabetical order

new_doc = ["user", "interface", "user"]
bow = id2word.doc2bow(new_doc)  # doc2bow expects doc as list of tokens - returns bow type token-count per doc
print(bow)  # returns ((tokenid, count)) in the order of alphabetical words
# Out:
# {'computer': 0, 'human': 1, 'interface': 2, 'response': 3, 'survey': 4, 'system': 5, 'time': 6, 'user': 7, 'eps': 8, 'trees': 9, 'graph': 10, 'minors': 11}
# [(2, 1), (7, 2)]

# %%
# Example on what tf-idf helps to find more frequent and rare words
import gensim
from gensim.corpora import Dictionary

docs = [
    ["human", "interface", "computer"],
    ["survey", "user", "computer", "system", "response", "time"],
    ["eps", "user", "interface", "system"],
    ["system", "human", "system", "eps"],
    ["user", "response", "time"],
    ["trees"],
    ["graph", "trees"],
    ["graph", "minors", "trees"],
    ["graph", "minors", "survey"]
]
id2word = Dictionary(docs)
# Let's say your dictionary has
# id2word.token2id = {'computer': 0, 'human': 1, 'interface': 2, 'response': 3, 'survey': 4, 'system': 5, 'time': 6, 'user': 7, 'eps': 8, 'trees': 9, 'graph': 10, 'minors': 11}

# Generate corpus in bow format
corpus = [id2word.doc2bow(doc) for doc in docs]


new_doc = ["user", "interface", "user"]
bow = id2word.doc2bow(new_doc) # Your BoW for this new doc will be [(2, 1), (7, 2)] => [(word_id, frequency), (..)]
print(bow)  # [(2, 1), (7, 2)]

# Now apply TF-IDF to the bow of doc
tfidf = gensim.models.TfidfModel(corpus=corpus, id2word=id2word)
tfidf_scores = tfidf[bow] # you will get a list of tuples of (word_id, tfidf_score) for this doc - [(2, 0.5648663441460566), (7, 0.8251824121072071)]
print(tfidf_scores)
# Out:
# [(2, 1), (7, 2)]
# [(2, 0.5648663441460566), (7, 0.8251824121072071)]

# %% [markdown]
# Here
# - `corpus`: List of documents in **Bag-of-Words (BoW)** format — i.e., each doc is a list of `(word_id, count)` tuples.
# - `bow`: One document from that corpus(for loop) in the bow format.
# - `tfidf`: A trained `TfidfModel` object.
# - `tfidf[bow]`: Gives the **TF-IDF-weighted BoW** representation for that document.
#
# Essentially:
#
# tfidf[bow] = transforms a doc in BoW into TF-IDF weights, giving you:
# - Which words are important (high score)
# - Which are common and less meaningful (low score)

# %% [markdown]
# ### Gensim simple_preprocess

# %%
# gensim simple_preprocess - lowercases, tokenize,
# remove the other language accents like ä to a when deacc=True, removes tokens of length < 2 min_len=2, max_length=15
from gensim.utils import simple_preprocess
print(simple_preprocess("i you he she I it whéät you they", deacc=True))
print(simple_preprocess("i you he she I it whéät you they"))
# Out:
# ['you', 'he', 'she', 'it', 'wheat', 'you', 'they']
# ['you', 'he', 'she', 'it', 'whéät', 'you', 'they']

# %% [markdown]
# ### Gensim's Phrases and Phraser models
#
# Gelps group common word pairs/triples into single tokens i.e to generate bigram, trigrams etc (like "new_york" from "new" and "york").
#
# Think of:
# - Phrases as the trainer/model that learns what bigrams/trigrams to detect.
# - Phraser(light weight transformer) as the efficient filter that applies that knowledge to new data.
# Phraser is a lighter version of Phrases
#
# Phrases learns phrase collocations. It builds statistical phrase model. It is a model that can be trained. Basically used to learn model from text. Phrases learns which word pairs (like "new york") should be combined into "new_york" based on frequency and scoring.
#
# Phraser is Lightweight transformer which applies the phrases model to new texts.This can’t be trained (only used). Use after learning to transform. Phraser Converts the heavy model into a fast transformer. You now use phrasermdl[sentence] to turn e.g. ["new", "york", "city"] → ["new_york", "city"].

# %%
import gensim
from gensim.models import Phrases
from gensim.models.phrases import Phraser
from gensim.corpora import Dictionary

docs = [
    "human interface computer",
    "survey user computer system response time",
    "user response time minors survey computer",
    "trees computer system response",
    "graph trees minors survey computer",
    "graph minors trees",
    "graph minors survey computer system"
]

# simple preprocess
data = [gensim.utils.simple_preprocess(doc, deacc=True) for doc in docs]

bigram_phrases_mdl = Phrases(data, min_count=2, threshold=1)
trigram_phrases_mdl = Phrases(bigram_phrases_mdl[data], threshold=1)

bigram_phraser = Phraser(bigram_phrases_mdl)
trigram_phraser = Phraser(trigram_phrases_mdl)

print(data)
bigram_phrases_mdl, trigram_phrases_mdl, bigram_phraser, trigram_phraser
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['user', 'response', 'time', 'minors', 'survey', 'computer'], ['trees', 'computer', 'system', 'response'], ['graph', 'trees', 'minors', 'survey', 'computer'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey', 'computer', 'system']]
# (<gensim.models.phrases.Phrases at 0x78c0eeedb450>,
#  <gensim.models.phrases.Phrases at 0x78c0eeeda890>,
#  <gensim.models.phrases.FrozenPhrases at 0x78c0ecf1ffd0>,
#  <gensim.models.phrases.FrozenPhrases at 0x78c0eeedb1d0>)

# %%
# bigrams
data_bigrams = []
for doc in data:
    doc_bigram = bigram_phraser[doc]
    print(doc_bigram)
    data_bigrams.append(doc_bigram)
# Out:
# ['human', 'interface', 'computer']
# ['survey', 'user', 'computer_system', 'response', 'time']
# ['user', 'response', 'time', 'minors_survey', 'computer']
# ['trees', 'computer_system', 'response']
# ['graph', 'trees', 'minors_survey', 'computer']
# ['graph', 'minors', 'trees']
# ['graph', 'minors_survey', 'computer_system']

# %%
# trigrams
for doc in data_bigrams:
    print(trigram_phraser[bigram_phraser[doc]])
# Out:
# ['human', 'interface', 'computer']
# ['survey', 'user', 'computer_system', 'response', 'time']
# ['user', 'response', 'time', 'minors_survey', 'computer']
# ['trees', 'computer_system', 'response']
# ['graph', 'trees', 'minors_survey', 'computer']
# ['graph', 'minors', 'trees']
# ['graph', 'minors_survey', 'computer_system']

# %% [markdown]
# ### LDA Model with Gensim and pyLDAvis

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/NLP/data/ushmm_dn.json .

# %%
import gensim
from gensim.corpora import Dictionary
from gensim.utils import simple_preprocess
import gensim.models as models

import spacy
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

import json
import re

import pyLDAvis
import pyLDAvis.gensim
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Lets just see how the data looks like
import pandas as pd
data = pd.read_json("./ushmm_dn.json")
data
# Out:
#                  RG                                              texts
# 0    RG-50.030.0001   My name David Kochalski. I was born in a smal...
# 1    RG-50.030.0002   All right. My name is Rita Kerner Hilton. I w...
# 2    RG-50.030.0003   Yeah. My full name now is Agnes Adachi, and m...
# 3    RG-50.030.0004   My name is Esthy Adler.  I think I was born i...
# 4    RG-50.030.0006   Where and when were your born?  My father was...
# ..              ...                                                ...
# 247  RG-50.030.0301   No. Per Anger, I got other names, which I had...
# 248  RG-50.030.0302   My name is Helene Barac, Helene D. Barac. I w...
# 249  RG-50.030.0303   A loom, that's right. They did that at home. ...
# 250  RG-50.030.0306   It was in '38 to '39. I remember being--just ...
# 251  RG-50.030.0307   My name is and they used to call us Willy or ...
#
# [252 rows x 2 columns]

# %%
def load_json(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    return data

# %%
# Preprocessing
# Stop-word Removal and Lemmatization
def preprocess_data(docs, allowed_postags=["NOUN", "ADJ", "VERB", "ADV"]):
    final_docs = []
    stop_words = stopwords.words("english")
    nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    for doc in docs:
        doc = nlp(doc)
        filtered_tokens = []
        for token in doc:
            if token not in stop_words and token.pos_ in allowed_postags:
                filtered_tokens.append(token.lemma_)
        filtered_doc = " ".join(filtered_tokens)
        final_docs.append(filtered_doc)
    return final_docs



# Loading
docs = load_json("./ushmm_dn.json")["texts"]
# Preprocessing - Lemmatization
lemmatized_docs = preprocess_data(docs)

# %%
# Tokenization of processed docs
def tokenization(docs):
    final_docs = []
    for doc in docs:
        tokens = simple_preprocess(doc, deacc=True) # returns list of token
        final_docs.append(tokens)
    return final_docs

clean_docs = tokenization(lemmatized_docs)

len(docs), docs[0][:100], len(lemmatized_docs), lemmatized_docs[0][:20], len(clean_docs), clean_docs[0][:20]
# Out:
# (252,
#  ' My name David Kochalski. I was born in a small town called , and I was born May 5, 1928.  Well, we ',
#  252,
#  'name bear small town',
#  252,
#  ['name',
#   'bear',
#   'small',
#   'town',
#   'call',
#   'bear',
#   'very',
#   'hard',
#   'work',
#   'child',
#   'father',
#   'mother',
#   'small',
#   'mill',
#   'flour',
#   'buckwheat',
#   'prosperous',
#   'comfortable',
#   'go',
#   'school'])

# %%
# Generate bigrams and trigrams
bigram_phrases_mdl = gensim.models.Phrases(sentences=clean_docs, min_count=5, threshold=100)
trigram_phrases_mdl = gensim.models.Phrases(sentences=bigram_phrases_mdl[clean_docs], threshold=100)

bigram_phraser = gensim.models.phrases.Phraser(bigram_phrases_mdl)
trigram_phraser = gensim.models.phrases.Phraser(trigram_phrases_mdl)

def generate_bigrams(docs):
    bigram_data = [bigram_phraser[doc] for doc in docs]
    return bigram_data

def generate_trigrams(docs):
    data_bigram_trigrams = [trigram_phraser[bigram_phraser[doc]] for doc in docs]
    return data_bigram_trigrams

# %%
# Generate bigrams and trigrams
bigram_data = generate_bigrams(clean_docs)
data_bigram_trigrams = generate_trigrams(bigram_data) # final data

# %%
# Generate id2word and corpus in bow format for our data with unigrams, bigrams and trigrams
id2word = Dictionary(data_bigram_trigrams)
id2word.token2id, len(id2word.token2id)
# Out:
# ({'able': 0,
#   'able_bodied': 1,
#   'about': 2,
#   'abroad': 3,
#   'absorb': 4,
#   'accord': 5,
#   'activity': 6,
#   'administrator': 7,
#   'advance': 8,
#   'advantage': 9,
#   'afraid': 10,
#   'afternoon': 11,
#   'again': 12,
#   'age': 13,
#   'ago': 14,
#   'agreement': 15,
#   'ahead': 16,
#   'aim': 17,
#   'air': 18,
#   'airman': 19,
#   'ajar': 20,
#   'alive': 21,
#   'all': 22,
#   'allow': 23,
#   'almost': 24,
#   'already': 25,
#   'also': 26,
#   'always': 27,
#   'ammunition': 28,
#   'angle': 29,
#   'angry': 30,
#   'animosity': 31,
#   'announce': 32,
#   'answer': 33,
#   'anticipate': 34,
#   'anxious': 35,
#   'anyhow': 36,
#   'anymore': 37,
#   'apartment': 38,
#   'apparatus': 39,
#   'appreciate': 40,
#   'apprentice': 41,
#   'approach': 42,
#   'approximately': 43,
#   'area': 44,
#   'arithmetic': 45,
#   'armament': 46,
#   'armistice': 47,
#   'army': 48,
#   'around': 49,
#   'arrange': 50,
#   'arreste': 51,
#   'artillery': 52,
#   'as': 53,
#   'as_soon': 54,
#   'ashamed': 55,
#   'ask': 56,
#   'assessment': 57,
#   'at': 58,
#   'attack': 59,
#   'attend': 60,
#   'aunt': 61,
#   'austrian': 62,
#   'avoid': 63,
#   'aware': 64,
#   'away': 65,
#   'back': 66,
#   'bad': 67,
#   'bag': 68,
#   'baked': 69,
#   'baker': 70,
#   'bang': 71,
#   'barbarian': 72,
#   'barbarism': 73,
#   'barber': 74,
#   'basement': 75,
#   'bath': 76,
#   'bathroom': 77,
#   'bear': 78,
#   'beautiful': 79,
#   'become': 80,
#   'bed': 81,
#   'before': 82,
#   'beg': 83,
#   'begin': 84,
#   'beginning': 85,
#   'behave': 86,
#   'behind': 87,
#   'believe': 88,
#   'benign': 89,
#   'big': 90,
#   'bird': 91,
#   'bit': 92,
#   'bitter': 93,
#   'black': 94,
#   'bleed': 95,
#   'blood': 96,
#   'bloody': 97,
#   'body': 98,
#   'bomb': 99,
#   'bombard': 100,
#   'bombardment': 101,
#   'book': 102,
#   'boom': 103,
#   'boot': 104,
#   'bother': 105,
#   'boy': 106,
#   'boyfriend': 107,
#   'brake': 108,
#   'bread': 109,
#   'bridge': 110,
#   'bring': 111,
#   'brother': 112,
#   'bucket': 113,
#   'buckwheat': 114,
#   'buggy': 115,
#   'building': 116,
#   'bullet': 117,
#   'bunker': 118,
#   'burn': 119,
#   'burning': 120,
#   'bury': 121,
#   'business': 122,
#   'busy': 123,
#   'butcher': 124,
#   'buy': 125,
#   'by': 126,
#   'cabinet_maker': 127,
#   'call': 128,
#   'camera': 129,
#   'camp': 130,
#   'capitulate': 131,
#   'care': 132,
#   'carnage': 133,
#   'case': 134,
#   'catch': 135,
#   'catholic': 136,
#   'cave': 137,
#   'cellar': 138,
#   'certain': 139,
#   'certain_amount': 140,
#   'certainly': 141,
#   'chain': 142,
#   'change': 143,
#   'chaos': 144,
#   'chase': 145,
#   'check': 146,
#   'chemist': 147,
#   'chest': 148,
#   'chief': 149,
#   'child': 150,
#   'chimney': 151,
#   'chore': 152,
#   'church': 153,
#   'circle': 154,
#   'circumcise': 155,
#   'circumstance': 156,
#   'city': 157,
#   'class': 158,
#   'clean': 159,
#   'clench': 160,
#   'close': 161,
#   'clothe': 162,
#   'cold': 163,
#   'collapse': 164,
#   'collect': 165,
#   'college': 166,
#   'come': 167,
#   'comfort': 168,
#   'comfortable': 169,
#   'commandant': 170,
#   'communication': 171,
#   'company': 172,
#   'compare': 173,
#   'completely': 174,
#   'concentrate': 175,
#   'concentration': 176,
#   'confession': 177,
#   'confiscate': 178,
#   'congregate': 179,
#   'conscious': 180,
#   'consciousness': 181,
#   'contrary': 182,
#   'cook': 183,
#   'cope': 184,
#   'couldn': 185,
#   'couple': 186,
#   'course': 187,
#   'court': 188,
#   'cousin': 189,
#   'crime': 190,
#   'cross': 191,
#   'cruelly': 192,
#   'cruelty': 193,
#   'crush': 194,
#   'cry': 195,
#   'cubicle': 196,
#   'curfew': 197,
#   'damn': 198,
#   'dance': 199,
#   'dangerous': 200,
#   'day': 201,
#   'daybreak': 202,
#   'dead': 203,
#   'deal': 204,
#   'death': 205,
#   'decide': 206,
#   'decimate': 207,
#   'declare': 208,
#   'deep': 209,
#   'defeat': 210,
#   'defense': 211,
#   'definitely': 212,
#   'delicate': 213,
#   'delivery': 214,
#   'depressed': 215,
#   'deprive': 216,
#   'desperate': 217,
#   'destroy': 218,
#   'deviate': 219,
#   'die': 220,
#   'difference': 221,
#   'different': 222,
#   'differently': 223,
#   'dig': 224,
#   'dig_ditch': 225,
#   'direct': 226,
#   'direction': 227,
#   'dirty': 228,
#   'disappear': 229,
#   'discipline': 230,
#   'discover': 231,
#   'discuss': 232,
#   'disgusted': 233,
#   'dish': 234,
#   'distribute': 235,
#   'distribution': 236,
#   'district': 237,
#   'ditch': 238,
#   'dizzy': 239,
#   'do': 240,
#   'doctor': 241,
#   'dog': 242,
#   'dollar': 243,
#   'door': 244,
#   'down': 245,
#   'downfall': 246,
#   'dream': 247,
#   'dress': 248,
#   'drink': 249,
#   'duck': 250,
#   'ear': 251,
#   'early': 252,
#   'earn': 253,
#   'earth': 254,
#   'easy': 255,
#   'eat': 256,
#   'economically': 257,
#   'edge': 258,
#   'educate': 259,
#   'education': 260,
#   'either': 261,
#   'eld': 262,
#   'elderly': 263,
#   'else': 264,
#   'empty': 265,
#   'enclose': 266,
#   'end': 267,
#   'enemy': 268,
#   'engage': 269,
#   'enough': 270,
#   'entrance': 271,
#   'epidemic': 272,
#   'escape': 273,
#   'especially': 274,
#   'estate': 275,
#   'even': 276,
#   'evening': 277,
#   'event': 278,
#   'eventually': 279,
#   'ever': 280,
#   'everytime': 281,
#   'exact_date': 282,
#   'example': 283,
#   'excrement': 284,
#   'exist': 285,
#   'expansion': 286,
#   'expect': 287,
#   'experience': 288,
#   'eye': 289,
#   'fact': 290,
#   'factory': 291,
#   'family': 292,
#   'far': 293,
#   'farm': 294,
#   'farmer': 295,
#   'fast': 296,
#   'father': 297,
#   'fault': 298,
#   'feed': 299,
#   'feel': 300,
#   'feeling': 301,
#   'fellow': 302,
#   'few': 303,
#   'field': 304,
#   'fierce': 305,
#   'fight': 306,
#   'figure': 307,
#   'fill': 308,
#   'film': 309,
#   'finally': 310,
#   'find': 311,
#   'fine': 312,
#   'finish': 313,
#   'fire': 314,
#   'first': 315,
#   'floor': 316,
#   'flour': 317,
#   'food': 318,
#   'foot': 319,
#   'foreman': 320,
#   'forest': 321,
#   'forget': 322,
#   'free': 323,
#   'fresh': 324,
#   'freshly': 325,
#   'friend': 326,
#   'friendly': 327,
#   'frightened': 328,
#   'front': 329,
#   'full': 330,
#   'funny': 331,
#   'garrison': 332,
#   'gather': 333,
#   'geography': 334,
#   'german': 335,
#   'get': 336,
#   'girl': 337,
#   'girlfriend': 338,
#   'give': 339,
#   'glad': 340,
#   'glue': 341,
#   'go': 342,
#   'gold': 343,
#   'good': 344,
#   'gover': 345,
#   'government': 346,
#   'grab': 347,
#   'grain': 348,
#   'grandfather': 349,
#   'great': 350,
#   'greet': 351,
#   'ground': 352,
#   'group': 353,
#   'guard': 354,
#   'guess': 355,
#   'gun': 356,
#   'guy': 357,
#   'half': 358,
#   'hand': 359,
#   'happen': 360,
#   'happy': 361,
#   'hard': 362,
#   'hardly': 363,
#   'harsh': 364,
#   'hate': 365,
#   'have': 366,
#   'haystack': 367,
#   'head': 368,
#   'healthy': 369,
#   'heap': 370,
#   'hear': 371,
#   'heart': 372,
#   'heavily': 373,
#   'heavy': 374,
#   'heck': 375,
#   'hell': 376,
#   'help': 377,
#   'helter': 378,
#   'here': 379,
#   'heroic': 380,
#   'hesitate': 381,
#   'hide': 382,
#   'high': 383,
#   'hippie': 384,
#   'history': 385,
#   'hit': 386,
#   'hoard': 387,
#   'hold': 388,
#   'holiday': 389,
#   'holocaust': 390,
#   'home': 391,
#   'honestly': 392,
#   'horde': 393,
#   'horrible': 394,
#   'horrid': 395,
#   'horse': 396,
#   'horse_buggy': 397,
#   'hospital': 398,
#   'hour': 399,
#   'house': 400,
#   'however': 401,
#   'huge': 402,
#   'human': 403,
#   'human_being': 404,
#   'hunger': 405,
#   'hungry': 406,
#   'hurt': 407,
#   'husband': 408,
#   'hygienic': 409,
#   'idea': 410,
#   'imagine': 411,
#   'immediately': 412,
#   'impatient': 413,
#   'impossible': 414,
#   'in': 415,
#   'ina': 416,
#   'incident': 417,
#   'include': 418,
#   'inferno': 419,
#   'influence': 420,
#   'influential': 421,
#   'information': 422,
#   'inside': 423,
#   'instead': 424,
#   'institution': 425,
#   'intelligent': 426,
#   'interested': 427,
#   'internal': 428,
#   'interpreter': 429,
#   'interview': 430,
#   'involve': 431,
#   'island': 432,
#   'jail': 433,
#   'jewish': 434,
#   'job': 435,
#   'jump': 436,
#   'just': 437,
#   'keep': 438,
#   'kid': 439,
#   'kill': 440,
#   'kilometer': 441,
#   'kind': 442,
#   'kiss': 443,
#   'know': 444,
#   'knowledgeable': 445,
#   'lady': 446,
#   'land': 447,
#   'language': 448,
#   'last': 449,
#   'late': 450,
#   'later': 451,
#   'law': 452,
#   'lay': 453,
#   'leave': 454,
#   'lecture': 455,
#   'lenient': 456,
#   'less': 457,
#   'lesson': 458,
#   'let': 459,
#   'life': 460,
#   'like': 461,
#   'liking': 462,
#   'lime': 463,
#   'line': 464,
#   'liquidate': 465,
#   'listen': 466,
#   'literally': 467,
#   'little': 468,
#   'live': 469,
#   'living': 470,
#   'load': 471,
#   'local': 472,
#   'locomotive': 473,
#   'lonely': 474,
#   'long': 475,
#   'look': 476,
#   'lorry': 477,
#   'lot': 478,
#   'louse': 479,
#   'lovely': 480,
#   'lucky': 481,
#   'machine_gun': 482,
#   'mad': 483,
#   'majority': 484,
#   'make': 485,
#   'maker': 486,
#   'man': 487,
#   'many': 488,
#   'map': 489,
#   'marching': 490,
#   'marionette': 491,
#   'mark': 492,
#   'marry': 493,
#   'massacre': 494,
#   'maybe': 495,
#   'mayhem': 496,
#   'mean': 497,
#   'medal': 498,
#   'meet': 499,
#   'memory': 500,
#   'mention': 501,
#   'meter': 502,
#   'middle': 503,
#   'midnight': 504,
#   'militia': 505,
#   'mill': 506,
#   'mind': 507,
#   'minute': 508,
#   'mischief': 509,
#   'mischievous': 510,
#   'miserable': 511,
#   'misery': 512,
#   'miss': 513,
#   'mobile': 514,
#   'moment': 515,
#   'money': 516,
#   'month': 517,
#   'more': 518,
#   'morning': 519,
#   'most': 520,
#   'mostly': 521,
#   'mother': 522,
#   'move': 523,
#   'mow': 524,
#   'much': 525,
#   'mystery': 526,
#   'name': 527,
#   'naturally': 528,
#   'need': 529,
#   'neighbor': 530,
#   'neither': 531,
#   'never': 532,
#   'new': 533,
#   'newspaper': 534,
#   'next': 535,
#   'nice': 536,
#   'nicely': 537,
#   'night': 538,
#   'no_matter': 539,
#   'non': 540,
#   'normally': 541,
#   'now': 542,
#   'number': 543,
#   'observe': 544,
#   'occupation': 545,
#   'occupy': 546,
#   'of': 547,
#   'officially': 548,
#   'often': 549,
#   'old': 550,
#   'on': 551,
#   'once': 552,
#   'one': 553,
#   'only': 554,
#   'open': 555,
#   'opening': 556,
#   'order': 557,
#   'ordinal': 558,
#   'organize': 559,
#   'organized': 560,
#   'origin': 561,
#   'orphan': 562,
#   'orphanage': 563,
#   'other': 564,
#   'otherwise': 565,
#   'out': 566,
#   'outside': 567,
#   'over': 568,
#   'overrun': 569,
#   'overwhelming': 570,
#   'own': 571,
#   'owner': 572,
#   'pact': 573,
#   'panic': 574,
#   'paper': 575,
#   'parachute': 576,
#   'parcel': 577,
#   'parent': 578,
#   'part': 579,
#   'particular': 580,
#   'partnership': 581,
#   'party': 582,
#   'pass': 583,
#   'pat': 584,
#   'patriotic': 585,
#   'pay': 586,
#   'pay_attention': 587,
#   'people': 588,
#   'persecution': 589,
#   'person': 590,
#   'personally': 591,
#   'photograph': 592,
#   'physicist': 593,
#   'pick': 594,
#   'pickup': 595,
#   'picture': 596,
#   'piece': 597,
#   'piece_bread': 598,
#   'place': 599,
#   'plane': 600,
#   'play': 601,
#   'pleasant': 602,
#   'point': 603,
#   'police': 604,
#   'policeman': 605,
#   'polish': 606,
#   'population': 607,
#   'poverty': 608,
#   'powder': 609,
#   'practically': 610,
#   'preparation': 611,
#   'prepare': 612,
#   'prepared': 613,
#   'pretend': 614,
#   'pretty': 615,
#   'priest': 616,
#   'privilege': 617,
#   'probably': 618,
#   'problem': 619,
#   'procedure': 620,
#   'professor': 621,
#   'prosper': 622,
#   'prosperous': 623,
#   'provocation': 624,
#   'public': 625,
#   'pull': 626,
#   'pump': 627,
#   'punish': 628,
#   'punishment': 629,
#   'push': 630,
#   'put': 631,
#   'qualified': 632,
#   'quarantine': 633,
#   'quarter': 634,
#   'question': 635,
#   'rabbi': 636,
#   'radio': 637,
#   'raggedy': 638,
#   'raise': 639,
#   'random': 640,
#   'reach': 641,
#   'read': 642,
#   'real': 643,
#   'really': 644,
#   'rebel': 645,
#   'recall': 646,
#   'recognize': 647,
#   'recollect': 648,
#   'recollection': 649,
#   'record': 650,
#   'regain': 651,
#   'regardless': 652,
#   'regimentation': 653,
#   'register': 654,
#   'regulation': 655,
#   'relate': 656,
#   'religion': 657,
#   'religious': 658,
#   'remain': 659,
#   'remember': 660,
#   'remind': 661,
#   'repeat': 662,
#   'resemble': 663,
#   'resent': 664,
#   'resist': 665,
#   'resistance': 666,
#   'respect': 667,
#   'respected': 668,
#   'responsibility': 669,
#   'responsible': 670,
#   'rest': 671,
#   'restaurant': 672,
#   'retreat': 673,
#   'rid': 674,
#   'right': 675,
#   'rightly': 676,
#   'risk': 677,
#   'river': 678,
#   'rob': 679,
#   'robe': 680,
#   'room': 681,
#   'routine': 682,
#   'rule': 683,
#   'run': 684,
#   'runaway': 685,
#   'russian': 686,
#   'sabotage': 687,
#   'same': 688,
#   'sample': 689,
#   'save': 690,
#   'say': 691,
#   'scarcity': 692,
#   'scare': 693,
#   'scared': 694,
#   'scatter': 695,
#   'school': 696,
#   'schooling': 697,
#   'scientifically': 698,
#   'scream': 699,
#   'second': 700,
#   'see': 701,
#   'segregate': 702,
#   'self': 703,
#   'sell': 704,
#   'send': 705,
#   'sentry': 706,
#   'separate': 707,
#   'service': 708,
#   'shake': 709,
#   'shame': 710,
#   'ship': 711,
#   'shoe': 712,
#   'shoemaker': 713,
#   'shoot': 714,
#   'shooting': 715,
#   'short': 716,
#   'show': 717,
#   'shrapnel': 718,
#   'sick': 719,
#   'sickness': 720,
#   'side': 721,
#   'sign': 722,
#   'signal': 723,
#   'singe_song': 724,
#   'sister': 725,
#   'sit': 726,
#   'situation': 727,
#   'skeltor': 728,
#   'skip': 729,
#   'skull': 730,
#   'slash': 731,
#   'sleep': 732,
#   'slowly': 733,
#   'small': 734,
#   'smart': 735,
#   'so': 736,
#   'soldier': 737,
#   'somehow': 738,
#   'sometimes': 739,
#   'somewhere': 740,
#   'son': 741,
#   'soon': 742,
#   'sophisticated': 743,
#   'sorry': 744,
#   'space': 745,
#   'spare': 746,
#   'speak': 747,
#   'special': 748,
#   'specific': 749,
#   'specifically': 750,
#   'spill': 751,
#   'spirit': 752,
#   'spoil': 753,
#   'squeeze': 754,
#   'staff': 755,
#   'stage': 756,
#   'stand': 757,
#   'start': 758,
#   'starvation': 759,
#   'stay': 760,
#   'steal': 761,
#   'still': 762,
#   'stone': 763,
#   'stop': 764,
#   'straight': 765,
#   'strange': 766,
#   'stranger': 767,
#   'street': 768,
#   'strong': 769,
#   'student': 770,
#   'stuff': 771,
#   'subscribe': 772,
#   'sudden': 773,
#   'suffer': 774,
#   'sufferer': 775,
#   'sufficient': 776,
#   'supervise': 777,
#   'supervision': 778,
#   'supper': 779,
#   'supply': 780,
#   'suppose': 781,
#   'sure': 782,
#   'surround': 783,
#   'survive': 784,
#   'synagogue': 785,
#   'tailor': 786,
#   'take': 787,
#   'talk': 788,
#   'tall': 789,
#   'tank': 790,
#   'tape': 791,
#   'task': 792,
#   'teach': 793,
#   'teacher': 794,
#   'tear': 795,
#   'tell': 796,
#   'terrible': 797,
#   'terrific': 798,
#   'that': 799,
#   'theater': 800,
#   'then': 801,
#   'there': 802,
#   'thing': 803,
#   'think': 804,
#   'third': 805,
#   'though': 806,
#   'thought': 807,
#   'thousand': 808,
#   'threaten': 809,
#   'throat': 810,
#   'through': 811,
#   'throw': 812,
#   'time': 813,
#   'tired': 814,
#   'today': 815,
#   'together': 816,
#   'tonight': 817,
#   'too': 818,
#   'tool': 819,
#   'top': 820,
#   'tough': 821,
#   'tourist': 822,
#   'town': 823,
#   'trade': 824,
#   'train': 825,
#   'trap': 826,
#   'treat': 827,
#   'tremendous': 828,
#   'truck': 829,
#   'truth': 830,
#   'try': 831,
#   'turn': 832,
#   'typhu': 833,
#   'unbearable': 834,
#   'uncle': 835,
#   'underground': 836,
#   'understand': 837,
#   'undress': 838,
#   'uneasy': 839,
#   'unhappy': 840,
#   'unite': 841,
#   'university': 842,
#   'unworthy': 843,
#   'up': 844,
#   'upbringing': 845,
#   'uprising': 846,
#   'urge': 847,
#   'use': 848,
#   'very': 849,
#   'village': 850,
#   'vip': 851,
#   'virtually': 852,
#   'vision': 853,
#   'wagon': 854,
#   'wait': 855,
#   'wake': 856,
#   'walk': 857,
#   'wall': 858,
#   'want': 859,
#   'war': 860,
#   'ware': 861,
#   'wash': 862,
#   'watch': 863,
#   'water': 864,
#   'way': 865,
#   'weaken': 866,
#   'wear': 867,
#   'week': 868,
#   'welcome': 869,
#   'well': 870,
#   'wheat': 871,
#   'while': 872,
#   'whirl': 873,
#   'whole': 874,
#   'wife': 875,
#   'will': 876,
#   'window': 877,
#   'wink': 878,
#   'winter': 879,
#   'wire': 880,
#   'witness': 881,
#   'woman': 882,
#   'wonder': 883,
#   'word': 884,
#   'work': 885,
#   'worker': 886,
#   'working': 887,
#   'worry': 888,
#   'worthy': 889,
#   'write': 890,
#   'writing': 891,
#   'wrong': 892,
#   'year': 893,
#   'yet': 894,
#   'young': 895,
#   'youngster': 896,
#   'youth': 897,
#   'abscess': 898,
#   'absolute': 899,
#   'absolutely': 900,
#   'abuse': 901,
#   'accept': 902,
#   'access': 903,
#   'accident': 904,
#   'accommodate': 905,
#   'acquaintance': 906,
#   'across': 907,
#   'act': 908,
#   'action': 909,
#   'actually': 910,
#   'address': 911,
#   'adjust': 912,
#   'administration': 913,
#   'admit': 914,
#   'adopt': 915,
#   'advanced': 916,
#   'adventurous': 917,
#   'advertising': 918,
#   'advice': 919,
#   'afford': 920,
#   'afterward': 921,
#   'agile': 922,
#   'aid': 923,
#   'ailment': 924,
#   'alenluf': 925,
#   'alert': 926,
#   'american': 927,
#   'amount': 928,
#   'anesthesia': 929,
#   'anesthetist': 930,
#   'anger': 931,
#   'animal': 932,
#   'ankle': 933,
#   'annex': 934,
#   'announcement': 935,
#   'ant': 936,
#   'anti': 937,
#   'anti_semitic': 938,
#   'antibiotic': 939,
#   'antiseptic': 940,
#   'anyplace': 941,
#   'anyway': 942,
#   'apart': 943,
#   'appendix': 944,
#   'application': 945,
#   'appoint': 946,
#   'apron': 947,
#   'argue': 948,
#   'argument': 949,
#   'arm': 950,
#   'arm_band': 951,
#   'armband': 952,
#   'arrest': 953,
#   'arrive': 954,
#   'artificial': 955,
#   'artist': 956,
#   'ascertain': 957,
#   'aside': 958,
#   'aspirin': 959,
#   'assembly': 960,
#   'assign': 961,
#   'assist': 962,
#   'assistant': 963,
#   'asthma': 964,
#   'at_all': 965,
#   'attach': 966,
#   'attention': 967,
#   'audacity': 968,
#   'awful': 969,
#   'baby': 970,
#   'babysitter': 971,
#   'bachelor': 972,
#   'backpack': 973,
#   'badly': 974,
#   'bale': 975,
#   'ball': 976,
#   'ballroom': 977,
#   'band': 978,
#   'bandage': 979,
#   'banker': 980,
#   'barbed_wire': 981,
#   'bark': 982,
#   'barrack': 983,
#   'base': 984,
#   'basically': 985,
#   'basis': 986,
#   'basket': 987,
#   'bathe': 988,
#   'bean': 989,
#   'beard': 990,
#   'beat': 991,
#   'beautifully': 992,
#   'bedding': 993,
#   'bedlam': 994,
#   'bedroom': 995,
#   'beet': 996,
#   'belong': 997,
#   'belt': 998,
#   'bench': 999,
#   ...},
#  15675)

# %%
# Remove Frequent words from the corpus token based on their tf-idf values.

tfidf_model = gensim.models.TfidfModel(corpus=my_corpus, id2word=id2word)
